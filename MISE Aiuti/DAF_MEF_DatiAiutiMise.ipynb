# %% [markdown]
# <img src="./img/LogoMise.png">

# %% [markdown]
# # Registro nazionale Aiuti di Stato
#
# ## Ministero dello Sviluppo economico
#
# ## Agenzia per la Coesione Territoriale
#
# ## Ministero del Lavoro e delle Politiche Sociali
#
# ## UE:
#
# * ### [FSE Fondo Sociale Europeo](http://ec.europa.eu/esf/main.jsp?catId=35&langId=it)
#
# * ### [FESR Fondo Europeo di Sviluppo Regionale](http://ec.europa.eu/regional_policy/index.cfm/it/funding/erdf/)
#
# Per aiuto di Stato si intende qualsiasi trasferimento di risorse pubbliche a favore di alcune imprese o produzioni che, attribuendo un vantaggio economico selettivo, falsa o minaccia di falsare la concorrenza.
#
# Tranne in alcuni casi, gli aiuti di Stato sono vietati dalla normativa europea e dal Trattato sul funzionamento dell'Unione Europea che disciplina la materia agli articoli 107 e 108.
#
# Il Dipartimento Politiche Europee, attraverso l'Ufficio per il Coordinamento in materia di aiuti di Stato, cura il coordinamento tra tutte le amministrazioni centrali e regionali per assicurare il rispetto delle norme europee.
#
#
# ### Registro:
#
# A partire dall'**agosto 2017** è stato introdotto il [**"Registro Nazionale Aiuti di Stato"**](http://www.sviluppoeconomico.gov.it/index.php/it/198-notizie-stampa/2036901-registro-nazionale-aiuti-di-stato).
#
# Il nuovo Registro è operativo dal 12 agosto 2017 sul sito http://www.rna.gov.it
#
# [Decreto direttoriale 28 luglio 2017 – Tracciati relativi ai dati e informazioni da trasmettere al Registro nazionale Aiuti e modalità tecniche e protocolli di comunicazione per l'interoperabilità con i sistemi informatici](http://www.sviluppoeconomico.gov.it/index.php/it/component/organigram/?view=structure&id=567)
#
# Il registro Nazionale Aiuti di Stato è il **primo strumento informatizzato attivato da un Paese membro** per il **controllo** e la pubblicità degli aiuti di Stato, Il Registro permette di verificare che le agevolazioni pubbliche siano concesse nel rispetto delle disposizioni previste dalla normativa comunitaria, specie al fine di evitare il cumulo dei benefici e, nel caso degli aiuti de minimis, il superamento del massimale di aiuto concedibile imposto dall’Unione europea.
#
# Lo strumento consente, inoltre, a tutte le amministrazioni pubbliche titolari di misure di aiuto di effettuare i controlli amministrativi necessari con modalità automatiche, grazie al rilascio di specifiche “visure” che recano l’elencazione dei benefici di cui l’impresa ha già goduto negli ultimi esercizi evitando, in tal modo, duplicazioni di interventi da parte di diverse amministrazioni e scongiurando il superamento dei limiti massimi concedibili a ciascuna impresa imposti dalla disciplina UE.
#
# Il Registro è già interconnesso con molti sistemi informativi fra i quali il Registro delle imprese, per l’acquisizione di informazioni relative ai soggetti beneficiari degli aiuti e con i registri SIAN  e SIPA sui quali continueranno ad essere inseriti gli elementi relativi agli aiuti relativi ai settori dell’agricoltura e della pesca.
#
# Vedi: [Divisione III - Monitoraggio e controllo degli interventi, servizi informatici](http://www.sviluppoeconomico.gov.it/index.php/it/component/organigram/?view=structure&id=567)
#
# ### [FSE Fondo Sociale Europeo](http://ec.europa.eu/esf/main.jsp?catId=35&langId=it)
#
# L'Italia sta utilizzando i finanziamenti dell'FSE per incrementare le opportunità lavorative (in particolare per i giovani), aiutare i gruppi svantaggiati, affinare le competenze della forza lavoro, potenziare i sistemi nazionali di istruzione e formazione e migliorare le capacità amministrative.
#
# Il Fondo sociale europeo (FSE) è il principale strumento utilizzato dall’UE per sostenere l'**occupazione**, aiutare i cittadini a trovare posti di lavoro migliori e assicurare opportunità lavorative più eque per tutti. A questo fine, l’FSE investe nel capitale umano dell’Europa: i lavoratori, i giovani e chi è alla ricerca di un lavoro. Grazie a una dotazione di **10 miliardi di euro l’anno**, l’FSE aumenta le prospettive occupazionali di milioni di cittadini europei, prestando particolare attenzione a chi incontra maggiori difficoltà a trovare lavoro.
#
# L’Unione europea si è impegnata a creare nuovi e migliori posti di lavoro e a realizzare una società inclusiva. Tali obiettivi sono al centro della strategia Europa 2020 per una crescita intelligente, sostenibile e inclusiva nell’UE. L’attuale crisi economica rende questa sfida ancora più ambiziosa. L'FSE sta rivestendo un ruolo importante per il raggiungimento degli obiettivi dell'Europa e per l'attenuazione degli effetti della crisi, in particolare l'aumento dei **livelli di disoccupazione e povertà**.
#
# ### [FESR Fondo Europeo di Sviluppo Regionale](http://ec.europa.eu/regional_policy/index.cfm/it/funding/erdf/)
#
# Il Fondo europeo di sviluppo regionale (Fesr), creato nel 1975, promuove l'adeguamento strutturale delle regioni in ritardo di sviluppo e la riconversione delle zone industriali in declino.
# In tale ottica, concorre alla promozione di un alto livello occupazionale, delle pari opportunità e della protezione e dello sviluppo sostenibile.
#
# #### LINK
#
# http://europalavoro.lavoro.gov.it/EuropaLavoro/Varie/Che-cos-il-Fondo-Sociale-Europeo
#
# http://europalavoro.lavoro.gov.it/europalavoro.lavoro.gov.it/EuropaLavoro/Varie/programmazione-2014-2020
#
# http://ec.europa.eu/esf/main.jsp?catId=35&langId=it
#
#
# ## Spunti di analisi
#
# - Sarebbe interessante avere accesso ai dati dell'Agenzia delle Entrate e misurare l'efficacia dell'aiuto ricevuto dall'ente.
#
#
# ## Collaborazioni:
#
# - Telemaco il servizio per identificare una p.Iva o Cod Fiscale con anagrafica è a pagamento e non è disponibile nè nel DAF nè in Open data
#
#
# ## Dati
#
# * [DATASET](https://www.rna.gov.it/RegistroNazionaleTrasparenza/faces/pages/OpenDataAiuti.jspx)  (Data elaborazione 30/12/2017)
#
# Dal 10-2009 ad oggi, il file indica il nome del mese. Per alcuni mesi non c'è il relativo file, alcuni buchi.
#
# Licenza:  ["IODL: Italian Open Data License v2.0".](http://www.dati.gov.it/iodl/2.0/)
#
# I file sono nominati OpenData_yyyy_mm.xml con mm e yyyy coincidenti rispettivamente con il mese e l’anno di inizio della misura per gli Open Data delle Misure di Aiuto
#
# Caratteristiche:
# * Attuali: il Registro Nazionale degli aiuti di Stato è stato approvato solo ad Agosto 2017
# * Granularità elevata
# * Probabilmente non ancora mai usati in dashboard istituzionali
# * Formato XML
# * Profondità temporale: dal 2010 - 1 file XML per mese
#
#
# * [METADATI originali in PDF](https://www.rna.gov.it/cs/groups/public/documents/document/y2mt/mdax/~edisp/cl_wcc-001577.pdf)
#
# Ho creato sotto la cartella D_general in Data  un dizionario dei metadati in un csv per ogni dimensione:
#  -  [Metadati Aiuti](data/D_general/MetadatiAiuti.csv)

# %%
#IPython setting
from IPython.display import display, HTML
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all" #permetti di eseguire pi
pd.set_option('display.max_colwidth', -1) #setta l'esecuzione di più statement in unica cella

# %%
metadati = pd.read_csv("data/D_general/MetadatiAiuti.csv", sep=';', header=0)
metadati
# Out:
#              Sezione                        Campo  \
# 0   AIUTO             CAR
# 1   AIUTO             TITOLO_MISURA
# 2   AIUTO             DES_TIPO_MISURA
# 3   AIUTO             COD_CE_MISURA
# 4   AIUTO             BASE_GIURIDICA_NAZIONALE
# 5   AIUTO             LINK_TESTO_INTEGRALE_MISUR
# 6   AIUTO             COD_UFF_GESTORE
# 7   AIUTO             DENOMINAZIONE_UFF_GESTORE
# 8   AIUTO             SOGGETTO_CONCEDENTE
# 9   AIUTO             COR
# 10  AIUTO             TITOLO_PROGETTO
# 11  AIUTO             DESCRIZIONE_PROGETTO
# 12  AIUTO             LINK_TRASPARENZA_NAZIONALE
# 13  AIUTO             DATA_CONCESSIONE
# 14  AIUTO             CUP
# 15  AIUTO             ATTO_CONCESSIONE
# 16  AIUTO             LINK_ATTO_CONCESSIONE
# 17  AIUTO             DENOMINAZIONE_BENEFICIARIO
# 18  AIUTO             CODICE_FISCALE_BENEFICIARIO
# 19  AIUTO             DES_TIPO_BENEFICIARIO
# 20  AIUTO             REGIONE_BENEFICIARIO
# 21  COMPONENTE_AIUTO  ID_COMPONENTE_AIUTO
# 22  COMPONENTE_AIUTO  COD_PROCEDIMENTO
# 23  COMPONENTE_AIUTO  DES_PROCEDIMENTO
# 24  COMPONENTE_AIUTO  COD_REGOLAMENTO
# 25  COMPONENTE_AIUTO  DES_REGOLAMENTO
# 26  COMPONENTE_AIUTO  COD_OBIETTIVO
# 27  COMPONENTE_AIUTO  DES_OBIETTIVO
# 28  COMPONENTE_AIUTO  SOGGETTO_INTERMEDIARIO
# 29  COMPONENTE_AIUTO  ENTITA_DELEGATA
# 30  COMPONENTE_AIUTO  SETTORE_ATTIVITA
# 31  STRUMENTO         COD_STRUMENTO
# 32  STRUMENTO         DES_STRUMENTO
# 33  STRUMENTO         ELEMENTO_DI_AIUTO
#
#                                                                                                                                                                                                                                                         Significato
# 0   Codice identificativo della Misura assegnato dal Registro
# 1   Titolo della Misura di Aiuto
# 2   Tipologia di misura (ovvero Regime di aiuti o Aiuto ad hoc)
# 3   Eventuale Identificativo della Misura CE come rilasciato dal sistema SANI
# 4   Denominazione estesa della norma che istituisce la misura
# 5   Link al testo integrale della misura
# 6   Codice nel Registro dell'Ufficio Gestore che gestisce l'Aiuto Individuale
# 7   Denominazione dell'Ufficio Gestore che gestisce l'Aiuto Individuale
# 8   Soggetto Concedente ai sensi del Regolamento che disciplina il funzionamento del Registro
# 9   Codice univoco rilasciato dal Registro in esito alla registrazione dell'Aiuto individuale; il codice identifica univocamente la registrazione di un Aiuto nel Registro Nazionale Aiuti ("Codice Concessione RNA")
# 10  Titolo del progetto per la realizzazione del quale  destinata la concessione dell'Aiuto
# 11  Descrizione sintetica del progetto per la realizzazione del quale  destinata la concessione dell'Aiuto
# 12  Collegamento con la sezione trasparenza del sito web predisposto ai fini del rispetto degli obblighi di trasparenza previsti dalla normativa nazionale
# 13  Data in cui al beneficiario  accordato, a norma del regime giuridico nazionale applicabile, il diritto di ricevere l'Aiuto
# 14  Codice Unico di Progetto d'investimento pubblico (CUP) rilasciato dal Sistema CUP del PCM-DIPE
# 15  Dati Identificativi dell'atto di concessione Aiuto (tipo numero e data dell'atto)
# 16  Link all'atto di concessione
# 17  Codice fiscale che identifica univocamente il soggetto beneficiario con sede in Italia, oppure, VAT identification number UE valido nel sistema VIES in caso di soggetto estero senza sede secondaria in Italia (e non registrata presso in Registro delle
# 18  Ragione sociale/Denominazione del soggetto beneficiario
# 19  Dimensione aziendale del soggetto beneficiario come definita dalla Raccomandazione 2003/361/CE del 6 maggio 2003
# 20  Regione di localizzazione del soggetto beneficiario
# 21  Identificativo, nel Registro della componente id aiuto
# 22  Codice nel Registro del procedimento in applicazione del quale vengono concessi gli aiuti
# 23  Descrizione del procedimento in applicazione del quale vengono concessi gli aiuti (ex notifica, esenzione, de minimis)
# 24  Codice nel Registro del Regolamento in applicazione del quale vengono concessi gli aiuti
# 25  Regolamento in applicazione del quale vengono concessi gli aiuti
# 26  Codice nel Registro dell'obiettivo
# 27  Descrizione dell'obiettivo
# 28  Descrizione dell'istituzione finanziaria, a prescindere dalla sua forma e dal suo assetto proprietario; da indicare solo in caso di concessione di Aiuti a finalitˆ regionale per lo sviluppo urbano (Art.16 Reg.651/2014) e Aiuti al finanziamento del rischio
# 29  Descrizione dell'Entitˆ intermediaria, in caso di concessione di Aiuti a finalitˆ regionale per lo sviluppo urbano (Art.16 Reg.651/2014) e Aiuti al finanziamento del rischio (Art.21 Reg.651/2014)
# 30  Attivitˆ interessate dalla componente di Aiuto seconto la codifica NACE
# 31  Codice nel Registro dello strumento ovvero della forma attraverso la quale gli aiuti possono essere concessi ai soggetti beneficiari
# 32  Identifica le forme attraverso la quale gli aiuti possono essere concessi ai soggetti beneficiari
# 33  Importo dell'aiuto (espresso in Û) concesso per la componente di aiuto e per ciascun tipo di strumento di Aiuto se fosse stato erogato al beneficiario sotto forma di sovvenzione, al lordo di qualsiasi imposta o altro onere

# %% [markdown]
# ## Data preparation:
#
# ### XML to JSON

# %%
import pandas as pd
import numpy as np
import json 
import os
import seaborn as sns
import matplotlib as mpl 
import matplotlib.cm as cm 
import matplotlib.pyplot as plt 
import matplotlib.style as style
import seaborn as sns 
# %matplotlib inline 

sns.set_context("notebook")
sns.set()
sns.set_style("darkgrid")
sns.set_palette(sns.color_palette("Set2", 10))

style.use('fivethirtyeight')

# %% [markdown]
# I dati rilasciati dal MISE sono in format XML. Per poterli agevolmente trattare converto ogni file XML in formato JSON tramite la libreria [xmltodict]("https://github.com/martinblech/xmltodict").
#
# Per questioni di spazio sul repo github non sono stati caricati i file nativi in formato XML ma solo i JSON finali.
# Il codice presente qui di seguito è stato usato per creare la trasformazione.

# %%
#https://github.com/martinblech/xmltodict
import xmltodict

fileDir = os.path.dirname(os.path.realpath('__file__'))
tot_file = 0
listing = os.listdir(fileDir)   

for infile in listing:
    
    if infile.endswith((".xml")):
        tot_file+=1
        name = os.path.splitext(infile)[0]
        filename = os.path.join(fileDir, infile)
        print (filename)
        with open(filename, 'r') as f:
            xmlString = f.read()
            jsonString = json.dumps(xmltodict.parse(xmlString), indent=4) #check indent
        
        with open("./output/"+name + ".json", 'w') as f:
            f.write(jsonString) 

print ("Tot file: "+str(tot_file))

# %% [markdown]
# ### Struttura dataset:

# %% [markdown]
# Ogni AIUTO è composto da delle informazioni di base e da uno o più COMPONENTI di aiuto.
#
# Ogni componente d'aiuto può essere composto da più STRUMENTI
#
# Suddividere le info in tre dataframe:
#
# 1- Dati anagrafici dell'**aiuto** --> data_aiuto
#
# 2- **Componenti** dell'aiuto --> data_componenti con chiave campo "COR"
#
# 3- **Strumento/i** del Componente --> data_
#
# I tre dataframe sono in relazione tramite il campo **COR**, ***ID_COMPONENTE_AIUTO** e
#
# **COR:**
# Codice univoco rilasciato dal Registro in esito alla registrazione dell'Aiuto individuale; il codice identifica univocamente la registrazione di un Aiuto nel Registro Nazionale Aiuti (“Codice Concessione RNA”)

# %% [markdown]
# #### Elenco metadati

# %%
good_infos_aiuto = [
    "CAR",
    "TITOLO_MISURA",
    "DES_TIPO_MISURA",
    "BASE_GIURIDICA_NAZIONALE",
    "LINK_TESTO_INTEGRALE_MISURA",
    "COD_UFF_GESTORE",
    "DENOMINAZIONE_UFF_GESTORE",
    "SOGGETTO_CONCEDENTE",
    "COR",
    "TITOLO_PROGETTO",
    "DESCRIZIONE_PROGETTO",
    "DATA_CONCESSIONE",
    "CUP",
     #"ATTO_CONCESSIONE",
    "DENOMINAZIONE_BENEFICIARIO",
    "CODICE_FISCALE_BENEFICIARIO",
    "DES_TIPO_BENEFICIARIO",
    "REGIONE_BENEFICIARIO"
    
]

good_infos_componente = [
    "ID_COMPONENTE_AIUTO",
    "COD_PROCEDIMENTO",
    "DES_PROCEDIMENTO",
    "COD_REGOLAMENTO",
    "DES_REGOLAMENTO",
    "COD_OBIETTIVO",
    "DES_OBIETTIVO",
    "SETTORE_ATTIVITA"
]

df_infos_componente = [
    "COR", #id componente 
    "ID_COMPONENTE_AIUTO",
    "COD_PROCEDIMENTO",
    "DES_PROCEDIMENTO",
    "COD_REGOLAMENTO",
    "DES_REGOLAMENTO",
    "COD_OBIETTIVO",
    "DES_OBIETTIVO",
    "SETTORE_ATTIVITA"
]


good_infos_strumento = [
    "COD_STRUMENTO",
    "DES_STRUMENTO",
    "ELEMENTO_DI_AIUTO"
]    


df_infos_strumento = [
    "COR", #id componente 
    "ID_COMPONENTE_AIUTO", #id componente aiuto
    "COD_STRUMENTO",
    "DES_STRUMENTO",
    "ELEMENTO_DI_AIUTO"
]

# %% [markdown]
# Al fine di rendere più agevole e scalabile l'analisi si è deciso di:
#
# - caricare tutti i file in formato json presenti e trasformati precedentemente
# - creare tre strutture dati che identificano le tre macro sezioni degli aiuti:
#
#
# Ogni AIUTO è composto da delle informazioni di base e da uno o più COMPONENTI di aiuto.
#
# Ogni componente d'aiuto può essere composto da più STRUMENTI.
#
#
# Le info verranno salvate in tre differenti dataframe che sarà poi possibile unire tramite join:
#
# 1- **AIUTI**: dati anagrafici dell'**aiuto** --> data_aiuto
#
# 2- **COMPONENTI**: dati anagrafici dell'aiuto --> data_componenti
#
# 3- **STRUMENTI**: dati anagrafici strumenti del Componente --> data_strumenti
#
# I tre dataframe sono in relazione tramite il campo **COR** e **ID_COMPONENTE_AIUTO**
#
# **COR:**
# Codice univoco rilasciato dal Registro in esito alla registrazione dell'Aiuto individuale; il codice identifica univocamente la registrazione di un Aiuto nel Registro Nazionale Aiuti (“Codice Concessione RNA”)
#
# **ID_COMPONENTE_AIUTO**: identificativo del componente dell'aiuto

# %%
#Crea sezione componente
def list_componente(cor_id, componente):
    comp=[]
    comp.append(cor_id)
    for c in good_infos_componente:
        comp.append(componente[c])
    return comp  

#Crea sezione strumento
def list_strumento(cor_id, comp_id, strumento):
    strum=[]
    strum.append(cor_id)
    strum.append(comp_id)
    for c in good_infos_strumento:
        strum.append(strumento[c])
    return strum

# %%
#final list with all AIUTI
data_aiuto = []
#final list with all COMPONENTI
data_componenti = []
#final list with all STRUMENTI
data_strumenti = []

fileDir = os.path.dirname(os.path.realpath('__file__'))
output_folder = os.path.join(fileDir, 'data/D_aiuti/')
listing = os.listdir(output_folder)   
#loop in json files from folder
for infile in listing: 
    if infile.endswith((".json")):
        filename = os.path.join(fileDir, infile)
        #List Files
        print (filename)
        filename = os.path.join(output_folder, infile)
        filehandle = open(filename)
        
        data = json.load(filehandle)    

        aiuto = data["LISTA_AIUTI"]["AIUTO"]
       
        if isinstance(aiuto,list):
            for row in aiuto:
                cor_id = row["COR"]
                #CREA AIUTO
                selected_row = []
                for a in good_infos_aiuto:
                    selected_row.append(row[a])
                    #CREA COMPONENTI: nuova lista di liste per i componenti e strumenti    
                componente = row["COMPONENTI_AIUTO"]["COMPONENTE_AIUTO"]
                    #check if it's a list or dictionary
                if isinstance(componente,list):
                    for i in componente:
                        comp_id = i["ID_COMPONENTE_AIUTO"] #serve per poi la chiave dello strumento
                        data_componenti.append(list_componente(cor_id,i)) 
                        #CREA STRUMENTO
                        strumento_0 = i["STRUMENTO_AIUTO"]
                        if strumento_0 is not None:
                            strumento = strumento_0["STRUMENTO_AIUTO"]
                            if isinstance(strumento,list):
                                for s in strumento:
                                    data_strumenti.append(list_strumento(cor_id, comp_id, s))    
                            if isinstance(strumento,dict):
                                data_strumenti.append(list_strumento(cor_id, comp_id, strumento))

                    #list, dict
                if isinstance(componente,dict):
                    comp_id = componente["ID_COMPONENTE_AIUTO"] 
                    data_componenti.append(list_componente(cor_id,componente)) 
                    #CREA STRUMENTO
                    strumento_0 = componente["STRUMENTO_AIUTO"]
                    if strumento_0 is not None:
                        strumento = strumento_0["STRUMENTO_AIUTO"]
                        #list, dict,list
                        if isinstance(strumento,list):
                            for s in strumento:
                                data_strumenti.append(list_strumento(cor_id, comp_id, s))
                                #list, dict,dict
                        if isinstance(strumento,dict):
                            data_strumenti.append(list_strumento(cor_id, comp_id, strumento))
                            #end strumenti
                        #add aiuto
                data_aiuto.append(selected_row)
                    
        # se c'è un unico aiuto è dict non lista
        if isinstance(aiuto,dict):
            cor_id = aiuto["COR"]
            selected_row = []
            componenti = []
            for a in good_infos_aiuto:
                selected_row.append(aiuto[a])
            componente = row["COMPONENTI_AIUTO"]["COMPONENTE_AIUTO"]

                #check if it's a list or dictionary
            if isinstance(componente,list):
                for i in componente:
                    comp_id = i["ID_COMPONENTE_AIUTO"] #serve per poi la chiave dello strumento
                    data_componenti.append(list_componente(cor_id,i)) 
                    #CREA STRUMENTI
                    strumento_0 = componente["STRUMENTO_AIUTO"]
                    if strumento_0 is not None:
                        strumento = strumento_0["STRUMENTO_AIUTO"]
                        if isinstance(strumento,list):
                            for s in strumento:
                                data_strumenti.append(list_strumento(cor_id, comp_id, s))
                        if isinstance(strumento,dict):
                                data_strumenti.append(list_strumento(cor_id, comp_id, strumento))
            #DICT
            if isinstance(componente,dict):
                comp_id = componente["ID_COMPONENTE_AIUTO"] 
                data_componenti.append(list_componente(cor_id,componente)) 
                strumento_0 = componente["STRUMENTO_AIUTO"]
                if strumento_0 is not None:
                    strumento = strumento_0["STRUMENTO_AIUTO"]
                    if isinstance(strumento,list):
                        for s in strumento:
                            data_strumenti.append(list_strumento(cor_id, comp_id, s))
                    if isinstance(strumento,dict):
                        data_strumenti.append(list_strumento(cor_id, comp_id, strumento))
                #Add aiuto
        data_aiuto.append(selected_row)
    filehandle.close()

# %% [markdown]
# ## Assemblo tutti gli AIUTI in unico dataframe

# %%
aiuti = pd.DataFrame(data_aiuto, columns=good_infos_aiuto)
#aiuti.set_index('COR', inplace=True)
aiuti.columns
aiuti.shape
aiuti.describe(include='all')
aiuti.sample(3)
# Out:
# Index(['CAR', 'TITOLO_MISURA', 'DES_TIPO_MISURA', 'BASE_GIURIDICA_NAZIONALE',
#        'LINK_TESTO_INTEGRALE_MISURA', 'COD_UFF_GESTORE',
#        'DENOMINAZIONE_UFF_GESTORE', 'SOGGETTO_CONCEDENTE', 'COR',
#        'TITOLO_PROGETTO', 'DESCRIZIONE_PROGETTO', 'DATA_CONCESSIONE', 'CUP',
#        'DENOMINAZIONE_BENEFICIARIO', 'CODICE_FISCALE_BENEFICIARIO',
#        'DES_TIPO_BENEFICIARIO', 'REGIONE_BENEFICIARIO'],
#       dtype='object')
# (168782, 17)
#            CAR                                     TITOLO_MISURA  \
# count   168782  168782
# unique  772     767
# top     526     Fondo di garanzia per le piccole e medie imprese
# freq    45318   45318
#
#         DES_TIPO_MISURA  \
# count   168782
# unique  2
# top     Regime di aiuti
# freq    168754
#
#                                               BASE_GIURIDICA_NAZIONALE  \
# count   168782
# unique  580
# top     Decreto del Ministro dello sviluppo economico 19 novembre 2015
# freq    45318
#
#                                                            LINK_TESTO_INTEGRALE_MISURA  \
# count   168782
# unique  656
# top     http://www.sviluppoeconomico.gov.it/images/stories/normativa/DM_19_11_2015.pdf
# freq    45318
#
#                                    COD_UFF_GESTORE  \
# count   168782
# unique  381
# top     MCC - Direzione Interventi per lo Sviluppo
# freq    45318
#
#                                  DENOMINAZIONE_UFF_GESTORE  \
# count   168782
# unique  433
# top     Banca del Mezzogiorno MedioCredito Centrale S.p.A.
# freq    45318
#
#                                        SOGGETTO_CONCEDENTE     COR  \
# count   168782                                              168782
# unique  275                                                 168712
# top     Banca del Mezzogiorno MedioCredito Centrale S.p.A.  45531
# freq    45318                                               2
#
#                     TITOLO_PROGETTO  \
# count   168782
# unique  29128
# top     Fondo di Garanzia lg.662/96
# freq    45318
#
#                                   DESCRIZIONE_PROGETTO  DATA_CONCESSIONE  \
# count   168782                                          168782
# unique  23860                                           701
# top     Fondo di Garanzia lg.662/96 - Garanzia diretta  2017-12-22+01:00
# freq    28964                                           8717
#
#                     CUP DENOMINAZIONE_BENEFICIARIO  \
# count   168782           168782
# unique  66111            130585
# top     B58C96000000001  Politecnico di Milano
# freq    43186            62
#
#        CODICE_FISCALE_BENEFICIARIO DES_TIPO_BENEFICIARIO REGIONE_BENEFICIARIO
# count   168782                      168782                168782
# unique  129638                      3                     135
# top     80003950781                 PMI                   Lombardia
# freq    71                          162684                38563
#        CAR  \
# 46765  526
# 49849  884
# 65115  702
#
#                                                                                                                                                                                                                    TITOLO_MISURA  \
# 46765  Fondo di garanzia per le piccole e medie imprese
# 49849  Regolamento per i fondi interprofessionali per la formazione continua per la concessioni di aiuti di stato esentati ai sensi del regolamento CE n.651/2014 e in regime de minimis ai sensi del regolamento CE n.1407/2013
# 65115  LINEA DI INTERVENTO CONTROGARANZIE
#
#        DES_TIPO_MISURA  \
# 46765  Regime di aiuti
# 49849  Regime di aiuti
# 65115  Regime di aiuti
#
#                                                                                         BASE_GIURIDICA_NAZIONALE  \
# 46765  Decreto del Ministro dello sviluppo economico 19 novembre 2015
# 49849  Disposizioni per la formazione del bilancio annuale e pluriennale dello Stato (legge finanziaria 2001
# 65115  ISTITUZIONE DELLA LINEA “CONTROGARANZIA” E DEL RELATIVO FONDO A VALERE SULL’ASSE III POR FESR 2014 – 2020
#
#                                                                                                                                                                                                                                      LINK_TESTO_INTEGRALE_MISURA  \
# 46765  http://www.sviluppoeconomico.gov.it/images/stories/normativa/DM_19_11_2015.pdf
# 49849  http://www.anpal.gov.it/Aziende/Fondo_Interprofessionali/Pagine/default.aspx
# 65115  http://www.regione.lombardia.it/cs/Satellite?c=Attivita&childpagename=HomeSPRL%2FWrapperBandiLayout&cid=1213812630787&p=1213812630787&packedargs=locale%3D1194453881584%26menu-to-render%3D1213301212544&pagename=HMSPRLWrapper&tipologia=Bandi%20Europei
#
#                                   COD_UFF_GESTORE  \
# 46765  MCC - Direzione Interventi per lo Sviluppo
# 49849  017
# 65115  RLO135
#
#                                             DENOMINAZIONE_UFF_GESTORE  \
# 46765  Banca del Mezzogiorno MedioCredito Centrale S.p.A.
# 49849  Formazienda
# 65115  UO COMPETITIVITA', SVILUPPO E ACCESSO AL CREDITO DELLE IMPRESE
#
#                                       SOGGETTO_CONCEDENTE     COR  \
# 46765  Banca del Mezzogiorno MedioCredito Centrale S.p.A.  97601
# 49849  Formazienda                                         101005
# 65115  Regione Lombardia - DG Sviluppo economico           50830
#
#                                                      TITOLO_PROGETTO  \
# 46765  Fondo di Garanzia lg.662/96
# 49849  Lingue e abilità personali
# 65115  DIMENSIONI INFISSI DI DEFENDI GIUSEPPE E ALLIEVI GIOVANNI SNC
#
#                                                 DESCRIZIONE_PROGETTO  \
# 46765  Fondo di Garanzia lg.662/96 - Garanzia diretta
# 49849  Formazione continua Lavoratori
# 65115  DIMENSIONI INFISSI DI DEFENDI GIUSEPPE E ALLIEVI GIOVANNI SNC
#
#        DATA_CONCESSIONE              CUP  \
# 46765  2017-10-18+02:00  B58C96000000001
# 49849  2017-10-25+02:00  000000000000000
# 65115  2017-01-10+01:00  E48C16000160009
#
#                                           DENOMINAZIONE_BENEFICIARIO  \
# 46765  BONTADI ROBERTO
# 49849  ANGELINI & PARTNERS SRL
# 65115  DIMENSIONI INFISSI DI DEFENDI GIUSEPPE E ALLIEVI GIOVANNI SNC
#
#       CODICE_FISCALE_BENEFICIARIO DES_TIPO_BENEFICIARIO  \
# 46765  BNTRRT61T18A952W            PMI
# 49849  03007960739                 PMI
# 65115  02343010167                 PMI
#
#                REGIONE_BENEFICIARIO
# 46765  Provincia Autonoma di Trento
# 49849  Puglia
# 65115  Lombardia

# %% [markdown]
# ## Assemblo tutti i COMPONENTI in unico dataframe

# %%
componenti = pd.DataFrame(data_componenti, columns=df_infos_componente)
componenti.columns
componenti.shape
componenti.describe(include='all')
#componenti.set_index('COR', inplace=True)
componenti.sample(3)
# Out:
# Index(['COR', 'ID_COMPONENTE_AIUTO', 'COD_PROCEDIMENTO', 'DES_PROCEDIMENTO',
#        'COD_REGOLAMENTO', 'DES_REGOLAMENTO', 'COD_OBIETTIVO', 'DES_OBIETTIVO',
#        'SETTORE_ATTIVITA'],
#       dtype='object')
# (171062, 9)
#            COR ID_COMPONENTE_AIUTO COD_PROCEDIMENTO DES_PROCEDIMENTO  \
# count   171062  171062              171062           171062
# unique  168712  171060              3                3
# top     171390  211301              1                De Minimis
# freq    12      2                   138028           138028
#
#        COD_REGOLAMENTO                         DES_REGOLAMENTO COD_OBIETTIVO  \
# count   171062          171062                                  171062
# unique  8               8                                       66
# top     CE1407/13       Reg. UE 1407/2013  de minimis generale  100800
# freq    116887          116887                                  71143
#
#        DES_OBIETTIVO SETTORE_ATTIVITA
# count   171062        171062
# unique  56            914
# top     PMI           G.47.7
# freq    72382         7397
#           COR ID_COMPONENTE_AIUTO COD_PROCEDIMENTO DES_PROCEDIMENTO  \
# 75604   4016   4888                1                De Minimis
# 75182   3593   4447                1                De Minimis
# 114869  71368  80358               1                De Minimis
#
#        COD_REGOLAMENTO                         DES_REGOLAMENTO COD_OBIETTIVO  \
# 75604   CE1998/2006     Reg. CE 1998/2006 de minimis  generale  150200
# 75182   CE1998/2006     Reg. CE 1998/2006 de minimis  generale  150200
# 114869  CE1407/13       Reg. UE 1407/2013  de minimis generale  100800
#
#                       DES_OBIETTIVO SETTORE_ATTIVITA
# 75604   Sviluppo regionale o locale  S.96.0
# 75182   Sviluppo regionale o locale  C.33.2
# 114869  PMI                          G.47.2

# %% [markdown]
# ## Assemblo tutti gli STRUMENTI in unico dataframe

# %%
strumenti = pd.DataFrame(data_strumenti, columns=df_infos_strumento)
#cast campo ELEMENTO_DI_AIUTO da object a float
strumenti['ELEMENTO_DI_AIUTO'] = strumenti['ELEMENTO_DI_AIUTO'].astype(float)
strumenti.describe(include='all')
strumenti.shape
#strumenti.set_index('COR', inplace=True)
strumenti.sample(3)
# Out:
#            COR ID_COMPONENTE_AIUTO COD_STRUMENTO  \
# count   172741  172741              172741
# unique  168712  171022              69
# top     171390  119040              10
# freq    12      4                   59286
# mean    NaN     NaN                 NaN
# std     NaN     NaN                 NaN
# min     NaN     NaN                 NaN
# 25%     NaN     NaN                 NaN
# 50%     NaN     NaN                 NaN
# 75%     NaN     NaN                 NaN
# max     NaN     NaN                 NaN
#
#                                     DES_STRUMENTO  ELEMENTO_DI_AIUTO
# count   172741                                     1.727410e+05
# unique  52                                        NaN
# top     Sovvenzione/Contributo in conto interessi NaN
# freq    75365                                     NaN
# mean    NaN                                        3.124805e+04
# std     NaN                                        1.251155e+06
# min     NaN                                        0.000000e+00
# 25%     NaN                                        1.078440e+03
# 50%     NaN                                        4.192860e+03
# 75%     NaN                                        1.562254e+04
# max     NaN                                        3.033114e+08
# (172741, 5)
#            COR ID_COMPONENTE_AIUTO COD_STRUMENTO  \
# 19182   127210  140359              37
# 48252   97086   108644              10
# 121185  76953   86393               37
#
#                                                                           DES_STRUMENTO  \
# 19182   Sovvenzione/Contributo in conto interessi
# 48252   Garanzia (se del caso con un riferimento alla decisione della Commissione (10))
# 121185  Sovvenzione/Contributo in conto interessi
#
#         ELEMENTO_DI_AIUTO
# 19182   3960.00
# 48252   1372.22
# 121185  1500.00

# %% [markdown]
# ## Info beneficiario
# Estraggo le denominazioni del beneficiario dalla sezione **"AIUTI"** e il codice fiscale o piva per andare a interrogare il servizio della Commissione Europea al fine di arricchire le info che abbiamo sul beneficiario per poterlo geolocalizzare a livello di comune.
#
#
# WSDL servizio:
#
# http://ec.europa.eu/taxation_customs/vies/checkVatService.wsdl
#
# Le informazioni disponibili nel dataset original permettono di identificare la Regione ma non il comune.

# %%
aiuti_id = aiuti[["CODICE_FISCALE_BENEFICIARIO"]]
aiuti_id.to_csv("./data/D_general/MappingRagioneSocialeIvaCodFisc.csv", sep='\t',index=False)

# %% [markdown]
# ## Data Exploration

# %%
aiuti.shape
componenti.shape
strumenti.shape
# Out:
# (168782, 17)
# (171062, 9)
# (172741, 5)

# %%
aiuti.columns
aiuti.describe(include='all')
#CAST DATA DI CONCESSIONE con datetime 
#ma il formato del time zone è sbagliato format='%Y-%m-%d%z' - es: 2016-08-05+02:00
#aiuti['DATA_CONCESSIONE_2'] =  pd.to_datetime(aiuti['DATA_CONCESSIONE'], format='%Y-%m-%d%z') #%Y-%m-%dT%H:%M:%S%z')
aiuti['DATA_CONCESSIONE'] = aiuti['DATA_CONCESSIONE'].astype('str')
aiuti['DATA_CONCESSIONE'] = aiuti.DATA_CONCESSIONE.str[:10]
aiuti['DATA_CONCESSIONE'] = pd.to_datetime(aiuti['DATA_CONCESSIONE'], format='%Y-%m-%d')
# Out:
# Index(['CAR', 'TITOLO_MISURA', 'DES_TIPO_MISURA', 'BASE_GIURIDICA_NAZIONALE',
#        'LINK_TESTO_INTEGRALE_MISURA', 'COD_UFF_GESTORE',
#        'DENOMINAZIONE_UFF_GESTORE', 'SOGGETTO_CONCEDENTE', 'COR',
#        'TITOLO_PROGETTO', 'DESCRIZIONE_PROGETTO', 'DATA_CONCESSIONE', 'CUP',
#        'DENOMINAZIONE_BENEFICIARIO', 'CODICE_FISCALE_BENEFICIARIO',
#        'DES_TIPO_BENEFICIARIO', 'REGIONE_BENEFICIARIO'],
#       dtype='object')
#            CAR                                     TITOLO_MISURA  \
# count   168782  168782
# unique  772     767
# top     526     Fondo di garanzia per le piccole e medie imprese
# freq    45318   45318
# first   NaN     NaN
# last    NaN     NaN
#
#         DES_TIPO_MISURA  \
# count   168782
# unique  2
# top     Regime di aiuti
# freq    168754
# first   NaN
# last    NaN
#
#                                               BASE_GIURIDICA_NAZIONALE  \
# count   168782
# unique  580
# top     Decreto del Ministro dello sviluppo economico 19 novembre 2015
# freq    45318
# first   NaN
# last    NaN
#
#                                                            LINK_TESTO_INTEGRALE_MISURA  \
# count   168782
# unique  656
# top     http://www.sviluppoeconomico.gov.it/images/stories/normativa/DM_19_11_2015.pdf
# freq    45318
# first   NaN
# last    NaN
#
#                                    COD_UFF_GESTORE  \
# count   168782
# unique  381
# top     MCC - Direzione Interventi per lo Sviluppo
# freq    45318
# first   NaN
# last    NaN
#
#                                  DENOMINAZIONE_UFF_GESTORE  \
# count   168782
# unique  433
# top     Banca del Mezzogiorno MedioCredito Centrale S.p.A.
# freq    45318
# first   NaN
# last    NaN
#
#                                        SOGGETTO_CONCEDENTE     COR  \
# count   168782                                              168782
# unique  275                                                 168712
# top     Banca del Mezzogiorno MedioCredito Centrale S.p.A.  45531
# freq    45318                                               2
# first   NaN                                                 NaN
# last    NaN                                                 NaN
#
#                     TITOLO_PROGETTO  \
# count   168782
# unique  29128
# top     Fondo di Garanzia lg.662/96
# freq    45318
# first   NaN
# last    NaN
#
#                                   DESCRIZIONE_PROGETTO     DATA_CONCESSIONE  \
# count   168782                                          168782
# unique  23860                                           701
# top     Fondo di Garanzia lg.662/96 - Garanzia diretta  2017-12-22 00:00:00
# freq    28964                                           8717
# first   NaN                                             2009-10-29 00:00:00
# last    NaN                                             2018-01-04 00:00:00
#
#                     CUP DENOMINAZIONE_BENEFICIARIO  \
# count   168782           168782
# unique  66111            130585
# top     B58C96000000001  Politecnico di Milano
# freq    43186            62
# first   NaN              NaN
# last    NaN              NaN
#
#        CODICE_FISCALE_BENEFICIARIO DES_TIPO_BENEFICIARIO REGIONE_BENEFICIARIO
# count   168782                      168782                168782
# unique  129638                      3                     135
# top     80003950781                 PMI                   Lombardia
# freq    71                          162684                38563
# first   NaN                         NaN                   NaN
# last    NaN                         NaN                   NaN

# %% [markdown]
# Faccio JOIN dei Dataset componenti e misure

# %%
componenti_strumenti = pd.merge(componenti, strumenti, on=['COR','ID_COMPONENTE_AIUTO'])
componenti_strumenti.shape
# Out:
# (172741, 12)
#            COR ID_COMPONENTE_AIUTO COD_PROCEDIMENTO DES_PROCEDIMENTO  \
# 22283   130503  182641              1                De Minimis
# 149387  161985  178659              1                De Minimis
# 118851  74547   83875               1                De Minimis
# 19342   127430  128722              3                Esenzione
# 53659   103256  105940              1                De Minimis
#
#        COD_REGOLAMENTO  \
# 22283   CE1407/13
# 149387  CE1407/13
# 118851  CE1407/13
# 19342   CE651/2014
# 53659   CE1407/13
#
#                                                  DES_REGOLAMENTO  \
# 22283   Reg. UE 1407/2013  de minimis generale
# 149387  Reg. UE 1407/2013  de minimis generale
# 118851  Reg. UE 1407/2013  de minimis generale
# 19342   Reg. CE 651/2014 esenzione generale per categoria (GBER)
# 53659   Reg. UE 1407/2013  de minimis generale
#
#        COD_OBIETTIVO  \
# 22283   100800
# 149387  100200
# 118851  100800
# 19342   501004
# 53659   105800
#
#                                                                                   DES_OBIETTIVO  \
# 22283   PMI
# 149387  Sviluppo regionale o locale
# 118851  PMI
# 19342   Accesso delle PMI ai finanziamenti | Aiuti alle imprese in fase di avviamento (art. 22)
# 53659   Altro obiettivo di sviluppo economico o sociale non classificato
#
#        SETTORE_ATTIVITA COD_STRUMENTO  \
# 22283   S.96.0           10
# 149387  C.15.2           16
# 118851  G.47.7           10
# 19342   M.72.1           2
# 53659   M.70.2           4
#
#                                                                           DES_STRUMENTO  \
# 22283   Garanzia (se del caso con un riferimento alla decisione della Commissione (10))
# 149387  Agevolazione fiscale o esenzione fiscale
# 118851  Garanzia (se del caso con un riferimento alla decisione della Commissione (10))
# 19342   Sovvenzione/Contributo in conto interessi
# 53659   Sovvenzione/Contributo in conto interessi
#
#         ELEMENTO_DI_AIUTO
# 22283   1272.54
# 149387  200000.00
# 118851  17523.76
# 19342   99786.50
# 53659   15564.85

# %%
componenti_strumenti.loc[componenti_strumenti['COR'] == "36884"]  

componenti
# Out:
#           COR ID_COMPONENTE_AIUTO COD_PROCEDIMENTO DES_PROCEDIMENTO  \
# 128212  36884  38365               3                Esenzione
# 128213  36884  38365               3                Esenzione
#
#        COD_REGOLAMENTO  \
# 128212  CE651/2014
# 128213  CE651/2014
#
#                                                  DES_REGOLAMENTO  \
# 128212  Reg. CE 651/2014 esenzione generale per categoria (GBER)
# 128213  Reg. CE 651/2014 esenzione generale per categoria (GBER)
#
#        COD_OBIETTIVO  \
# 128212  501604
# 128213  501604
#
#                                                                                                          DES_OBIETTIVO  \
# 128212  Aiuti a favore di ricerca, sviluppo e innovazione | Ricerca industriale (art 25) [art. 25, par. 2, lettera b)]
# 128213  Aiuti a favore di ricerca, sviluppo e innovazione | Ricerca industriale (art 25) [art. 25, par. 2, lettera b)]
#
#        SETTORE_ATTIVITA COD_STRUMENTO  \
# 128212  C.20.5           9
# 128213  C.20.5           37
#
#                                     DES_STRUMENTO  ELEMENTO_DI_AIUTO
# 128212  Prestito/Anticipo rimborsabile             51580.24
# 128213  Sovvenzione/Contributo in conto interessi  230948.92

# %%
componenti_strumenti_aggr = componenti_strumenti[['COR','ELEMENTO_DI_AIUTO']]
componenti_strumenti_aggr= componenti_strumenti_aggr.groupby(['COR']).sum()
componenti_strumenti_aggr.sample(3)
# Out:
#         ELEMENTO_DI_AIUTO
# COR
# 189173  281.25
# 157308  109362.00
# 32402   6583.78

# %%
#check su aiuto con più componenti e strumentu
strumenti.loc[strumenti['COR'] == "36527"]
print(componenti_strumenti_aggr['36527'])
# Out:
#           COR ID_COMPONENTE_AIUTO COD_STRUMENTO  \
# 128192  36527  38331               9
# 128193  36527  38331               37
# 128194  36527  38332               9
# 128195  36527  38332               37
#
#                                     DES_STRUMENTO  ELEMENTO_DI_AIUTO
# 128192  Prestito/Anticipo rimborsabile             168947.17
# 128193  Sovvenzione/Contributo in conto interessi  537646.20
# 128194  Prestito/Anticipo rimborsabile             287895.52
# 128195  Sovvenzione/Contributo in conto interessi  916179.50
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# //anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20405)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20359)()
#
# KeyError: '36527'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-178-3dba9d7c2317> in <module>()
#       1 #check su aiuto con più componenti e strumentu
#       2 strumenti.loc[strumenti['COR'] == "36527"]
# ----> 3 print(componenti_strumenti_aggr['36527'])
#
# //anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2060             return self._getitem_multilevel(key)
#    2061         else:
# -> 2062             return self._getitem_column(key)
#    2063
#    2064     def _getitem_column(self, key):
#
# //anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2067         # get column
#    2068         if self.columns.is_unique:
# -> 2069             return self._get_item_cache(key)
#    2070
#    2071         # duplicate columns & possible reduce dimensionality
#
# //anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1532         res = cache.get(item)
#    1533         if res is None:
# -> 1534             values = self._data.get(item)
#    1535             res = self._box_item_values(item, values)
#    1536             cache[item] = res
#
# //anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# //anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
# -> 2395                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2396
#    2397         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20405)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20359)()
#
# KeyError: '36527'

# %%
aiuti.REGIONE_BENEFICIARIO.value_counts()
# Out:
# Lombardia                                                            38563
# Veneto                                                               15988
# Emilia-Romagna                                                       14472
# Sicilia                                                              13415
# Piemonte                                                             11180
# Campania                                                             10844
# Toscana                                                              8286
# Friuli-Venezia Giulia                                                7972
# Puglia                                                               7970
# Marche                                                               6919
# Sardegna                                                             6771
# Lazio                                                                6555
# Calabria                                                             3907
# Provincia Autonoma di Bolzano/Bozen                                  3144
# Abruzzo                                                              2885
# Umbria                                                               2815
# Provincia Autonoma di Trento                                         2638
# Liguria                                                              1315
# Basilicata                                                           1164
# Valle d'Aosta/Vallée d'Aoste                                         870
# Molise                                                               501
# Campania, Lazio                                                      47
# Lombardia, Piemonte                                                  34
# Inner London - East                                                  31
# Campania, Lombardia                                                  26
# Lombardia, Veneto                                                    22
# Emilia-Romagna, Lombardia                                            17
# Friuli-Venezia Giulia, Veneto                                        17
# Campania, Emilia-Romagna                                             16
# Emilia-Romagna, Veneto                                               13
#                                                                      ..
# Abruzzo, Lazio, Umbria                                               1
# Campania, Lombardia, Sicilia                                         1
# Basilicata, Emilia-Romagna                                           1
# Liguria, Toscana                                                     1
# Abruzzo, Basilicata                                                  1
# Campania, Piemonte, Puglia                                           1
# Basilicata, Campania, Piemonte, Puglia                               1
# Friuli-Venezia Giulia, Lombardia, Piemonte, Veneto                   1
# Emilia-Romagna, Toscana                                              1
# Molise, Veneto                                                       1
# Liguria, Provincia Autonoma di Trento                                1
# Basilicata, Emilia-Romagna, Sicilia                                  1
# Abruzzo, Umbria                                                      1
# Friuli-Venezia Giulia, Liguria                                       1
# Emilia-Romagna, Molise                                               1
# Friuli-Venezia Giulia, Sardegna                                      1
# Campania, Provincia Autonoma di Trento                               1
# Abruzzo, Campania, Lombardia                                         1
# Provincia Autonoma di Bolzano/Bozen, Provincia Autonoma di Trento    1
# Toscana, Veneto                                                      1
# Calabria, Emilia-Romagna, Lazio, Liguria                             1
# Abruzzo, Toscana                                                     1
# Lazio, Provincia Autonoma di Trento                                  1
# Basilicata, Calabria                                                 1
# Liguria, Sicilia                                                     1
# Abruzzo, Molise                                                      1
# Calabria, Campania, Lazio, Toscana                                   1
# Emilia-Romagna, Liguria                                              1
# Calabria, Campania                                                   1
# Emilia-Romagna, Sardegna                                             1
# Name: REGIONE_BENEFICIARIO, Length: 135, dtype: int64

# %%
aiuti.TITOLO_MISURA.value_counts()
# Out:
# Fondo di garanzia per le piccole e medie imprese                                                                                                                                                                                                                   45318
# Regolamento per i fondi interprofessionali per la formazione continua per la concessioni di aiuti di stato esentati ai sensi del regolamento CE n.651/2014 e in regime de minimis ai sensi del regolamento CE n.1407/2013                                          21289
# Zone Franche Urbane dell’Obiettivo Convergenza, nonché nel territorio dei comuni della provincia di Carbonia-Iglesias                                                                                                                                              19850
# Nuova Sabatini - Finanziamenti per l'acquisto di nuovi macchinari, impianti e attrezzature da parte delle piccole e medie imprese                                                                                                                                  10047
# LINEA DI INTERVENTO CONTROGARANZIE                                                                                                                                                                                                                                 9467
# Zona Franca Urbana Sisma Centro Italia                                                                                                                                                                                                                             6149
# AVVISO PUBBLICO FINALIZZATO A FAVORIRE L'ACCESSO AL CREDITO DELLE IMPRESE PER IL TRAMITE DEI CONFIDI                                                                                                                                                               3360
# MODALITA' DI APPLICAZIONE DEL REGOLAMENTO (UE) N. 1407/2013 DEL 18/12/2013 SUGLI AIUTI DE MINIMIS ALLE IMPRESE OPERANTI NEL TERRITORIO DELLA REGIONE EMILIA-ROMAGNA E DESTINATARIE DI CONTRIBUTI PUBBLICI NELL'AMBITO DELLE POLITICHE ATTIVE DEL LAVORO            2316
# FVG-INCENTIVI PER INTERVENTI DI POLITICA ATTIVA DEL LAVORO                                                                                                                                                                                                         1949
# Zona Franca dell'Emilia                                                                                                                                                                                                                                            1770
# Interventi di ingegneria finanziaria per il sostegno e lo sviluppo delle piccole e medie imprese. Aggiornamento delle disposizioni operative per l'utilizzo del Fondo regionale di Garanzia, istituito presso la finanziaria regionale Veneto Sviluppo S.p.A.,     1475
# Programma Operativo Regionale - Fondo Sociale Europeo 2014-2020 in sinergia con il Fondo Europeo di Sviluppo Regionale - Asse I Occupabilità - "L'impresa Inn-FORMATA. La formazione che innova le imprese venete". Avviso pubblico per la presentazione di pro    1424
# RER - Aiuti destinati alle imprese operanti nel territorio della Regione appartenenti ai settori esposti alla concorrenza internazionale e che sono rivolti alla prima formazione, alla riqualificazione ed aggiornamento dei loro addetti                         1193
# PIANI FORMATIVI DI AREA A FINANZIAMENTO INDIRETTO PER IMPRESE E SOGGETTI ASSIMILABILI. BANDO REGIONALE 2016-2018.                                                                                                                                                  1107
# BANDO DELLA CITTA' METROPOLITANA DI TORINO (2016-2018) "PIANI FORMATIVI DI AREA A FINANZIAMENTO INDIRETTO PER IMPRESE E SOGGETTI ASSIMILABILI"                                                                                                                     1067
# Avviso pubblico ISI 2016, Incentivi alle imprese per la realizzazione di interventi in materia di salute e sicurezza sul lavoro, in attuazione dell’articolo 11, comma 5, del decreto legislativo 9 aprile 2008, n.81                                              1018
# FVG-DPReg 226/2007-Regolamento per l’assegnazione delle risorse finanziarie ai sensi dell’ articolo 7, comma 35, della legge regionale 1/2007 a favore dei Consorzi di garanzia fidi della regione Friuli Venezia Giulia.                                          958
# POR FESR 2014-2020 – ASSE III – AZIONE III.3.B.2.3 (AZIONE 3.3.4 DELL’ACCORDO                                                                                                                                                                                      880
# Credito d'esercizio                                                                                                                                                                                                                                                871
# DM 23 GIUGNO 2016 - REGIME DI INCENTIVAZIONE DELL'ENERGIA ELETTRICA PRODOTTA DA FONTI RINNOVABILI DIVERSE DAL SOLARE FOTOVOLTAICO                                                                                                                                  823
# Contributi per sicurezza, certificazioni di prodotto e di processo, ambiente                                                                                                                                                                                       748
# POR FSE 2014 - 2020 - Approvazione dell'avviso formazione continua - Fase V                                                                                                                                                                                        724
# Bando "Impresa Sicura" - 2016                                                                                                                                                                                                                                      705
# Zona Franca della Lombardia                                                                                                                                                                                                                                        631
# RIORGANIZZAZIONE DEGLI STRUMENTI PER LE AGEVOLAZIONI CREDITIZIE E LO SVILUPPO DEL SISTEMA DELLE GARANZIE PER LE IMPRESE ARTIGIANE                                                                                                                                  603
# contributi per investimenti innovativi finalizzati all’incremento della sicurezza a favore delle micro e piccole imprese commerciali - bando 2015                                                                                                                  539
# Accrescimento delle competenze della forza lavoro - azioni di formazione continua                                                                                                                                                                                  523
# FORMAZIONE - AIUTI DE MINIMIS destinati alle imprese operanti nel territorio della Regione Toscana                                                                                                                                                                 520
# Bando Ricerca e innovazione  - edizione 2014                                                                                                                                                                                                                       469
# PAT - Aiuti alle imprese L.P. 6/99 in COMPENSAZIONE FISCALE                                                                                                                                                                                                        453
#                                                                                                                                                                                                                                                                   ...
# Fondo di rotazione per la concessione di prestiti a tasso agevolato cinema e audiovisivo                                                                                                                                                                           1
# 1.4.1. Sostegno alla creazione e al consolidamento di start up innovative ad alta intensità di apllicazione di concoscenza e alle iniziative di spinn off della ricerca                                                                                            1
# Sostegno per la costituzione e la gestione di gruppi operativi del PEI in materia di produttività e sostenibilità dell'agricoltura                                                                                                                                 1
# Sostegno di programmi di sviluppo di cluster regionali in determinate aree tecnologiche e applicative                                                                                                                                                              1
# Bando per l’accesso alle agevolazioni per progetti di ricerca industriale e sviluppo sperimentale, riservate alle imprese associate ai poli di innovazione                                                                                                         1
# VOUCHER ALLE IMPRESE START - UP  PER ASSISTENZA TECNICO-SPECIALISTICA FINALIZZATA ALLO SVILUPPO DELL'INNOVAZIONE APPROVATO CON DELIBERA N.31 DEL 12/04/2017 - AMPLIAMENTO DEL PLAFOND DISPONIBILE                                                                  1
# FVG - DPReg. 9/2008 "Interventi a favore dell'innovazione nel settore della filiera foresta-legno", di cui all'art. 16 L.R. 26/2005                                                                                                                                1
# CONTRIBUTO STRAORDINARIO PER L’EROGAZIONE DI SERVIZI RICONOSCIUTI DI PUBBLICO INTERESSE LOCALE                                                                                                                                                                     1
# concessione contributo straordinario comune di Pontebba                                                                                                                                                                                                            1
# Criteri applicativi per la concessione di contributi ad associazioni di categoria e loro cooperative (Provincia di Bolzano Legge provinciale 4/1997)                                                                                                               1
# FVG - L.R. 14/2012, ART. 2, COMMI 72, 73 e 74 - CONTRIBUTO A SOSTEGNO ONERI LA CJALDERIE SOC. COOP. SOCIALE IMPRESA SOCIALE ONLUS                                                                                                                                  1
# Promozione di nuovi mercati per l'iinovazione della P                                                                                                                                                                                                              1
# Partecipazione della Regione Lazio alle attività dell'anno 2016 della Fondazione Musica per Roma                                                                                                                                                                   1
# Attribuzione ad Aler di Milano del contributo regionale straordinario pari a 10 ml€ a sostegno degli interventi di recupero e manutenzione delle unità abitative sfitte                                                                                            1
# INTERVENTI A VALERE SULLA GESTIONE ORDINARIA                                                                                                                                                                                                                       1
# PAT Aiuti alle imprese L.P. 6/99 per CONSORZI                                                                                                                                                                                                                      1
# RV Direttiva per la realizzazione di Azioni Integrate di Coesione Territoriale (AICT) per l’inserimento e il reinserimento di soggetti svantaggiati                                                                                                                1
# RISORSE DA ATTRIBUIRE AGLI ENTI COMPETENTI IN MATERIA FORESTALE PER L'AGGIORNAMENTO E L'ADEGUAMENTO DEI PIANI DI GESTIONE FORESTALE PER L'ANNO 2017.                                                                                                               1
# APPROVAZIONE DELL’AVVISO FORMAZIONE CONTINUA – EXPO E                                                                                                                                                                                                              1
# Approvazione schema di convenzione per i servizi abitativi a canone convenzionato                                                                                                                                                                                  1
# POR FESR 2014-2020 AZIONE 3.1.1 SUB. B COMMERCIO                                                                                                                                                                                                                   1
# FVG - REALIZZAZIONE PROGETTI ATTUAZIONE TIROCINI INTEGRAZIONE LAVORATIVA PERSONE CON DISABILITA'                                                                                                                                                                   1
# Sottomisura 4.2 "Sostegno a investimenti a favore della trasformazione/ commercializzazione e/o dello sviluppo dei prodotti agricoli"                                                                                                                              1
# Fondo per la nascita e lo sviluppo delle start up innovative                                                                                                                                                                                                       1
# Criteri e modalità per l’erogazione di contributi a grandi eventi sportivi: campionati nazionali, mondiali, europei, coppe del mondo ed eventi nazionali e internazionali che si svolgeranno sul territorio lombardo                                               1
# Integrazione accordo di programma riqualificazione Zingonia                                                                                                                                                                                                        1
# FONDO DI GARANZIA PMI AGRICOLE PER IL TRAMITE DEI CONFIDI                                                                                                                                                                                                          1
# POR Calabria FESR 2014-2020: Azione 112 Sostegno per l'acquisto di servizi per l'innovazione tecnologica, strategica, organizzativa e commerciale delle imprese                                                                                                    1
# UNIONE DEI COMUNI DELLA BASSA REGGIANA CONTRIBUTO 2017 - BORSA DELTURISMO FLUVIALE DELPO                                                                                                                                                                           1
# Contributo per la commercializzazione dei prodotti turistici trentini                                                                                                                                                                                              1
# Name: TITOLO_MISURA, Length: 767, dtype: int64

# %%
componenti.DES_OBIETTIVO.value_counts()
# Out:
# PMI                                                                                                                                                                                                                                               72382
# Sviluppo regionale o locale                                                                                                                                                                                                                       30184
# Formazione                                                                                                                                                                                                                                        19652
# Aiuti alla Formazione (art.31)                                                                                                                                                                                                                    12624
# Aiuti agli investimenti e all'occupazione in favore delle PMI (art. 15)                                                                                                                                                                           10049
# Altro obiettivo di sviluppo economico o sociale non classificato                                                                                                                                                                                  6321
# Promozione dell'esportazione e dell'internazionalizzazione                                                                                                                                                                                        2710
# Ricerca, sviluppo e innovazione                                                                                                                                                                                                                   2357
# Aiuti a favore di ricerca, sviluppo e innovazione | Ricerca industriale (art 25) [art. 25, par. 2, lettera b)]                                                                                                                                    1784
# Aiuti a favore di ricerca, sviluppo e innovazione | Sviluppo sperimentale [art. 25, par. 2, lettera c)]                                                                                                                                           1725
# Sviluppo settoriale                                                                                                                                                                                                                               1650
# Aiuti alle PMI | Aiuti agli investimenti a favore delle PMI (art. 17)                                                                                                                                                                             1570
# Protezione ambientale                                                                                                                                                                                                                             1177
# Finanziamento del rischio                                                                                                                                                                                                                         1103
# Aiuti alle PMI | Aiuti per servizi di consulenza (art. 18)                                                                                                                                                                                        670
# Aiuti a favore di ricerca, sviluppo e innovazione | Aiuti all'innovazione a favore delle PMI (art. 28)                                                                                                                                            544
# Aiuti a favore di lavoratori svantaggiati e di lavoratori con disabilità | Aiuti all'assunzione di lavoratori svantaggiati sotto forma di integrazioni salariali (art. 32)                                                                        441
# Accesso delle PMI ai finanziamenti | Aiuti alle imprese in fase di avviamento (art. 22)                                                                                                                                                           416
# Aiuti alle PMI | Aiuti per la partecipazione alle fiere (art. 19)                                                                                                                                                                                 381
# Aiuti a favore dei lavoratori svantaggiati e/o dei lavoratori con disabilità                                                                                                                                                                      339
# Efficienza energetica                                                                                                                                                                                                                             310
# Aiuti per la cultura e la conservazione del patrimonio (art. 53)                                                                                                                                                                                  290
# Aiuti per la tutela dell'ambiente | Aiuti agli investimenti che consentono alle imprese di andare oltre le norme dell'Unione in materia di tutela ambientale o di innalzare il livello di tutela ambientale in assenza di tali norme (art. 36)    252
# Cultura                                                                                                                                                                                                                                           237
# Servizi d'interesse economico generale (SIEG)                                                                                                                                                                                                     205
# Aiuti a favore di ricerca, sviluppo e innovazione | Aiuti per l'innovazione dei processi e dell'organizzazione (art. 29)                                                                                                                          187
# Aiuti a favore di lavoratori svantaggiati e di lavoratori con disabilità | Aiuti all'occupazione di lavoratori con disabilita sotto forma di integrazioni salariali (art. 33)                                                                     172
# Regimi di aiuti a favore delle opere audiovisive (art. 54)                                                                                                                                                                                        166
# Infrastrutture sportive e infrastrutture ricreative multifunzionali                                                                                                                                                                               159
# Compensazione di danni arrecati da calamità naturali o da altri eventi eccezionali                                                                                                                                                                135
# Aiuti per la tutela dell'ambiente | Aiuti agli investimenti a favore di misure di efficienza energetica (art. 38)                                                                                                                                 120
# Realizzazione di un importante progetto di comune interesse europeo                                                                                                                                                                               109
# Aiuti a finalità regionale — Aiuti agli investimenti (art. 14) — Regime                                                                                                                                                                           101
# Aiuti per la tutela dell'ambiente | Aiuti agli investimenti volti a promuovere la produzione di energia da fonti rinnovabili (art. 41)                                                                                                            79
# Energia rinnovabile                                                                                                                                                                                                                               71
# Aiuti per le infrastrutture sportive e le infrastrutture ricreative multifunzionali (art. 55)                                                                                                                                                     53
# Aiuti a favore di lavoratori svantaggiati e di lavoratori con disabilità | Aiuti intesi a compensare i sovraccosti connessi all'occupazione di lavoratori con disabilita (art. 34)                                                                51
# Aiuti per la tutela dell'ambiente | Aiuti per gli studi ambientali (art. 49)                                                                                                                                                                      48
# Aiuti a favore di ricerca, sviluppo e innovazione | Ricerca fondamentale [art. 25, par. 2, lettera a)]                                                                                                                                            41
# Infrastrutture energetiche                                                                                                                                                                                                                        39
# Aiuti per le infrastrutture a banda larga (art. 52)                                                                                                                                                                                               38
# Infrastrutture a banda larga                                                                                                                                                                                                                      24
# Aiuti a favore di ricerca, sviluppo e innovazione | Aiuti ai poli d'innovazione (art. 27)                                                                                                                                                         22
# Aiuti a favore di ricerca, sviluppo e innovazione | Studi di fattibilità [art. 25, par. 2, lettera d)]                                                                                                                                            15
# Aiuti per la tutela dell'ambiente | Aiuti agli investimenti per teleriscaldamento e teleraffreddamento efficienti sotto il profilo energetico (art. 46)                                                                                           13
# Conservazione del patrimonio                                                                                                                                                                                                                      13
# Aiuti agli investimenti per le infrastrutture locali (art. 56)                                                                                                                                                                                    8
# Aiuti per la tutela dell'ambiente | Aiuti agli investimenti a favore della cogenerazione ad alto rendimento (art. 40)                                                                                                                             7
# Aiuti a favore di ricerca, sviluppo e innovazione | Aiuti agli investimenti per le infrastrutture di ricerca (art. 26)                                                                                                                            6
# Aiuti sotto forma di capitale di rischio (art. 28-29)                                                                                                                                                                                             3
# Aiuti a finalità regionale per lo sviluppo urbano (Art.16)                                                                                                                                                                                        2
# Aiuti destinati a ovviare ai danni arrecati da determinate calamità naturali (art.50)                                                                                                                                                             2
# Aiuti regionali agli investimenti e all'occupazione (art. 13) — Regime                                                                                                                                                                            2
# Aiuti per la tutela dell'ambiente | Aiuti agli investimenti per l'adeguamento anticipato a future norme dell'Unione (art. 37)                                                                                                                     1
# Aiuti a favore di lavoratori svantaggiati e di lavoratori con disabilità | Aiuti intesi a compensare i costi dell'assistenza fornita ai lavoratori svantaggiati (art. 35)                                                                         1
# Sostegno sociale a singoli consumatori                                                                                                                                                                                                            1
# Name: DES_OBIETTIVO, dtype: int64

# %%
componenti.SETTORE_ATTIVITA.value_counts()
# Out:
# G.47.7                                                                                    7397
# I.56.1                                                                                    6964
# F.43.2                                                                                    6293
# H.49.4                                                                                    5965
# F.41.2                                                                                    5252
# C.25.6                                                                                    4520
# S.96.0                                                                                    4077
# J.62.0                                                                                    3936
# I.56.3                                                                                    3840
# G.46.4                                                                                    3619
# G.46.7                                                                                    3246
# P.85.5                                                                                    3238
# I.55.1                                                                                    3080
# G.45.2                                                                                    3077
# G.47.2                                                                                    3042
# C.25.1                                                                                    2968
# F.43.3                                                                                    2935
# G.47.5                                                                                    2856
# G.47.1                                                                                    2518
# G.46.3                                                                                    2474
# C.10.7                                                                                    2151
# C.16.2                                                                                    1961
# C.31.0                                                                                    1923
# C.22.2                                                                                    1886
# C.28.2                                                                                    1838
# C.25.9                                                                                    1749
# M.71.1                                                                                    1680
# G.46.6                                                                                    1599
# G.46.1                                                                                    1521
# C.14.1                                                                                    1515
#                                                                                           ...
# C.25.1, C.25.6, F.43.2                                                                    1
# C.22.1, I.56.1                                                                            1
# S.95.0                                                                                    1
# C.32.1, C.32.3                                                                            1
# C.10.3, C.10.6, C.10.9, G.46.2, G.46.6                                                    1
# P.85.5, R.93.1, R.93.2                                                                    1
# H.52.2, M.70.2, N.77.1                                                                    1
# G.45.1, N.77.3                                                                            1
# G.45.4, G.47.5                                                                            1
# G.47.9, J.61.9                                                                            1
# A.01.6, A.02.1, C.23.6, C.23.7, F.41.2, F.42.1, F.42.2, F.42.9, F.43.1, F.43.9, H.49.4    1
# G.47.6, G.47.7, I.56.3                                                                    1
# C.27.9, N.81.3                                                                            1
# A.01.1, R.90.0                                                                            1
# F.43.3, G.47.4, G.47.7, Q.86.2, S.96.0                                                    1
# P.85.1, P.85.2, P.85.3                                                                    1
# C.10.8, G.46.3                                                                            1
# C.25.9, G.46.4                                                                            1
# C.33.1, G.46.1, G.46.4, M.72.0                                                            1
# A.01.2, M.72.0                                                                            1
# I.55.9, P.85.0                                                                            1
# G.46.0, S.96.0                                                                            1
# C.25.1, J.62.0                                                                            1
# G.47.5, G.47.8                                                                            1
# C.32.9, G.47.7                                                                            1
# F.42.1, F.42.2                                                                            1
# C.26.2, C.33.1, F.43.2, G.47.4, J.61.9, S.95.1                                            1
# M.72.1, N.82.3                                                                            1
# M.69.2, Q.88.9                                                                            1
# A.02.2, F.41.2, F.42.1                                                                    1
# Name: SETTORE_ATTIVITA, Length: 914, dtype: int64

# %%
strumenti.DES_STRUMENTO.value_counts()
# Out:
# Sovvenzione/Contributo in conto interessi                                                                                                                                                                                                         75365
# Garanzia (se del caso con un riferimento alla decisione della Commissione (10))                                                                                                                                                                   59286
# Agevolazione fiscale o esenzione fiscale                                                                                                                                                                                                          28489
# Misura per il finanziamento del rischio                                                                                                                                                                                                           4835
# Prestito/Anticipo rimborsabile                                                                                                                                                                                                                    3116
# AIUTI ALLA FORMAZIONE (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                      341
# contributo in conto capitale (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                               188
# Contributo in forma di servizio agevolato (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                  183
# riduzione aliquota tariffa elettrica (Categoria: Agevolazione fiscale o esenzione fiscale)                                                                                                                                                        109
# SOVVENZIONE (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                                105
# sovvenzione diretta attinenti a: formazione, sovraccosti connessi all'occupazione di lavoratori con disabilità - assistenza fornita ai lavoratori svantaggiati - integrazioni salariali (Categoria: Sovvenzione/Contributo in conto interessi)    70
# Incentivo all'assunzione e formazione continua (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                             68
# contributo in conto capitale  (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                              62
# contributo riduzione costi garanzia (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                        54
# contributo a fondo perduto (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                 51
# Indennizzo (Categoria: Garanzia (se del caso con un riferimento alla decisione della Commissione (10)))                                                                                                                                           50
# Contributi a fondo perduto (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                 43
# Aiuti partecipazioni a fiere (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                               35
# dote impresa incentivo all'assunzione (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                      33
# Contributo a fondo perduto (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                 32
# Contributo spese per il personale (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                          27
# Aiuto alla liquidità attraverso rinegoziazione durata e/o tasso di interesse di mutui già concessi (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                         22
# Sospensione rate dei mutui (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                 17
# Aiuto in conto servizio (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                    15
# Servizi Agevolati (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                          14
# AIUTI PARTECIPAZIONE FIERE (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                 14
# VOUCHER (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                                    13
# supporto alla costituzione, allo start up  e incubazione (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                   12
# aiuti partecipazione a fiere (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                               11
# Sovvenzione diretta (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                        11
# Voucher (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                                    11
# sovvenzione diretta in denaro (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                              11
# contributo in conto capitale start up (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                      7
# contributi a fondo perduto (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                 6
# incentivo alle imprese (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                     4
# CONTRIBUTO (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                                 4
# PREMIO FORFETTARIO (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                         4
# RIMBORSO SPESE (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                             3
# compesazione oneri servizio (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                3
# Aiuti partecipazioni fiere (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                 2
# Contributo per attività istituzionale volo sportivo (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                        2
# contributi  (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                                2
# sovvenzione per servizi di internazionalizzazione (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                          2
# Contributo a fondo perduto per parziale copertura dei costi (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                1
# contributo straordinario (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                   1
# contributo in conto capitale (Categoria: Misura per il finanziamento del rischio)                                                                                                                                                                 1
# Contributo (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                                 1
# contributo (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                                 1
# Sovvenzione (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                                1
# Moratoria su finanziamenti (Categoria: Prestito/Anticipo rimborsabile)                                                                                                                                                                            1
# sovvenzione (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                                1
# Contributo diretto di spesa (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                1
# Name: DES_STRUMENTO, dtype: int64

# %%
#ax = sns.countplot(x="REGIONE_BENEFICIARIO", data=aiuti)
#ax.set_ylabele("Regione")
#ax.set_ylabel("Frequenza Aiuti")
#ax.set_xticklabels(rotation=30)

g = sns.factorplot("REGIONE_BENEFICIARIO", data=aiuti, kind="count")
g.set_xticklabels(rotation=30)


#ax.legend(labels=labels_sleep_legend)
