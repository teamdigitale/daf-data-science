# %% [markdown]
# <img src="./img/LogoMise.png">

# %% [markdown]
# # Registro nazionale Aiuti di Stato
#
# ## Ministero dello Sviluppo economico
#
# ## Agenzia per la Coesione Territoriale
#
# ## Ministero del Lavoro e delle Politiche Sociali
#
# ## UE:
#
# Per aiuto di Stato si intende qualsiasi trasferimento di risorse pubbliche a favore di alcune imprese o produzioni che, attribuendo un vantaggio economico selettivo, falsa o minaccia di falsare la concorrenza.
#
# Tranne in alcuni casi, gli aiuti di Stato sono vietati dalla normativa europea e dal Trattato sul funzionamento dell'Unione Europea che disciplina la materia agli articoli 107 e 108.
#
# Il Dipartimento Politiche Europee, attraverso l'Ufficio per il Coordinamento in materia di aiuti di Stato, cura il coordinamento tra tutte le amministrazioni centrali e regionali per assicurare il rispetto delle norme europee.
#
#
# ### Registro:
#
# A partire dall'**agosto 2017** è stato introdotto il [**"Registro Nazionale Aiuti di Stato"**](http://www.sviluppoeconomico.gov.it/index.php/it/198-notizie-stampa/2036901-registro-nazionale-aiuti-di-stato).
#
# Il nuovo Registro è operativo dal 12 agosto 2017 sul sito http://www.rna.gov.it
#
# [Decreto direttoriale 28 luglio 2017 – Tracciati relativi ai dati e informazioni da trasmettere al Registro nazionale Aiuti e modalità tecniche e protocolli di comunicazione per l'interoperabilità con i sistemi informatici](http://www.sviluppoeconomico.gov.it/index.php/it/component/organigram/?view=structure&id=567)
#
# Il registro Nazionale Aiuti di Stato è il **primo strumento informatizzato attivato da un Paese membro** per il **controllo** e la pubblicità degli aiuti di Stato, Il Registro permette di verificare che le agevolazioni pubbliche siano concesse nel rispetto delle disposizioni previste dalla normativa comunitaria, specie al fine di evitare il cumulo dei benefici e, nel caso degli aiuti de minimis, il superamento del massimale di aiuto concedibile imposto dall’Unione europea.
#
# Lo strumento consente, inoltre, a tutte le amministrazioni pubbliche titolari di misure di aiuto di effettuare i controlli amministrativi necessari con modalità automatiche, grazie al rilascio di specifiche “visure” che recano l’elencazione dei benefici di cui l’impresa ha già goduto negli ultimi esercizi evitando, in tal modo, duplicazioni di interventi da parte di diverse amministrazioni e scongiurando il superamento dei limiti massimi concedibili a ciascuna impresa imposti dalla disciplina UE.
#
# Il Registro è già interconnesso con molti sistemi informativi fra i quali il Registro delle imprese, per l’acquisizione di informazioni relative ai soggetti beneficiari degli aiuti e con i registri SIAN  e SIPA sui quali continueranno ad essere inseriti gli elementi relativi agli aiuti relativi ai settori dell’agricoltura e della pesca.
#
# Vedi: [Divisione III - Monitoraggio e controllo degli interventi, servizi informatici](http://www.sviluppoeconomico.gov.it/index.php/it/component/organigram/?view=structure&id=567)
#
# Correlati:
#
# * ### [FSE Fondo Sociale Europeo](http://ec.europa.eu/esf/main.jsp?catId=35&langId=it)
#
# * ### [FESR Fondo Europeo di Sviluppo Regionale](http://ec.europa.eu/regional_policy/index.cfm/it/funding/erdf/)
#
#
#
#
# ## Spunti di analisi
#
# - Sarebbe interessante avere accesso ai dati dell'Agenzia delle Entrate e misurare l'efficacia dell'aiuto ricevuto dall'ente.
#
#
# ## Collaborazioni:
#
# - Base dati BDU del MEF
#
#
# ## Dati
#
# NOTA: tutti i dataset utilizzati in quesya analisi sono accessibili e di pubblico dominio.
#
# * [DATASET](https://www.rna.gov.it/RegistroNazionaleTrasparenza/faces/pages/OpenDataAiuti.jspx)  (Data elaborazione 30/12/2017)
#
# Dal 10-2009 ad oggi, il file indica il nome del mese. Per alcuni mesi non c'è il relativo file, alcuni buchi.
#
# Licenza:  ["IODL: Italian Open Data License v2.0".](http://www.dati.gov.it/iodl/2.0/)
#
# I file sono nominati OpenData_yyyy_mm.xml con mm e yyyy coincidenti rispettivamente con il mese e l’anno di inizio della misura per gli Open Data delle Misure di Aiuto
#
# Caratteristiche:
# * Attuali: il Registro Nazionale degli aiuti di Stato è stato approvato solo ad Agosto 2017
# * Granularità elevata
# * Probabilmente non ancora mai usati in dashboard istituzionali
# * Formato XML
# * Profondità temporale: dal 2010 - 1 file XML per mese
#
#
# * [METADATI originali in PDF](https://www.rna.gov.it/cs/groups/public/documents/document/y2mt/mdax/~edisp/cl_wcc-001577.pdf)
#
# Ho creato sotto la cartella D_general in Data  un dizionario dei metadati in un csv per ogni dimensione:
#  -  [Metadati Aiuti](data/D_general/MetadatiAiuti.csv)
#
#  -  [Codici ATECO](https://dati.inail.it/opendata/elements/SettoreAttivitaEconomica)
#
# ### CUP
# http://opencup.gov.it/web/opencup/dettaglio-opendata-complessivo
#
# ### Dateset di appoggio:
#
# * Elenco comuni istat

# %%
#IPython setting

import pandas as pd
import numpy as np
import json 
import os
import re
import seaborn as sns
import matplotlib as mpl 
import matplotlib.cm as cm 
import matplotlib.pyplot as plt 
import matplotlib.style as style
import seaborn as sns 
# %matplotlib inline 

from IPython.display import display, HTML
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all" #setta l'esecuzione di più statement in unica cella
pd.set_option('display.max_colwidth', -1) 
pd.set_option('display.width', 5000) 
pd.set_option('display.max_columns', 60) 

# Set up formatting so larger numbers aren't displayed in scientific notation (h/t @thecapacity)
pd.set_option('display.float_format', lambda x: '%.3f' % x)


sns.set_context("notebook")
sns.set()
sns.set_style("darkgrid")
sns.set_palette(sns.color_palette("Set2", 10))

style.use('fivethirtyeight')

# %%
metadati = pd.read_csv("data/general/MetadatiAiuti.csv", sep=';', header=0)
metadati
# Out:
#              Sezione                        Campo                                                                                                                                                                                                                                                      Significato
# 0   AIUTO             CAR                          Codice identificativo della Misura assegnato dal Registro
# 1   AIUTO             TITOLO_MISURA                Titolo della Misura di Aiuto
# 2   AIUTO             DES_TIPO_MISURA              Tipologia di misura (ovvero Regime di aiuti o Aiuto ad hoc)
# 3   AIUTO             COD_CE_MISURA                Eventuale Identificativo della Misura CE come rilasciato dal sistema SANI
# 4   AIUTO             BASE_GIURIDICA_NAZIONALE     Denominazione estesa della norma che istituisce la misura
# 5   AIUTO             LINK_TESTO_INTEGRALE_MISUR   Link al testo integrale della misura
# 6   AIUTO             COD_UFF_GESTORE              Codice nel Registro dell'Ufficio Gestore che gestisce l'Aiuto Individuale
# 7   AIUTO             DENOMINAZIONE_UFF_GESTORE    Denominazione dell'Ufficio Gestore che gestisce l'Aiuto Individuale
# 8   AIUTO             SOGGETTO_CONCEDENTE          Soggetto Concedente ai sensi del Regolamento che disciplina il funzionamento del Registro
# 9   AIUTO             COR                          Codice univoco rilasciato dal Registro in esito alla registrazione dell'Aiuto individuale; il codice identifica univocamente la registrazione di un Aiuto nel Registro Nazionale Aiuti ("Codice Concessione RNA")
# 10  AIUTO             TITOLO_PROGETTO              Titolo del progetto per la realizzazione del quale  destinata la concessione dell'Aiuto
# 11  AIUTO             DESCRIZIONE_PROGETTO         Descrizione sintetica del progetto per la realizzazione del quale  destinata la concessione dell'Aiuto
# 12  AIUTO             LINK_TRASPARENZA_NAZIONALE   Collegamento con la sezione trasparenza del sito web predisposto ai fini del rispetto degli obblighi di trasparenza previsti dalla normativa nazionale
# 13  AIUTO             DATA_CONCESSIONE             Data in cui al beneficiario  accordato, a norma del regime giuridico nazionale applicabile, il diritto di ricevere l'Aiuto
# 14  AIUTO             CUP                          Codice Unico di Progetto d'investimento pubblico (CUP) rilasciato dal Sistema CUP del PCM-DIPE
# 15  AIUTO             ATTO_CONCESSIONE             Dati Identificativi dell'atto di concessione Aiuto (tipo numero e data dell'atto)
# 16  AIUTO             LINK_ATTO_CONCESSIONE        Link all'atto di concessione
# 17  AIUTO             DENOMINAZIONE_BENEFICIARIO   Codice fiscale che identifica univocamente il soggetto beneficiario con sede in Italia, oppure, VAT identification number UE valido nel sistema VIES in caso di soggetto estero senza sede secondaria in Italia (e non registrata presso in Registro delle
# 18  AIUTO             CODICE_FISCALE_BENEFICIARIO  Ragione sociale/Denominazione del soggetto beneficiario
# 19  AIUTO             DES_TIPO_BENEFICIARIO        Dimensione aziendale del soggetto beneficiario come definita dalla Raccomandazione 2003/361/CE del 6 maggio 2003
# 20  AIUTO             REGIONE_BENEFICIARIO         Regione di localizzazione del soggetto beneficiario
# 21  COMPONENTE_AIUTO  ID_COMPONENTE_AIUTO          Identificativo, nel Registro della componente id aiuto
# 22  COMPONENTE_AIUTO  COD_PROCEDIMENTO             Codice nel Registro del procedimento in applicazione del quale vengono concessi gli aiuti
# 23  COMPONENTE_AIUTO  DES_PROCEDIMENTO             Descrizione del procedimento in applicazione del quale vengono concessi gli aiuti (ex notifica, esenzione, de minimis)
# 24  COMPONENTE_AIUTO  COD_REGOLAMENTO              Codice nel Registro del Regolamento in applicazione del quale vengono concessi gli aiuti
# 25  COMPONENTE_AIUTO  DES_REGOLAMENTO              Regolamento in applicazione del quale vengono concessi gli aiuti
# 26  COMPONENTE_AIUTO  COD_OBIETTIVO                Codice nel Registro dell'obiettivo
# 27  COMPONENTE_AIUTO  DES_OBIETTIVO                Descrizione dell'obiettivo
# 28  COMPONENTE_AIUTO  SOGGETTO_INTERMEDIARIO       Descrizione dell'istituzione finanziaria, a prescindere dalla sua forma e dal suo assetto proprietario; da indicare solo in caso di concessione di Aiuti a finalitˆ regionale per lo sviluppo urbano (Art.16 Reg.651/2014) e Aiuti al finanziamento del rischio
# 29  COMPONENTE_AIUTO  ENTITA_DELEGATA              Descrizione dell'Entitˆ intermediaria, in caso di concessione di Aiuti a finalitˆ regionale per lo sviluppo urbano (Art.16 Reg.651/2014) e Aiuti al finanziamento del rischio (Art.21 Reg.651/2014)
# 30  COMPONENTE_AIUTO  SETTORE_ATTIVITA             Attivitˆ interessate dalla componente di Aiuto seconto la codifica NACE
# 31  STRUMENTO         COD_STRUMENTO                Codice nel Registro dello strumento ovvero della forma attraverso la quale gli aiuti possono essere concessi ai soggetti beneficiari
# 32  STRUMENTO         DES_STRUMENTO                Identifica le forme attraverso la quale gli aiuti possono essere concessi ai soggetti beneficiari
# 33  STRUMENTO         ELEMENTO_DI_AIUTO            Importo dell'aiuto (espresso in Û) concesso per la componente di aiuto e per ciascun tipo di strumento di Aiuto se fosse stato erogato al beneficiario sotto forma di sovvenzione, al lordo di qualsiasi imposta o altro onere

# %% [markdown]
# ## Campi di particolare interesse:
#
# ### Codice fiscale beneficiario
#
# Nel Registro Imprese, a livello nazionale, ogni impresa è univocamente identificata da un Codice Fiscale e da una partita IVA. Codice Fiscale e partita IVA, tranne eccezioni, sono sempre coincidenti per le società, e sempre differenti per le imprese individuali.
# Il numero Registro Imprese, ovvero il numero di iscrizione attribuito dal Registro Imprese della Camera di Commercio, è il Codice Fiscale; nel caso si tratti di impresa individuale sarà il Codice Fiscale del titolare.
#
# Tale dato è contenuto nella Visura camerale, che riporta i dati legali dell’impresa, censiti presso il Registro Imprese della Camera di Commercio competente per territorio (ovvero quello nel quale è ubicata la sede legale dell’impresa).
#
# Fonte: http://www.registroimprese.it/codice-fiscale-p.iva-rea
#
# ### CUP
# Il Codice Unico di Progetto (CUP) è il codice che identifica un progetto d'investimento pubblico ed è lo strumento cardine per il funzionamento del Sistema di Monitoraggio degli Investimenti Pubblici (MIP).
#
# La sua richiesta è obbligatoria per tutta la "spesa per lo sviluppo", inclusi i progetti realizzati utilizzando risorse provenienti da bilanci di enti pubblici o di società partecipate, direttamente o indirettamente, da capitale pubblico e quelli realizzati con operazioni di finanza di progetto, "pura" o "assistita", o comunque che coinvolgono il patrimonio pubblico, anche se realizzati con risorse private. I progetti rientranti nella spesa per lo sviluppo possono consistere in:
# - lavori pubblici (come individuati dalla legge 109/1994 e successive modificazioni e integrazioni),
# - incentivi a favore di attività produttive,
# - contributi a favore di soggetti privati, diversi da attività produttive,
# - acquisto o realizzazione di servizi (ad esempio corsi di formazione e progetti di ricerca),
# - acquisto di beni finalizzato allo sviluppo,
# - sottoscrizione iniziale o aumento di capitale sociale (compresi spin off), fondi di rischio o di garanzia.
# In particolare, la richiesta del CUP è obbligatoria per gli interventi rientranti nel Quadro Strategico Nazionale (QSN), nella programmazione dei Fondi Europei, quali ad esempio Fondi strutturali e di investimento europei (ESIF) 2014-2020 e nel Fondo di Sviluppo e Coesione.
#
# Il CUP è anche uno dei principali strumenti adottati per garantire la trasparenza e la tracciabilità dei flussi finanziari, per prevenire eventuali infiltrazioni criminali e, in particolare, per il Monitoraggio Finanziario delle Grandi Opere, MGO.

# %%
#metadati_cup = pd.read_csv("data/D_cup/MetadatiCUP.csv", sep=';', header=0)
#metadati_cup
cup = pd.read_csv("data/cup/CUP.csv", sep='|', header=0, error_bad_lines=False)
cup.shape()

# %% [markdown]
# ## Data preparation:
#
# ### XML to JSON

# %% [markdown]
# I dati rilasciati dal MISE sono in format XML. Per poterli agevolmente trattare converto ogni file XML in formato JSON tramite la libreria [xmltodict]("https://github.com/martinblech/xmltodict").
#
# Per questioni di spazio sul repo github non sono stati caricati i file nativi in formato XML ma solo i JSON finali.
#
#
# Il codice presente qui di seguito è stato usato per creare la trasformazione.

# %%
#https://github.com/martinblech/xmltodict
import xmltodict

fileDir = os.path.dirname(os.path.realpath('__file__'))
tot_file = 0
listing = os.listdir(fileDir)   

for infile in listing:
    
    if infile.endswith((".xml")):
        tot_file+=1
        name = os.path.splitext(infile)[0]
        filename = os.path.join(fileDir, infile)
        print (filename)
        with open(filename, 'r') as f:
            xmlString = f.read()
            jsonString = json.dumps(xmltodict.parse(xmlString), indent=4) #check indent
        
        with open("./output/"+name + ".json", 'w') as f:
            f.write(jsonString) 

print ("Tot file: "+str(tot_file))

# %% [markdown]
# ### Struttura dataset:

# %% [markdown]
# Ogni AIUTO è composto da delle informazioni di base e da uno o più COMPONENTI di aiuto.
#
# Ogni componente d'aiuto può essere composto da più STRUMENTI
#
# Suddividere le info in tre dataframe:
#
# 1- Dati anagrafici dell'**aiuto** --> data_aiuto
#
# 2- **Componenti** dell'aiuto --> data_componenti con chiave campo "COR"
#
# 3- **Strumento/i** del Componente --> data_
#
# I tre dataframe sono in relazione tramite il campo **COR**, ***ID_COMPONENTE_AIUTO** e
#
# **COR:**
# Codice univoco rilasciato dal Registro in esito alla registrazione dell'Aiuto individuale; il codice identifica univocamente la registrazione di un Aiuto nel Registro Nazionale Aiuti (“Codice Concessione RNA”)

# %% [markdown]
# #### Elenco metadati

# %%
good_infos_aiuto = [
    "CAR",
    "TITOLO_MISURA",
    "DES_TIPO_MISURA",
    "BASE_GIURIDICA_NAZIONALE",
    "LINK_TESTO_INTEGRALE_MISURA",
    "COD_UFF_GESTORE",
    "DENOMINAZIONE_UFF_GESTORE",
    "SOGGETTO_CONCEDENTE",
    "COR",
    "TITOLO_PROGETTO",
    "DESCRIZIONE_PROGETTO",
    "DATA_CONCESSIONE",
    "CUP", #Il Codice Unico di Progetto (CUP) è il codice che identifica un progetto d'investimento pubblico ed è lo strumento cardine per il funzionamento del Sistema di Monitoraggio degli Investimenti Pubblici (MIP).
     #"ATTO_CONCESSIONE",#non sempre presente, al momento non gestito
    "DENOMINAZIONE_BENEFICIARIO",
    "CODICE_FISCALE_BENEFICIARIO",
    "DES_TIPO_BENEFICIARIO",
    "REGIONE_BENEFICIARIO"
    
]

good_infos_componente = [
    "ID_COMPONENTE_AIUTO",
    "COD_PROCEDIMENTO",
    "DES_PROCEDIMENTO",
    "COD_REGOLAMENTO",
    "DES_REGOLAMENTO",
    "COD_OBIETTIVO",
    "DES_OBIETTIVO",
    "SETTORE_ATTIVITA"
]

df_infos_componente = [
    "COR", 
    "ID_COMPONENTE_AIUTO",
    "COD_PROCEDIMENTO",
    "DES_PROCEDIMENTO",
    "COD_REGOLAMENTO",
    "DES_REGOLAMENTO",
    "COD_OBIETTIVO",
    "DES_OBIETTIVO",
    "SETTORE_ATTIVITA"
]


good_infos_strumento = [
    "COD_STRUMENTO",
    "DES_STRUMENTO",
    "ELEMENTO_DI_AIUTO"
]    


df_infos_strumento = [
    "COR", 
    "ID_COMPONENTE_AIUTO", #id componente aiuto
    "COD_STRUMENTO",
    "DES_STRUMENTO",
    "ELEMENTO_DI_AIUTO"
]

# %% [markdown]
# Al fine di rendere più agevole e scalabile l'analisi si è deciso di:
#
# - caricare tutti i file in formato json presenti e trasformati precedentemente
# - creare tre strutture dati che identificano le tre macro sezioni degli aiuti:
#
#
# Ogni AIUTO è composto da delle informazioni di base e da uno o più COMPONENTI di aiuto.
#
# Ogni componente d'aiuto può essere composto da più STRUMENTI.
#
#
# Le info verranno salvate in tre differenti dataframe che sarà poi possibile unire tramite join:
#
# 1- **AIUTI**: dati anagrafici dell'**aiuto** --> data_aiuto
#
# 2- **COMPONENTI**: dati anagrafici dell'aiuto --> data_componenti
#
# 3- **STRUMENTI**: dati anagrafici strumenti del Componente --> data_strumenti
#
# I tre dataframe sono in relazione tramite il campo **COR** e **ID_COMPONENTE_AIUTO**
#
# **COR:**
# Codice univoco rilasciato dal Registro in esito alla registrazione dell'Aiuto individuale; il codice identifica univocamente la registrazione di un Aiuto nel Registro Nazionale Aiuti (“Codice Concessione RNA”)
#
# **ID_COMPONENTE_AIUTO**: identificativo del componente dell'aiuto

# %% [markdown]
# Ciclo tra tutti i file prodotti in json per caricarmi un unico dataframe per ogni sezione (Aiuto, Componente, Strumento) du tutti i file che ho scaricato dal sito del MISE.

# %%
#Crea sezione componente
def list_componente(cor_id, componente):
    comp=[]
    comp.append(cor_id)
    for c in good_infos_componente:
        comp.append(componente[c])
    return comp  

#Crea sezione strumento
def list_strumento(cor_id, comp_id, strumento):
    strum=[]
    strum.append(cor_id)
    strum.append(comp_id)
    for c in good_infos_strumento:
        strum.append(strumento[c])
    return strum

# %%
#final list with all AIUTI
data_aiuto = []
#final list with all COMPONENTI
data_componenti = []
#final list with all STRUMENTI
data_strumenti = []

fileDir = os.path.dirname(os.path.realpath('__file__'))
output_folder = os.path.join(fileDir, 'data/aiuti/')
listing = os.listdir(output_folder)   
#loop in json files from folder
for infile in listing: 
    if infile.endswith((".json")):
        filename = os.path.join(fileDir, infile)
        #List Files
        print (filename)
        filename = os.path.join(output_folder, infile)
        filehandle = open(filename)
        
        data = json.load(filehandle)    

        aiuto = data["LISTA_AIUTI"]["AIUTO"]
       
        if isinstance(aiuto,list):
            for row in aiuto:
                cor_id = row["COR"]
                #CREA AIUTO
                selected_row = []
                for a in good_infos_aiuto:
                    selected_row.append(row[a])
                    #CREA COMPONENTI: nuova lista di liste per i componenti e strumenti    
                componente = row["COMPONENTI_AIUTO"]["COMPONENTE_AIUTO"]
                    #check if it's a list or dictionary
                if isinstance(componente,list):
                    for i in componente:
                        comp_id = i["ID_COMPONENTE_AIUTO"] #serve per poi la chiave dello strumento
                        data_componenti.append(list_componente(cor_id,i)) 
                        #CREA STRUMENTO
                        strumento_0 = i["STRUMENTO_AIUTO"]
                        if strumento_0 is not None:
                            strumento = strumento_0["STRUMENTO_AIUTO"]
                            if isinstance(strumento,list):
                                for s in strumento:
                                    data_strumenti.append(list_strumento(cor_id, comp_id, s))    
                            if isinstance(strumento,dict):
                                data_strumenti.append(list_strumento(cor_id, comp_id, strumento))

                    #list, dict
                if isinstance(componente,dict):
                    comp_id = componente["ID_COMPONENTE_AIUTO"] 
                    data_componenti.append(list_componente(cor_id,componente)) 
                    #CREA STRUMENTO
                    strumento_0 = componente["STRUMENTO_AIUTO"]
                    if strumento_0 is not None:
                        strumento = strumento_0["STRUMENTO_AIUTO"]
                        #list, dict,list
                        if isinstance(strumento,list):
                            for s in strumento:
                                data_strumenti.append(list_strumento(cor_id, comp_id, s))
                                #list, dict,dict
                        if isinstance(strumento,dict):
                            data_strumenti.append(list_strumento(cor_id, comp_id, strumento))
                           
                        #add aiuto
                data_aiuto.append(selected_row)
                    
        # se c'è un unico aiuto è dict non lista
        if isinstance(aiuto,dict):
            cor_id = aiuto["COR"]
            selected_row = []
            componenti = []
            for a in good_infos_aiuto:
                selected_row.append(aiuto[a])
            componente = row["COMPONENTI_AIUTO"]["COMPONENTE_AIUTO"]

                #check if it's a list or dictionary
            if isinstance(componente,list):
                for i in componente:
                    comp_id = i["ID_COMPONENTE_AIUTO"] #serve per poi la chiave dello strumento
                    data_componenti.append(list_componente(cor_id,i)) 
                    #CREA STRUMENTI
                    strumento_0 = componente["STRUMENTO_AIUTO"]
                    if strumento_0 is not None:
                        strumento = strumento_0["STRUMENTO_AIUTO"]
                        if isinstance(strumento,list):
                            for s in strumento:
                                data_strumenti.append(list_strumento(cor_id, comp_id, s))
                        if isinstance(strumento,dict):
                                data_strumenti.append(list_strumento(cor_id, comp_id, strumento))
            #DICT
            if isinstance(componente,dict):
                comp_id = componente["ID_COMPONENTE_AIUTO"] 
                data_componenti.append(list_componente(cor_id,componente)) 
                strumento_0 = componente["STRUMENTO_AIUTO"]
                if strumento_0 is not None:
                    strumento = strumento_0["STRUMENTO_AIUTO"]
                    if isinstance(strumento,list):
                        for s in strumento:
                            data_strumenti.append(list_strumento(cor_id, comp_id, s))
                    if isinstance(strumento,dict):
                        data_strumenti.append(list_strumento(cor_id, comp_id, strumento))
                #Add aiuto
        data_aiuto.append(selected_row)
    filehandle.close()

# %% [markdown]
# # Assemblo tutti gli AIUTI in unico dataframe

# %%
aiuti = pd.DataFrame(data_aiuto, columns=good_infos_aiuto)

#CAST "DATA_CONCESSIONE" con datetime 
#il formato del time zone è sbagliato format='%Y-%m-%d%z' - es: 2016-08-05+02:00
#aiuti['DATA_CONCESSIONE'] =  pd.to_datetime(aiuti['DATA_CONCESSIONE'], format='%Y-%m-%d%z'))
aiuti['DATA_CONCESSIONE'] = aiuti['DATA_CONCESSIONE'].astype('str')
aiuti['DATA_CONCESSIONE'] = aiuti.DATA_CONCESSIONE.str[:10]
aiuti['DATA_CONCESSIONE'] = pd.to_datetime(aiuti['DATA_CONCESSIONE'], format='%Y-%m-%d')
#Aggiungo anno per comodità
aiuti['Y'] = aiuti['DATA_CONCESSIONE'].dt.year

# %%
aiuti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168782 entries, 0 to 168781
# Data columns (total 18 columns):
# CAR                            168782 non-null object
# TITOLO_MISURA                  168782 non-null object
# DES_TIPO_MISURA                168782 non-null object
# BASE_GIURIDICA_NAZIONALE       168782 non-null object
# LINK_TESTO_INTEGRALE_MISURA    168782 non-null object
# COD_UFF_GESTORE                168782 non-null object
# DENOMINAZIONE_UFF_GESTORE      168782 non-null object
# SOGGETTO_CONCEDENTE            168782 non-null object
# COR                            168782 non-null object
# TITOLO_PROGETTO                168782 non-null object
# DESCRIZIONE_PROGETTO           168782 non-null object
# DATA_CONCESSIONE               168782 non-null datetime64[ns]
# CUP                            168782 non-null object
# DENOMINAZIONE_BENEFICIARIO     168782 non-null object
# CODICE_FISCALE_BENEFICIARIO    168782 non-null object
# DES_TIPO_BENEFICIARIO          168782 non-null object
# REGIONE_BENEFICIARIO           168782 non-null object
# Y                              168782 non-null int64
# dtypes: datetime64[ns](1), int64(1), object(16)
# memory usage: 23.2+ MB

# %%
aiuti.Y.value_counts()
# Out:
# 2017    136402
# 2014    23204
# 2016    6151
# 2015    2155
# 2018    634
# 2013    92
# 2010    48
# 2011    47
# 2012    35
# 2009    14
# Name: Y, dtype: int64

# %%
aiuti.DENOMINAZIONE_UFF_GESTORE.value_counts()
# Out:
# Banca del Mezzogiorno MedioCredito Centrale S.p.A.                                                                                            45318
# DGIAI Divisione X - Interventi per il sostegno all'internazionalizzazione e all'innovazione delle imprese e per lo sviluppo di aree urbane    28400
# DGIAI Divisione VI - lncentivi fiscali e accesso al credito                                                                                   10054
# UO COMPETITIVITA', SVILUPPO E ACCESSO AL CREDITO DELLE IMPRESE                                                                                9837
# Fondimpresa                                                                                                                                   9006
# STR ACCESSO AL CREDITO                                                                                                                        3993
# SERVIZIO PROGRAMMAZIONE DELLE POLITICHE DELL'ISTRUZIONE, DELLA FORMAZIONE, DEL LAVORO E DELLA CONOSCENZA                                      3499
# Formazienda                                                                                                                                   3065
# UFFICIO BANDI                                                                                                                                 2590
# PO INTERVENTI DI POLITICA ATTIVA DEL LAVORO                                                                                                   2080
# Fonder                                                                                                                                        2071
# Fondo For.te                                                                                                                                  2007
# PROGRAMMAZIONE FSE                                                                                                                            1825
# VENETO SVILUPPO SPA (00854750270)                                                                                                             1788
# Ripartizione Economia                                                                                                                         1695
# Fonarcom                                                                                                                                      1503
# PROMOZIONE                                                                                                                                    1264
# UO PROMOZIONE DELL' ATTRATTIVITA' E SOSTEGNO DEL SETTORE TURISTICO                                                                            1187
# FORMAZIONE OCCUPATI                                                                                                                           1107
# PROGRAMMAZIONE ATTIVITA' FORMATIVE PER LAVORATORI OCCUPATI                                                                                    1067
# ForAgri                                                                                                                                       1031
# C.R.I.A.S. - Cassa Regionale per il Credito alle Imprese Siciliane                                                                            937
# Confidi Trentino Imprese                                                                                                                      887
# GESTORE SERVIZI ENERGETICI - GSE SPA                                                                                                          823
# STR OCCUPAZIONE E OCCUPABILITA'                                                                                                               811
# FVG - CATA ARTIGIANATO FRIULI VENEZIA GIULIA S.R.L.                                                                                           658
# U. O. Contributi alle imprese e Rendicontazione                                                                                               619
# Fondartigianato                                                                                                                               606
# STR RICERCA, INNOVAZIONE E TRASFERIMENTO TECNOLOGICO                                                                                          596
# Fondo Banche Assicurazioni                                                                                                                    585
#                                                                                                                                              ...
# servizio nuova impresa                                                                                                                        1
# STR PROMOZIONE DI POLITICHE PER LA COMPETITIVITÀ, ATTUAZIONE PRS                                                                              1
# Ufficio frutti-viticoltura                                                                                                                    1
# Struttura s.r.l.                                                                                                                              1
# Servizio Affari Generali                                                                                                                      1
# SERVIZIO TECNICO                                                                                                                              1
# SVILUPPO ARTIGIANO SOCIETA'  REGIONALE CONSORTILE COOPERATIVA DI GARANZIA COLLETTIVA FIDI                                                     1
# FOGALCO Soc. Coop. - Fondo di Garanzia al Commercio Turismo e Servizi - Società Cooperativa -                                                 1
# Finlombarda SpA - Area Credito e Pre-Contenzioso                                                                                              1
# Area Agricoltura                                                                                                                              1
# Sarda Fidi SC                                                                                                                                 1
# FIDI NORDEST soc coop (EX ARTIGIANFIDI VICENZA soc.coop.)                                                                                     1
# STR PATRIMONIO CULTURALE E IMPRESE CULTURALI                                                                                                  1
# Servizio Sostegno alle imprese                                                                                                                1
# UFFICIO SEGRETERIA                                                                                                                            1
# SARDAFIDI SCPA                                                                                                                                1
# CONFIDI RATING ITALIA                                                                                                                         1
# PF Competitività e multifunzionalità dell'impresa agricola e SDA di Fermo - Ascoli Piceno                                                     1
# CONFIDARE SCPA (EX CONFARTIGIANATO FIDI PIEMONTE E NORD OVEST S.C.P.A.)                                                                       1
# COOPERATIVA ARTIGIANA DI GARANZIA "G.KUFERLE" A R.L.                                                                                          1
# ARTIGIANFIDI PADOVA SOCIETA' COOPERATIVA                                                                                                      1
# Ufficio Ispettivo                                                                                                                             1
# ASSICOMFIDI                                                                                                                                   1
# Finlombarda Ufficio Minibond                                                                                                                  1
# ASCOM FIDI Soc. Coop. Collettiva                                                                                                              1
# Settore Servizi alle imprese agricole e florovivaismo                                                                                         1
# POLITICHE E SERVIZI PER IL LAVORO                                                                                                             1
# Settore Affari Giuridici                                                                                                                      1
# Regione Piemonte - Sistema Universitario, Diritto allo Studio, Ricerca e Innovazione                                                          1
# STR SEMPLIFICAZIONE E DIGITALIZZAZIONE                                                                                                        1
# Name: DENOMINAZIONE_UFF_GESTORE, Length: 433, dtype: int64

# %%
aiuti.SOGGETTO_CONCEDENTE.value_counts()
# Out:
# Banca del Mezzogiorno MedioCredito Centrale S.p.A.                                                                                                           45318
# Ministero dello sviluppo economico - Direzione generale per gli incentivi alle imprese                                                                       38804
# Regione Lombardia - DG Sviluppo economico                                                                                                                    16653
# FONDIMPRESA                                                                                                                                                  9006
# Regione Emilia-Romagna - Giunta Regionale - Direzione Generale Economia della Conoscenza, del Lavoro e dell'Impresa                                          4325
# Formazienda                                                                                                                                                  3065
# REGIONE AUTONOMA FRIULI VENEZIA GIULIA - DIREZIONE CENTRALE LAVORO, FORMAZIONE, ISTRUZIONE, PARI OPPORTUNITA', POLITICHE GIOVANILI, RICERCA E UNIVERSITA'    2714
# UNIONCAMERE LOMBARDIA                                                                                                                                        2672
# FONDER                                                                                                                                                       2071
# FONDO FOR.TE                                                                                                                                                 2007
# Regione Veneto - Direzione Formazione e Istruzione                                                                                                           1825
# Veneto Sviluppo Spa                                                                                                                                          1790
# Provincia Autonoma di Bolzano - Ripartizione Economia                                                                                                        1706
# FonARCom                                                                                                                                                     1503
# Camera di Commercio Industria Artigianato e Agricoltura di Cuneo                                                                                             1224
# INAIL - Direzione Centrale Prevenzione                                                                                                                       1182
# AOO Regione Toscana Giunta                                                                                                                                   1146
# REGIONE PIEMONTE - DIREZIONE COESIONE SOCIALE                                                                                                                1107
# CITTA' METROPOLITANA DI TORINO                                                                                                                               1067
# ForAgri                                                                                                                                                      1031
# REGIONE SICILIANA - DIPARTIMENTO ATTIVITA' PRODUTTIVE                                                                                                        969
# Regione Lombardia - DG Università Ricerca e Open Innovation                                                                                                  908
# CONFIDI TRENTINO IMPRESE - SOCIETA' COOPERATIVA                                                                                                              887
# GESTORE SERVIZI ENERGETICI                                                                                                                                   823
# Regione Lombardia - DG Istruzione Formazione Lavoro                                                                                                          811
# Provincia Autonoma di Trento                                                                                                                                 748
# CATA ARTIGIANATO FRIULI VENEZIA GIULIA S.R.L.                                                                                                                658
# Camera di Commercio, Industria, Artigianato e Agricoltura di Firenze                                                                                         619
# Regione autonoma Friuli Venezia Giulia - Direzione centrale attività produttive, turismo e cooperazione                                                      608
# Fondo artigianato formazione                                                                                                                                 606
#                                                                                                                                                             ...
# UNIONE MONTANA APPENNINO PARMA EST                                                                                                                           2
# Regione Veneto - Direzione Ricerca Innovazione ed Energia                                                                                                    2
# FidImpresa MARCHE                                                                                                                                            2
# COMUNE DI TRIESTE                                                                                                                                            2
# SARDAFIDI SCPA                                                                                                                                               2
# Comune di Borgo Valsugana                                                                                                                                    2
# COFIMER S.C.P.A.                                                                                                                                             2
# Fondoprofessioni                                                                                                                                             2
# Regione Autonoma Valle d'Aosta - Dipartimento trasporti - Struttura aeroporto e ferrovie                                                                     2
# Film Commission Vallée d'Aoste                                                                                                                               2
# ARTIGIANFIDI PADOVA SOCIETA' COOPERATIVA                                                                                                                     1
# UNIONE DEI COMUNI VALLI TARO E CENO                                                                                                                          1
# Struttura s.r.l.                                                                                                                                             1
# CONFIDARE SCPA (EX CONFARTIGIANATO FIDI PIEMONTE E NORD OVEST S.C.P.A.)                                                                                      1
# FINAOSTA SPA                                                                                                                                                 1
# Regione Autonoma delle Sardegna - Servizio Sostegno alle Imprese                                                                                             1
# FOGALCO Soc. Coop. - Fondo di Garanzia al Commercio Turismo e Servizi - Società Cooperativa -                                                                1
# COOPERATIVA ARTIGIANA DI GARANZIA "G.KUFERLE" A R.L.                                                                                                         1
# CONFIDI RATING ITALIA                                                                                                                                        1
# FIDI NORDEST soc coop (EX ARTIGIANFIDI VICENZA soc.coop.)                                                                                                    1
# COOPERATIVA DI GARANZIA FRA GLI ARTIGIANI DELLA PROVINCIA DI TERNI S.C. -Confidi-                                                                            1
# Camera di Commercio della Maremma e del Tirreno                                                                                                              1
# ASCOM FIDI Soc. Coop. Collettiva                                                                                                                             1
# CAMERA DI COMMERCIO INDUSTRIA ARTIGIANATO E AGRICOLTURA DI VITERBO                                                                                           1
# IN.SAR. Iniziative Sardegna spa                                                                                                                              1
# COMUNE DI STREMBO                                                                                                                                            1
# GA.FI.ART. S.C.                                                                                                                                              1
# ASSICOMFIDI                                                                                                                                                  1
# Comunità Montana Valtellina di Sondrio                                                                                                                       1
# SVILUPPO ARTIGIANO SOCIETA'  REGIONALE CONSORTILE COOPERATIVA DI GARANZIA COLLETTIVA FIDI                                                                    1
# Name: SOGGETTO_CONCEDENTE, Length: 275, dtype: int64

# %% [markdown]
# ## Assemblo tutti i COMPONENTI in unico dataframe

# %%
componenti = pd.DataFrame(data_componenti, columns=df_infos_componente)
componenti.info()
componenti.sample(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171062 entries, 0 to 171061
# Data columns (total 9 columns):
# COR                    171062 non-null object
# ID_COMPONENTE_AIUTO    171062 non-null object
# COD_PROCEDIMENTO       171062 non-null object
# DES_PROCEDIMENTO       171062 non-null object
# COD_REGOLAMENTO        171062 non-null object
# DES_REGOLAMENTO        171062 non-null object
# COD_OBIETTIVO          171062 non-null object
# DES_OBIETTIVO          171062 non-null object
# SETTORE_ATTIVITA       171062 non-null object
# dtypes: object(9)
# memory usage: 11.7+ MB
#            COR ID_COMPONENTE_AIUTO COD_PROCEDIMENTO DES_PROCEDIMENTO COD_REGOLAMENTO                         DES_REGOLAMENTO COD_OBIETTIVO                DES_OBIETTIVO SETTORE_ATTIVITA
# 73955   2366    47175               1                De Minimis       CE1998/2006     Reg. CE 1998/2006 de minimis  generale  150200        Sviluppo regionale o locale  F.43.2
# 151779  165882  182797              1                De Minimis       CE1407/13       Reg. UE 1407/2013  de minimis generale  100800        PMI                          C.33.1

# %% [markdown]
# ## Assemblo tutti gli STRUMENTI in unico dataframe

# %%
strumenti = pd.DataFrame(data_strumenti, columns=df_infos_strumento)
#cast campo ELEMENTO_DI_AIUTO da object a float - IMPORTO DELL'AIUTO
strumenti['ELEMENTO_DI_AIUTO'] = strumenti['ELEMENTO_DI_AIUTO'].astype(float)
strumenti.info()
strumenti.sample(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172741 entries, 0 to 172740
# Data columns (total 5 columns):
# COR                    172741 non-null object
# ID_COMPONENTE_AIUTO    172741 non-null object
# COD_STRUMENTO          172741 non-null object
# DES_STRUMENTO          172741 non-null object
# ELEMENTO_DI_AIUTO      172741 non-null float64
# dtypes: float64(1), object(4)
# memory usage: 6.6+ MB
#            COR ID_COMPONENTE_AIUTO COD_STRUMENTO                                                                    DES_STRUMENTO  ELEMENTO_DI_AIUTO
# 169572  185450  203369              37            Sovvenzione/Contributo in conto interessi                                       2570.400
# 140335  152772  168763              10            Garanzia (se del caso con un riferimento alla decisione della Commissione (10)) 2448.000
# 41656   90193   129005              10            Garanzia (se del caso con un riferimento alla decisione della Commissione (10)) 0.000

# %% [markdown]
# ## Info beneficiario
# Estraggo le denominazioni del beneficiario dalla sezione **"AIUTI"** e il codice fiscale o piva per andare a interrogare il servizio della Commissione Europea al fine di arricchire le info che abbiamo sul beneficiario per poterlo geolocalizzare a livello di comune.
#
#
# WSDL servizio:
#
# http://ec.europa.eu/taxation_customs/vies/checkVatService.wsdl
#
# Le informazioni disponibili nel dataset original permettono di identificare la Regione ma non il comune.

# %%
aiuti_id = aiuti[["CODICE_FISCALE_BENEFICIARIO"]]
aiuti_id.to_csv("./data/general/MappingRagioneSocialeIvaCodFisc.csv", sep='\t',index=False)

# %%
PATTERN = "^[A-Z]{6}[0-9]{2}([A-E]|[HLMPRST])[0-9]{2}[A-Z][0-9]([A-Z]|[0-9])[0-9][A-Z]$"
#controlla se è un codice fiscale
def get_type(field):
    return(re.match(PATTERN, field))
#restituisci anno
def get_year(codfisc):
    year = int(codfisc[6:8])
    return year
#resituisci sesso
def get_sex(codfisc):
    return int(codfisc[9:11]) < 32 and 'M' or 'F'

# %% [markdown]
# ## Data Manipulation

# %%
aiuti.shape
componenti.shape
strumenti.shape
# Out:
# (168782, 18)
# (171062, 9)
# (172741, 5)

# %% [markdown]
# Faccio JOIN dei Dataset componenti e misure

# %%
componenti_strumenti = pd.merge(componenti, strumenti, on=['COR','ID_COMPONENTE_AIUTO'])
componenti_strumenti.shape
# Out:
# (172741, 12)

# %%
#random check
componenti_strumenti.loc[componenti_strumenti['COR'] == "36527"]
# Out:
#           COR ID_COMPONENTE_AIUTO COD_PROCEDIMENTO DES_PROCEDIMENTO COD_REGOLAMENTO                                           DES_REGOLAMENTO COD_OBIETTIVO                                                                                                   DES_OBIETTIVO SETTORE_ATTIVITA COD_STRUMENTO                              DES_STRUMENTO  ELEMENTO_DI_AIUTO
# 128192  36527  38331               3                Esenzione        CE651/2014      Reg. CE 651/2014 esenzione generale per categoria (GBER)  501604        Aiuti a favore di ricerca, sviluppo e innovazione | Ricerca industriale (art 25) [art. 25, par. 2, lettera b)]  C.30.1           9             Prestito/Anticipo rimborsabile            168947.170
# 128193  36527  38331               3                Esenzione        CE651/2014      Reg. CE 651/2014 esenzione generale per categoria (GBER)  501604        Aiuti a favore di ricerca, sviluppo e innovazione | Ricerca industriale (art 25) [art. 25, par. 2, lettera b)]  C.30.1           37            Sovvenzione/Contributo in conto interessi 537646.200
# 128194  36527  38332               3                Esenzione        CE651/2014      Reg. CE 651/2014 esenzione generale per categoria (GBER)  501606        Aiuti a favore di ricerca, sviluppo e innovazione | Sviluppo sperimentale [art. 25, par. 2, lettera c)]         C.30.1           9             Prestito/Anticipo rimborsabile            287895.520
# 128195  36527  38332               3                Esenzione        CE651/2014      Reg. CE 651/2014 esenzione generale per categoria (GBER)  501606        Aiuti a favore di ricerca, sviluppo e innovazione | Sviluppo sperimentale [art. 25, par. 2, lettera c)]         C.30.1           37            Sovvenzione/Contributo in conto interessi 916179.500

# %%
#check su aiuto con più componenti e strumenti
strumenti.loc[strumenti['COR'] == "36527"]
# Out:
#           COR ID_COMPONENTE_AIUTO COD_STRUMENTO                              DES_STRUMENTO  ELEMENTO_DI_AIUTO
# 128192  36527  38331               9             Prestito/Anticipo rimborsabile            168947.170
# 128193  36527  38331               37            Sovvenzione/Contributo in conto interessi 537646.200
# 128194  36527  38332               9             Prestito/Anticipo rimborsabile            287895.520
# 128195  36527  38332               37            Sovvenzione/Contributo in conto interessi 916179.500

# %%
#ULTMO JOIN FINALE --> CHECK DATI
len (aiuti)
len (componenti_strumenti) #max final len 172.741
total_aiuti = pd.merge(aiuti, componenti_strumenti, on=['COR'], indicator=False)
total_aiuti.info()
#total_aiuti["_merge"].value_counts()
# Out:
# 168782
# 172741
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 172816 entries, 0 to 172815
# Data columns (total 29 columns):
# CAR                            172816 non-null object
# TITOLO_MISURA                  172816 non-null object
# DES_TIPO_MISURA                172816 non-null object
# BASE_GIURIDICA_NAZIONALE       172816 non-null object
# LINK_TESTO_INTEGRALE_MISURA    172816 non-null object
# COD_UFF_GESTORE                172816 non-null object
# DENOMINAZIONE_UFF_GESTORE      172816 non-null object
# SOGGETTO_CONCEDENTE            172816 non-null object
# COR                            172816 non-null object
# TITOLO_PROGETTO                172816 non-null object
# DESCRIZIONE_PROGETTO           172816 non-null object
# DATA_CONCESSIONE               172816 non-null datetime64[ns]
# CUP                            172816 non-null object
# DENOMINAZIONE_BENEFICIARIO     172816 non-null object
# CODICE_FISCALE_BENEFICIARIO    172816 non-null object
# DES_TIPO_BENEFICIARIO          172816 non-null object
# REGIONE_BENEFICIARIO           172816 non-null object
# Y                              172816 non-null int64
# ID_COMPONENTE_AIUTO            172816 non-null object
# COD_PROCEDIMENTO               172816 non-null object
# DES_PROCEDIMENTO               172816 non-null object
# COD_REGOLAMENTO                172816 non-null object
# DES_REGOLAMENTO                172816 non-null object
# COD_OBIETTIVO                  172816 non-null object
# DES_OBIETTIVO                  172816 non-null object
# SETTORE_ATTIVITA               172816 non-null object
# COD_STRUMENTO                  172816 non-null object
# DES_STRUMENTO                  172816 non-null object
# ELEMENTO_DI_AIUTO              172816 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(26)
# memory usage: 39.6+ MB

# %%
len(total_aiuti)
#add columns for geo info
total_aiuti["ETA"]=""
total_aiuti["SEX"]=""
total_aiuti["INDIRIZZO"]=""
total_aiuti["COMUNE"]=""
total_aiuti["PROVINCIA"]=""
total_aiuti["LATITUDINE"]=""
total_aiuti["LATITUDINE"]=""
total_aiuti["TIPO_BENEFICIARIO"]=""
# Out:
# 172816

# %%
total_aiuti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 172816 entries, 0 to 172815
# Data columns (total 36 columns):
# CAR                            172816 non-null object
# TITOLO_MISURA                  172816 non-null object
# DES_TIPO_MISURA                172816 non-null object
# BASE_GIURIDICA_NAZIONALE       172816 non-null object
# LINK_TESTO_INTEGRALE_MISURA    172816 non-null object
# COD_UFF_GESTORE                172816 non-null object
# DENOMINAZIONE_UFF_GESTORE      172816 non-null object
# SOGGETTO_CONCEDENTE            172816 non-null object
# COR                            172816 non-null object
# TITOLO_PROGETTO                172816 non-null object
# DESCRIZIONE_PROGETTO           172816 non-null object
# DATA_CONCESSIONE               172816 non-null datetime64[ns]
# CUP                            172816 non-null object
# DENOMINAZIONE_BENEFICIARIO     172816 non-null object
# CODICE_FISCALE_BENEFICIARIO    172816 non-null object
# DES_TIPO_BENEFICIARIO          172816 non-null object
# REGIONE_BENEFICIARIO           172816 non-null object
# Y                              172816 non-null int64
# ID_COMPONENTE_AIUTO            172816 non-null object
# COD_PROCEDIMENTO               172816 non-null object
# DES_PROCEDIMENTO               172816 non-null object
# COD_REGOLAMENTO                172816 non-null object
# DES_REGOLAMENTO                172816 non-null object
# COD_OBIETTIVO                  172816 non-null object
# DES_OBIETTIVO                  172816 non-null object
# SETTORE_ATTIVITA               172816 non-null object
# COD_STRUMENTO                  172816 non-null object
# DES_STRUMENTO                  172816 non-null object
# ELEMENTO_DI_AIUTO              172816 non-null float64
# ETA                            172816 non-null object
# SEX                            172816 non-null object
# INDIRIZZO                      172816 non-null object
# COMUNE                         172816 non-null object
# PROVINCIA                      172816 non-null object
# LATITUDINE                     172816 non-null object
# TIPO_BENEFICIARIO              172816 non-null object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(33)
# memory usage: 48.8+ MB

# %%
total_campi= list(total_aiuti.columns.values)
demo_campi = ['CAR', 'TITOLO_MISURA', 'DES_TIPO_MISURA', 'BASE_GIURIDICA_NAZIONALE', 'COD_UFF_GESTORE', 'DENOMINAZIONE_UFF_GESTORE', 'SOGGETTO_CONCEDENTE', 'COR', 'TITOLO_PROGETTO', 'DESCRIZIONE_PROGETTO', 'DATA_CONCESSIONE', 'CUP', 'DENOMINAZIONE_BENEFICIARIO', 'CODICE_FISCALE_BENEFICIARIO', 'DES_TIPO_BENEFICIARIO', 'REGIONE_BENEFICIARIO', 'Y', 'ID_COMPONENTE_AIUTO', 'DES_PROCEDIMENTO', 'DES_REGOLAMENTO',  'DES_OBIETTIVO', 'SETTORE_ATTIVITA', 'DES_STRUMENTO', 'ELEMENTO_DI_AIUTO', 'INDIRIZZO', 'COMUNE', 'PROVINCIA', 'LATITUDINE', 'TIPO_BENEFICIARIO']

# %%
total_aiuti.drop_duplicates()
# Out:
#          CAR                                                                                                                                                                                                          TITOLO_MISURA  DES_TIPO_MISURA                                                                                                                                                                                                                                                                                      BASE_GIURIDICA_NAZIONALE                                                                                                                                                                                                                                      LINK_TESTO_INTEGRALE_MISURA COD_UFF_GESTORE                                                                      DENOMINAZIONE_UFF_GESTORE                                                                                                  SOGGETTO_CONCEDENTE     COR                                                                                                                                                                                                       TITOLO_PROGETTO                                                                                    DESCRIZIONE_PROGETTO DATA_CONCESSIONE              CUP                                            DENOMINAZIONE_BENEFICIARIO CODICE_FISCALE_BENEFICIARIO DES_TIPO_BENEFICIARIO                 REGIONE_BENEFICIARIO     Y ID_COMPONENTE_AIUTO COD_PROCEDIMENTO DES_PROCEDIMENTO COD_REGOLAMENTO                                           DES_REGOLAMENTO COD_OBIETTIVO                                                          DES_OBIETTIVO SETTORE_ATTIVITA COD_STRUMENTO                                                                    DES_STRUMENTO  ELEMENTO_DI_AIUTO ETA SEX INDIRIZZO COMUNE PROVINCIA LATITUDINE TIPO_BENEFICIARIO
# 0       537   Programma degli interventi economici                                                                                                                                                                                   Regime di aiuti  Riordinamento delle camere di commercio, industria, artigianato e agricoltura.                                                                                                                                                                                                                                http://                                                                                                                                                                                                                                                          PROINT          Ufficio Promozione interna - Punto Impresa Digitale                                            Camera di Commercio Industria Artigianato Agricoltura di Treviso Belluno                                             30621   Bando di concorso per la concessione di contributi alle pmi per favorire lo sviluppo di progetti, prodotti, servizi, processi e modelli organizzativi innovativi nonchè l’adozione di tecnologie e servizi digitali   Sviluppo di progetti, prodotti, servizi, processi e modelli organizzativi innovativi                   2016-10-24        I43D16000100003  TSW SRL                                                               02424910269                 PMI                   Veneto                               2016  31681               1                De Minimis       CE1407/13       Reg. UE 1407/2013  de minimis generale                    100800        PMI                                                                    J.62.0           2             Sovvenzione/Contributo in conto interessi                                       7999.000
# 1       537   Programma degli interventi economici                                                                                                                                                                                   Regime di aiuti  Riordinamento delle camere di commercio, industria, artigianato e agricoltura.                                                                                                                                                                                                                                http://                                                                                                                                                                                                                                                          PROINT          Ufficio Promozione interna - Punto Impresa Digitale                                            Camera di Commercio Industria Artigianato Agricoltura di Treviso Belluno                                             30666   Bando di concorso per la concessione di contributi alle pmi per favorire lo sviluppo di progetti, prodotti, servizi, processi e modelli organizzativi innovativi nonché’ l’adozione di tecnologie e servizi digitali  Sviluppo di progetti, prodotti, servizi, processi e modelli organizzativi innovativi                   2016-10-24        I33D16000030003  CAPPELLOTTO - S.P.A.                                                  00566140265                 PMI                   Veneto                               2016  31635               1                De Minimis       CE1407/13       Reg. UE 1407/2013  de minimis generale                    100800        PMI                                                                    C.28.3           2             Sovvenzione/Contributo in conto interessi                                       15000.000
# 2       537   Programma degli interventi economici                                                                                                                                                                                   Regime di aiuti  Riordinamento delle camere di commercio, industria, artigianato e agricoltura.                                                                                                                                                                                                                                http://                                                                                                                                                                                                                                                          PROINT          Ufficio Promozione interna - Punto Impresa Digitale                                            Camera di Commercio Industria Artigianato Agricoltura di Treviso Belluno                                             30667   Bando di concorso per la concessione di contributi alle pmi per favorire lo sviluppo di progetti, prodotti, servizi, processi e modelli organizzativi innovativi nonchè l’adozione di tecnologie e servizi digitali   Sviluppo di progetti, prodotti, servizi, processi e modelli organizzativi innovativi                   2016-10-24        I33D16000040003  TOPTECH SOLUTIONS S.R.L.                                              03555130263                 PMI                   Veneto                               2016  31753               1                De Minimis       CE1407/13       Reg. UE 1407/2013  de minimis generale                    100800        PMI                                                                    C.31.0           2             Sovvenzione/Contributo in conto interessi                                       7088.000
# 3       537   Programma degli interventi economici                                                                                                                                                                                   Regime di aiuti  Riordinamento delle camere di commercio, industria, artigianato e agricoltura.                                                                                                                                                                                                                                http://                                                                                                                                                                                                                                                          PROINT          Ufficio Promozione interna - Punto Impresa Digitale                                            Camera di Commercio Industria Artigianato Agricoltura di Treviso Belluno                                             30668   Bando di concorso per la concessione di contributi alle pmi per favorire lo sviluppo di progetti, prodotti, servizi, processi e modelli organizzativi innovativi nonchè l’adozione di tecnologie e servizi digitali   Sviluppo di progetti, prodotti, servizi, processi e modelli organizzativi innovativi                   2016-10-24        I53D16000020003  SCATTOLIFICIO ONDULKART SPA                                           00193530276                 PMI                   Veneto                               2016  31755               1                De Minimis       CE1407/13       Reg. UE 1407/2013  de minimis generale                    100800        PMI                                                                    C.17.2           2             Sovvenzione/Contributo in conto interessi                                       13890.000
# 4       537   Programma degli interventi economici                                                                                                                                                                                   Regime di aiuti  Riordinamento delle camere di commercio, industria, artigianato e agricoltura.                                                                                                                                                                                                                                http://                                                                                                                                                                                                                                                          PROINT          Ufficio Promozione interna - Punto Impresa Digitale                                            Camera di Commercio Industria Artigianato Agricoltura di Treviso Belluno                                             30669   Bando di concorso per la concessione di contributi alle pmi per favorire lo sviluppo di progetti, prodotti, servizi, processi e modelli organizzativi innovativi nonchè l’adozione di tecnologie e servizi digitali   Sviluppo di progetti, prodotti, servizi, processi e modelli organizzativi innovativi                   2016-10-24        I93D16000000003  MEET YOUR BUSINESS S.R.L.                                             04752610263                 PMI                   Veneto                               2016  31757               1                De Minimis       CE1407/13       Reg. UE 1407/2013  de minimis generale                    100800        PMI                                                                    M.70.2           2             Sovvenzione/Contributo in conto interessi                                       15000.000
# 5       537   Programma degli interventi economici                                                                                                                                                                                   Regime di aiuti  Riordinamento delle camere di commercio, industria, artigianato e agricoltura.                                                                                                                                                                                                                                http://                                                                                                                                                                                                                                                          PROINT          Ufficio Promozione interna - Punto Impresa Digitale                                            Camera di Commercio Industria Artigianato Agricoltura di Treviso Belluno                                             30670   Bando di concorso per la concessione di contributi alle pmi per favorire lo sviluppo di progetti, prodotti, servizi, processi e modelli organizzativi innovativi nonchè l’adozione di tecnologie e servizi digitali   Sviluppo di progetti, prodotti, servizi, processi e modelli organizzativi innovativi                   2016-10-24        I33D16000050003  TONIOLO CASEARIA SPA                                                  01217950268                 PMI                   Veneto                               2016  31759               1                De Minimis       CE1407/13       Reg. UE 1407/2013  de minimis generale                    100800        PMI                                                                    C.10.5           2             Sovvenzione/Contributo in conto interessi                                       8750.000
# 6       537   Programma degli interventi economici                                                                                                                                                                                   Regime di aiuti  Riordinamento delle camere di commercio, industria, artigianato e agricoltura.                                                                                                                                                                                                                                http://                                                                                                                                                                                                                                                          PROINT          Ufficio Promozione interna - Punto Impresa Digitale                                            Camera di Commercio Industria Artigianato Agricoltura di Treviso Belluno                                             30671   Bando di concorso per la concessione di contributi alle pmi per favorire lo sviluppo di progetti, prodotti, servizi, processi e modelli organizzativi innovativi nonchè l’adozione di tecnologie e servizi digitali   Sviluppo di progetti, prodotti, servizi, processi e modelli organizzativi innovativi                   2016-10-24        I13D16000000003  VP SOLAR S.R.L.                                                       04131820260                 PMI                   Veneto                               2016  31760               1                De Minimis       CE1407/13       Reg. UE 1407/2013  de minimis generale                    100800        PMI                                                                    G.46.6           2             Sovvenzione/Contributo in conto interessi                                       7123.000
# 7       537   Programma degli interventi economici                                                                                                                                                                                   Regime di aiuti  Riordinamento delle camere di commercio, industria, artigianato e agricoltura.                                                                                                                                                                                                                                http://                                                                                                                                                                                                                                                          PROINT          Ufficio Promozione interna - Punto Impresa Digitale                                            Camera di Commercio Industria Artigianato Agricoltura di Treviso Belluno                                             30681   Bando di concorso per la concessione di contributi alle pmi per favorire lo sviluppo di progetti, prodotti, servizi, processi e modelli organizzativi innovativi nonché l’adozione di tecnologie e servizi digitali   Tecnologie e servizi digitali innovativi                                                               2016-10-24        I43D16000110003  CMN GROUP SRL                                                         02189540269                 PMI                   Veneto                               2016  31781               1                De Minimis       CE1407/13       Reg. UE 1407/2013  de minimis generale                    100800        PMI                                                                    G.46.4           2             Sovvenzione/Contributo in conto interessi                                       5565.000
# 8       537   Programma degli interventi economici                                                                                                                                                                                   Regime di aiuti  Riordinamento delle camere di commercio, industria, artigianato e agricoltura.                                                                                                                                                                                                                                http://                                                                                                                                                                                                                                                          PROINT          Ufficio Promozione interna - Punto Impresa Digitale                                            Camera di Commercio Industria Artigianato Agricoltura di Treviso Belluno                                             30682   Bando di concorso per la concessione di contributi alle pmi per favorire lo sviluppo di progetti, prodotti, servizi, processi e modelli organizzativi innovativi nonché l’adozione di tecnologie e servizi digitali   Tecnologie e servizi digitali innovativi                                                               2016-10-24        I93D16000020003  S.I.M.A. S.R.L.                                                       00752630269                 PMI                   Veneto                               2016  31782               1                De Minimis       CE1407/13       Reg. UE 1407/2013  de minimis generale                    100800        PMI                                                                    C.28.3           2             Sovvenzione/Contributo in conto interessi                                       7321.000
# 9       537   Programma degli interventi economici                                                                                                                                                                                   Regime di aiuti  Riordinamento delle camere di commercio, industria, artigianato e agricoltura.                                                                                                                                                                                                                                http://                                                                                                                                                                                                                                                          PROINT          Ufficio Promozione interna - Punto Impresa Digitale                                            Camera di Commercio Industria Artigianato Agricoltura di Treviso Belluno                                             30683   Bando di concorso per la concessione di contributi alle pmi per favorire lo sviluppo di progetti, prodotti, servizi, processi e modelli organizzativi innovativi nonché l’adozione di tecnologie e servizi digitali   Tecnologie e servizi digitali innovativi                                                               2016-10-24        I13D16000010003  DISEC S.R.L.                                                          03532240268                 PMI                   Veneto                               2016  31783               1                De Minimis       CE1407/13       Reg. UE 1407/2013  de minimis generale                    100800        PMI                                                                    C.25.7           2             Sovvenzione/Contributo in conto interessi                                       12128.000
# 10      537   Programma degli interventi economici                                                                                                                                                                                   Regime di aiuti  Riordinamento delle camere di commercio, industria, artigianato e agricoltura.                                                                                                                                                                                                                                http://                                                                                                                                                                                                                                                          PROINT          Ufficio Promozione interna - Punto Impresa Digitale                                            Camera di Commercio Industria Artigianato Agricoltura di Treviso Belluno                                             30684   Bando di concorso per la concessione di contributi alle pmi per favorire lo sviluppo di progetti, prodotti, servizi, processi e modelli organizzativi innovativi nonché l’adozione di tecnologie e servizi digitali   Tecnologie e servizi digitali innovativi                                                               2016-10-24        I93D16000040003  CHECK UP S.R.L.                                                       01201610936                 PMI                   Veneto                               2016  31784               1                De Minimis       CE1407/13       Reg. UE 1407/2013  de minimis generale                    100800        PMI                                                                    C.26.5           2             Sovvenzione/Contributo in conto interessi                                       5464.000
# 11      537   Programma degli interventi economici                                                                                                                                                                                   Regime di aiuti  Riordinamento delle camere di commercio, industria, artigianato e agricoltura.                                                                                                                                                                                                                                http://                                                                                                                                                                                                                                                          PROINT          Ufficio Promozione interna - Punto Impresa Digitale                                            Camera di Commercio Industria Artigianato Agricoltura di Treviso Belluno                                             30685   Bando di concorso per la concessione di contributi alle pmi per favorire lo sviluppo di progetti, prodotti, servizi, processi e modelli organizzativi innovativi nonché l’adozione di tecnologie e servizi digitali   Tecnologie e servizi digitali innovativi                                                               2016-10-24        I23D16000120003  PRODECO PHARMA S.R.L.                                                 02103160269                 PMI                   Veneto                               2016  31785               1                De Minimis       CE1407/13       Reg. UE 1407/2013  de minimis generale                    100800        PMI                                                                    C.21.2           2             Sovvenzione/Contributo in conto interessi                                       12423.000
# 12      537   Programma degli interventi economici                                                                                                                                                                                   Regime di aiuti  Riordinamento delle camere di commercio, industria, artigianato e agricoltura.                                                                                                                                                                                                                                http://                                                                                                                                                                                                                                                          PROINT          Ufficio Promozione interna - Punto Impresa Digitale                                            Camera di Commercio Industria Artigianato Agricoltura di Treviso Belluno                                             30686   Bando di concorso per la concessione di contributi alle pmi per favorire lo sviluppo di progetti, prodotti, servizi, processi e modelli organizzativi innovativi nonché l’adozione di tecnologie e servizi digitali   Tecnologie e servizi digitali innovativi                                                               2016-10-24        I23D16000050003  BASSO SEBASTIANO - S.R.L.                                             00786860262                 PMI                   Veneto                               2016  31787               1                De Minimis       CE1407/13       Reg. UE 1407/2013  de minimis generale                    100800        PMI                                                                    G.46.3           2             Sovvenzione/Contributo in conto interessi                                       13167.000
# 13      537   Programma degli interventi economici                                                                                                                                                                                   Regime di aiuti  Riordinamento delle camere di commercio, industria, artigianato e agricoltura.                                                                                                                                                                                                                                http://                                                                                                                                                                                                                                                          PROINT          Ufficio Promozione interna - Punto Impresa Digitale                                            Camera di Commercio Industria Artigianato Agricoltura di Treviso Belluno                                             30687   Bando di concorso per la concessione di contributi alle pmi per favorire lo sviluppo di progetti, prodotti, servizi, processi e modelli organizzativi innovativi nonchè l’adozione di tecnologie e servizi digitali   Sviluppo di progetti, prodotti, servizi, processi e modelli organizzativi innovativi                   2016-10-24        I23D16000020003  OASI.S OPEN AUTOMATION SYSTEMS INTEGRATOR SERVER Srl                  03435980267                 PMI                   Veneto                               2016  31786               1                De Minimis       CE1407/13       Reg. UE 1407/2013  de minimis generale                    100800        PMI                                                                    C.28.9           2             Sovvenzione/Contributo in conto interessi                                       15000.000
# 14      537   Programma degli interventi economici                                                                                                                                                                                   Regime di aiuti  Riordinamento delle camere di commercio, industria, artigianato e agricoltura.                                                                                                                                                                                                                                http://                                                                                                                                                                                                                                                          PROINT          Ufficio Promozione interna - Punto Impresa Digitale                                            Camera di Commercio Industria Artigianato Agricoltura di Treviso Belluno                                             30688   Bando di concorso per la concessione di contributi alle pmi per favorire lo sviluppo di progetti, prodotti, servizi, processi e modelli organizzativi innovativi nonché l’adozione di tecnologie e servizi digitali   Tecnologie e servizi digitali innovativi                                                               2016-10-24        I43D16000120003  TUBILASER SRL                                                         03747570269                 PMI                   Veneto                               2016  31788               1                De Minimis       CE1407/13       Reg. UE 1407/2013  de minimis generale                    100800        PMI                                                                    C.25.6           2             Sovvenzione/Contributo in conto interessi                                       14270.000
# 15      537   Programma degli interventi economici                                                                                                                                                                                   Regime di aiuti  Riordinamento delle camere di commercio, industria, artigianato e agricoltura.                                                                                                                                                                                                                                http://                                                                                                                                                                                                                                                          PROINT          Ufficio Promozione interna - Punto Impresa Digitale                                            Camera di Commercio Industria Artigianato Agricoltura di Treviso Belluno                                             30689   Bando di concorso per la concessione di contributi alle pmi per favorire lo sviluppo di progetti, prodotti, servizi, processi e modelli organizzativi innovativi nonché l’adozione di tecnologie e servizi digitali   Tecnologie e servizi digitali innovativi                                                               2016-10-24        I93D16000050003  BLUE MOBILITY S.R.L.                                                  04342350263                 PMI                   Veneto                               2016  31789               1                De Minimis       CE1407/13       Reg. UE 1407/2013  de minimis generale                    100800        PMI                                                                    G.46.5           2             Sovvenzione/Contributo in conto interessi                                       9555.000
# 16      537   Programma degli interventi economici                                                                                                                                                                                   Regime di aiuti  Riordinamento delle camere di commercio, industria, artigianato e agricoltura.                                                                                                                                                                                                                                http://                                                                                                                                                                                                                                                          PROINT          Ufficio Promozione interna - Punto Impresa Digitale                                            Camera di Commercio Industria Artigianato Agricoltura di Treviso Belluno                                             30690   Bando di concorso per la concessione di contributi alle pmi per favorire lo sviluppo di progetti, prodotti, servizi, processi e modelli organizzativi innovativi nonché l’adozione di tecnologie e servizi digitali   Tecnologie e servizi digitali innovativi                                                               2016-10-24        I93D16000060003  HIP - MITSU S.R.L.                                                    02502610260                 PMI                   Veneto                               2016  31790               1                De Minimis       CE1407/13       Reg. UE 1407/2013  de minimis generale                    100800        PMI                                                                    C.28.4           2             Sovvenzione/Contributo in conto interessi                                       12321.000
# 17      537   Programma degli interventi economici                                                                                                                                                                                   Regime di aiuti  Riordinamento delle camere di commercio, industria, artigianato e agricoltura.                                                                                                                                                                                                                                http://                                                                                                                                                                                                                                                          PROINT          Ufficio Promozione interna - Punto Impresa Digitale                                            Camera di Commercio Industria Artigianato Agricoltura di Treviso Belluno                                             30691   Bando di concorso per la concessione di contributi alle pmi per favorire lo sviluppo di progetti, prodotti, servizi, processi e modelli organizzativi innovativi nonché l’adozione di tecnologie e servizi digitali   Tecnologie e servizi digitali innovativi                                                               2016-10-24        I93D16000070003  SALVADORI CORNICI                                                     00890170269                 PMI                   Veneto                               2016  31791               1                De Minimis       CE1407/13       Reg. UE 1407/2013  de minimis generale                    100800        PMI                                                                    C.16.2           2             Sovvenzione/Contributo in conto interessi                                       13405.000
# 18      537   Programma degli interventi economici                                                                                                                                                                                   Regime di aiuti  Riordinamento delle camere di commercio, industria, artigianato e agricoltura.                                                                                                                                                                                                                                http://                                                                                                                                                                                                                                                          PROINT          Ufficio Promozione interna - Punto Impresa Digitale                                            Camera di Commercio Industria Artigianato Agricoltura di Treviso Belluno                                             30692   Bando di concorso per la concessione di contributi alle pmi per favorire lo sviluppo di progetti, prodotti, servizi, processi e modelli organizzativi innovativi nonché l’adozione di tecnologie e servizi digitali   Tecnologie e servizi digitali innovativi                                                               2016-10-24        I13D16000020003  P.M.P. S.P.A.                                                         00069850261                 PMI                   Veneto                               2016  31793               1                De Minimis       CE1407/13       Reg. UE 1407/2013  de minimis generale                    100800        PMI                                                                    C.22.2           2             Sovvenzione/Contributo in conto interessi                                       6000.000
# 19      537   Programma degli interventi economici                                                                                                                                                                                   Regime di aiuti  Riordinamento delle camere di commercio, industria, artigianato e agricoltura.                                                                                                                                                                                                                                http://                                                                                                                                                                                                                                                          PROINT          Ufficio Promozione interna - Punto Impresa Digitale                                            Camera di Commercio Industria Artigianato Agricoltura di Treviso Belluno                                             30693   Bando di concorso per la concessione di contributi alle pmi per favorire lo sviluppo di progetti, prodotti, servizi, processi e modelli organizzativi innovativi nonché l’adozione di tecnologie e servizi digitali   Tecnologie e servizi digitali innovativi                                                               2016-10-24        I53D16000030003  A&S FORM S.R.L.                                                       04304320262                 PMI                   Veneto                               2016  31795               1                De Minimis       CE1407/13       Reg. UE 1407/2013  de minimis generale                    100800        PMI                                                                    P.85.5           2             Sovvenzione/Contributo in conto interessi                                       6541.000
# 20      537   Programma degli interventi economici                                                                                                                                                                                   Regime di aiuti  Riordinamento delle camere di commercio, industria, artigianato e agricoltura.                                                                                                                                                                                                                                http://                                                                                                                                                                                                                                                          PROINT          Ufficio Promozione interna - Punto Impresa Digitale                                            Camera di Commercio Industria Artigianato Agricoltura di Treviso Belluno                                             30694   Bando di concorso per la concessione di contributi alle pmi per favorire lo sviluppo di progetti, prodotti, servizi, processi e modelli organizzativi innovativi nonché l’adozione di tecnologie e servizi digitali   Tecnologie e servizi digitali innovativi                                                               2016-10-24        I93D16000080003  PROCED S.R.L.                                                         01952150264                 PMI                   Veneto                               2016  31797               1                De Minimis       CE1407/13       Reg. UE 1407/2013  de minimis generale                    100800        PMI                                                                    G.46.6           2             Sovvenzione/Contributo in conto interessi                                       14675.000
# 21      537   Programma degli interventi economici                                                                                                                                                                                   Regime di aiuti  Riordinamento delle camere di commercio, industria, artigianato e agricoltura.                                                                                                                                                                                                                                http://                                                                                                                                                                                                                                                          PROINT          Ufficio Promozione interna - Punto Impresa Digitale                                            Camera di Commercio Industria Artigianato Agricoltura di Treviso Belluno                                             30701   Bando di concorso per la concessione di contributi alle pmi per favorire lo sviluppo di progetti, prodotti, servizi, processi e modelli organizzativi innovativi nonchè l’adozione di tecnologie e servizi digitali   Sviluppo di progetti, prodotti, servizi, processi e modelli organizzativi innovativi                   2016-10-24        I23D16000030003  MAAS INNOVATION S.R.L.                                                04727420269                 PMI                   Veneto                               2016  31775               1                De Minimis       CE1407/13       Reg. UE 1407/2013  de minimis generale                    100800        PMI                                                                    C.25.6           2             Sovvenzione/Contributo in conto interessi                                       15000.000
# 22      537   Programma degli interventi economici                                                                                                                                                                                   Regime di aiuti  Riordinamento delle camere di commercio, industria, artigianato e agricoltura.                                                                                                                                                                                                                                http://                                                                                                                                                                                                                                                          PROINT          Ufficio Promozione interna - Punto Impresa Digitale                                            Camera di Commercio Industria Artigianato Agricoltura di Treviso Belluno                                             30702   Bando di concorso per la concessione di contributi alle pmi per favorire lo sviluppo di progetti, prodotti, servizi, processi e modelli organizzativi innovativi nonchè l’adozione di tecnologie e servizi digitali   Sviluppo di progetti, prodotti, servizi, processi e modelli organizzativi innovativi                   2016-10-24        I23D16000040003  G. & P. GARBELLOTTO S.P.A.                                            01162440265                 PMI                   Veneto                               2016  31778               1                De Minimis       CE1407/13       Reg. UE 1407/2013  de minimis generale                    100800        PMI                                                                    C.16.2           2             Sovvenzione/Contributo in conto interessi                                       11578.000
# ...
# 172807  2385  Fondo di Prevenzione dell'usura                                                                                                                                                                                        Regime di aiuti  Disposizioni in materia di usura (Articolo 15)                                                                                                                                                                                                                                                                http://www.dt.mef.gov.it/export/sites/sitodt/modules/documenti_it/prevenzione_reati_finanziari/normativa/LEGGE_7_marzo_1996.pdf                                                                                                                                  LOM29           FOGALCO Soc. Coop. - Fondo di Garanzia al Commercio Turismo e Servizi - Società Cooperativa -  FOGALCO Soc. Coop. - Fondo di Garanzia al Commercio Turismo e Servizi - Società Cooperativa -                        192838  GARANZIA                                                                                                                                                                                                              Aiuto fornito sotto forma di garanzia                                                                  2017-12-29        n.d.             A. & M. RISTORAZIONE S.N.C. DI TELI ANDREA E C.                       03318020165                 PMI                   Lombardia                            2017  211285              1                De Minimis       CE1407/13       Reg. UE 1407/2013  de minimis generale                    100800        PMI                                                                    I.56.1           10            Garanzia (se del caso con un riferimento alla decisione della Commissione (10)) 1378.180
# 172808  2558  RER - POR FESR 2014 - 2020 - ASSE 3, AZIONE 3.4.1. APPROVAZIONE "BANDO PER PROGETTI DI PROMOZIONE DELL'EXPORT E PER LA PARTECIPAZIONE A EVENTI FIERISTICI - 2017"                                                      Regime di aiuti  POR FESR 2014 - 2020 - ASSE 3 "COMPETITIVITA' ED ATTRATTIVITA' DEL SISTEMA PRODUTTIVO", AZIONE 3.4.1. APPROVAZIONE "BANDO PER PROGETTI DI PROMOZIONE DELL'EXPORT PER IMPRESE NON ESPORTATRICI E PER LA PARTECIPAZIONE A EVENTI FIERISTICI - 2017" E PARZIALE MODIFICA AL BANDO DI CUI ALLA D.G.R. N. 18/2016  http://imprese.regione.emilia-romagna.it/Finanziamenti/internazionalizzazione/progetti-di-promozione-dellexport-e-per-la-partecipazione-ad-eventi-fieristici                                                                                                     3               SERVIZIO ATTRATTIVITÀ E INTERNAZIONALIZZAZIONE                                                 Regione Emilia-Romagna - Giunta Regionale - Direzione Generale Economia della Conoscenza, del Lavoro e dell'Impresa  192851  Sviluppo di reti commerciali all'estero                                                                                                                                                                               Interventi di internazionalizzazione                                                                   2017-12-29        E38I17000520004  S.C.A. S.R.L.                                                         01323250181                 PMI                   Emilia-Romagna                       2017  171287              3                Esenzione        CE651/2014      Reg. CE 651/2014 esenzione generale per categoria (GBER)  500806        Aiuti alle PMI | Aiuti per la partecipazione alle fiere (art. 19)      C.10.5           37            Sovvenzione/Contributo in conto interessi                                       8805.000
# 172809  1609  Avviso pubblico ISI 2016, Incentivi alle imprese per la realizzazione di interventi in materia di salute e sicurezza sul lavoro, in attuazione dell’articolo 11, comma 5, del decreto legislativo 9 aprile 2008, n.81  Regime di aiuti  TESTO UNICO SULLA SALUTE E SICUREZZA NEI LUOGHI DI LAVORO                                                                                                                                                                                                                                                     https://www.inail.it/cs/internet/attivita/prevenzione-e-sicurezza/agevolazioni-e-finanziamenti/incentivi-alle-imprese/bando-isi-2016.html                                                                                                                        21000           INAIL - DR TOSCANA ISI                                                                         INAIL - Direzione Centrale Prevenzione                                                                               192853  bando ISI                                                                                                                                                                                                             sostituzione e smaltimento copertura eternit                                                           2017-12-29        E58c17000150005  ELCO S.R.L.                                                           01219150537                 PMI                   Toscana                              2017  211287              1                De Minimis       CE1407/13       Reg. UE 1407/2013  de minimis generale                    105800        Altro obiettivo di sviluppo economico o sociale non classificato       F.42.2           12            Misura per il finanziamento del rischio                                         17998.000
# 172810  2558  RER - POR FESR 2014 - 2020 - ASSE 3, AZIONE 3.4.1. APPROVAZIONE "BANDO PER PROGETTI DI PROMOZIONE DELL'EXPORT E PER LA PARTECIPAZIONE A EVENTI FIERISTICI - 2017"                                                      Regime di aiuti  POR FESR 2014 - 2020 - ASSE 3 "COMPETITIVITA' ED ATTRATTIVITA' DEL SISTEMA PRODUTTIVO", AZIONE 3.4.1. APPROVAZIONE "BANDO PER PROGETTI DI PROMOZIONE DELL'EXPORT PER IMPRESE NON ESPORTATRICI E PER LA PARTECIPAZIONE A EVENTI FIERISTICI - 2017" E PARZIALE MODIFICA AL BANDO DI CUI ALLA D.G.R. N. 18/2016  http://imprese.regione.emilia-romagna.it/Finanziamenti/internazionalizzazione/progetti-di-promozione-dellexport-e-per-la-partecipazione-ad-eventi-fieristici                                                                                                     3               SERVIZIO ATTRATTIVITÀ E INTERNAZIONALIZZAZIONE                                                 Regione Emilia-Romagna - Giunta Regionale - Direzione Generale Economia della Conoscenza, del Lavoro e dell'Impresa  192865  attività di sviluppo della rete vendita, della clientela e del fatturato mediante partecipazione a fiere espositive estere di settore a carattere internazionale                                                      Interventi di internazionalizzazione                                                                   2017-12-29        E78I17000300004  SATI GROUP S.P.A.                                                     03882680378                 PMI                   Emilia-Romagna                       2017  174762              3                Esenzione        CE651/2014      Reg. CE 651/2014 esenzione generale per categoria (GBER)  500806        Aiuti alle PMI | Aiuti per la partecipazione alle fiere (art. 19)      G.46.4           37            Sovvenzione/Contributo in conto interessi                                       17700.000
# 172811  2558  RER - POR FESR 2014 - 2020 - ASSE 3, AZIONE 3.4.1. APPROVAZIONE "BANDO PER PROGETTI DI PROMOZIONE DELL'EXPORT E PER LA PARTECIPAZIONE A EVENTI FIERISTICI - 2017"                                                      Regime di aiuti  POR FESR 2014 - 2020 - ASSE 3 "COMPETITIVITA' ED ATTRATTIVITA' DEL SISTEMA PRODUTTIVO", AZIONE 3.4.1. APPROVAZIONE "BANDO PER PROGETTI DI PROMOZIONE DELL'EXPORT PER IMPRESE NON ESPORTATRICI E PER LA PARTECIPAZIONE A EVENTI FIERISTICI - 2017" E PARZIALE MODIFICA AL BANDO DI CUI ALLA D.G.R. N. 18/2016  http://imprese.regione.emilia-romagna.it/Finanziamenti/internazionalizzazione/progetti-di-promozione-dellexport-e-per-la-partecipazione-ad-eventi-fieristici                                                                                                     3               SERVIZIO ATTRATTIVITÀ E INTERNAZIONALIZZAZIONE                                                 Regione Emilia-Romagna - Giunta Regionale - Direzione Generale Economia della Conoscenza, del Lavoro e dell'Impresa  192891  Tellure Rôta e le fiere Internazionali : "Una vetrina per moving Solution"                                                                                                                                            Interventi di internazionalizzazione                                                                   2017-12-29        E18I17000350004  TELLURE ROTA - S.P.A.                                                 00180900367                 PMI                   Emilia-Romagna                       2017  179418              3                Esenzione        CE651/2014      Reg. CE 651/2014 esenzione generale per categoria (GBER)  500806        Aiuti alle PMI | Aiuti per la partecipazione alle fiere (art. 19)      C.25.9           37            Sovvenzione/Contributo in conto interessi                                       18750.000
# 172812  2558  RER - POR FESR 2014 - 2020 - ASSE 3, AZIONE 3.4.1. APPROVAZIONE "BANDO PER PROGETTI DI PROMOZIONE DELL'EXPORT E PER LA PARTECIPAZIONE A EVENTI FIERISTICI - 2017"                                                      Regime di aiuti  POR FESR 2014 - 2020 - ASSE 3 "COMPETITIVITA' ED ATTRATTIVITA' DEL SISTEMA PRODUTTIVO", AZIONE 3.4.1. APPROVAZIONE "BANDO PER PROGETTI DI PROMOZIONE DELL'EXPORT PER IMPRESE NON ESPORTATRICI E PER LA PARTECIPAZIONE A EVENTI FIERISTICI - 2017" E PARZIALE MODIFICA AL BANDO DI CUI ALLA D.G.R. N. 18/2016  http://imprese.regione.emilia-romagna.it/Finanziamenti/internazionalizzazione/progetti-di-promozione-dellexport-e-per-la-partecipazione-ad-eventi-fieristici                                                                                                     3               SERVIZIO ATTRATTIVITÀ E INTERNAZIONALIZZAZIONE                                                 Regione Emilia-Romagna - Giunta Regionale - Direzione Generale Economia della Conoscenza, del Lavoro e dell'Impresa  192913  AMPLIAMENTO SETTORIALE E CONSOLIDAMENTO TERRITORIALE DEL MERCATO ESTERO                                                                                                                                               Interventi di internazionalizzazione                                                                   2017-12-29        E88I17000690004  ZANASI  S.R.L.                                                        01386040362                 PMI                   Emilia-Romagna                       2017  186506              3                Esenzione        CE651/2014      Reg. CE 651/2014 esenzione generale per categoria (GBER)  500804        Aiuti alle PMI | Aiuti per servizi di consulenza (art. 18)             C.28.9           37            Sovvenzione/Contributo in conto interessi                                       11190.000
# 172813  1609  Avviso pubblico ISI 2016, Incentivi alle imprese per la realizzazione di interventi in materia di salute e sicurezza sul lavoro, in attuazione dell’articolo 11, comma 5, del decreto legislativo 9 aprile 2008, n.81  Regime di aiuti  TESTO UNICO SULLA SALUTE E SICUREZZA NEI LUOGHI DI LAVORO                                                                                                                                                                                                                                                     https://www.inail.it/cs/internet/attivita/prevenzione-e-sicurezza/agevolazioni-e-finanziamenti/incentivi-alle-imprese/bando-isi-2016.html                                                                                                                        21000           INAIL - DR TOSCANA ISI                                                                         INAIL - Direzione Centrale Prevenzione                                                                               192940  isi                                                                                                                                                                                                                   smaltimento e ripristino copertura                                                                     2017-12-29        E12F17001640005  NAUTICA CALA GALERA S.P.A.                                            00973360423                 PMI                   Toscana                              2017  211301              1                De Minimis       CE1407/13       Reg. UE 1407/2013  de minimis generale                    105800        Altro obiettivo di sviluppo economico o sociale non classificato       C.33.1           12            Misura per il finanziamento del rischio                                         55250.000
# 172815  691   FONDO DI ROTAZIONE PER L'INTERNAZIONALIZZAZIONE DELLE IMPRESE - FRI                                                                                                                                                    Regime di aiuti  ACCORDO DI PROGRAMMA PER LO SVILUPPO ECONOMICO E LA COMPETITIVITÀ DEL SISTEMA LOMBARDO 2010-2015. RELAZIONE ATTIVITÀ 2012 E PROGRAMMA DI AZIONE 2013                                                                                                                                                          http://www.sviluppoeconomico.regione.lombardia.it/cs/Satellite?c=Attivita&childpagename=DG_Commercio%2FWrapperBandiLayout&cid=1213486913499&p=1213486913499&packedargs=locale%3D1194453881584%26menu-to-render%3D1213301212376&pagename=DG_COMMWrapper&tipologi  RLO13303        STR SOSTEGNO ALL'EXPORT E ATTRAZIONE DEGLI INVESTIMENTI                                        Regione Lombardia - DG Sviluppo economico                                                                            45540   ABICH QUEBEC                                                                                                                                                                                                          ABICH QUEBEC                                                                                           2014-02-05        E17H14000130009  ABICH - S.R.L.                                                        01864020035                 PMI                   Lombardia                            2014  211301              1                De Minimis       CE1407/13       Reg. UE 1407/2013  de minimis generale                    105800        Altro obiettivo di sviluppo economico o sociale non classificato       C.33.1           12            Misura per il finanziamento del rischio                                         55250.000
#
# [172741 rows x 36 columns]

# %%
# CHECK: Get a report of all duplicate records in a dataframe, based on specific columns
dupes = total_aiuti[total_aiuti.duplicated(['COR', 'ID_COMPONENTE_AIUTO','ELEMENTO_DI_AIUTO'], keep=False)]
print(len(dupes))
# Out:
# 438

# %%
total_demo = total_aiuti[demo_campi]
print (len(total_demo))
total_demo = total_demo.loc[total_demo['Y'] == 2017]  
print (len(total_demo))
# Out:
# 172816
# 140155

# %%
#salvo in csv per SUPERSET il dataframecompleto
#castomizzare con max e min valore temporale dei file
total_demo.to_csv("./data/aiuti/AiutiTotali.csv", sep='|',index=False, header=True,  encoding='utf-8')

# %%
total_aiuti.groupby(['DES_TIPO_MISURA', pd.Grouper(key='DATA_CONCESSIONE', freq='A')])['ELEMENTO_DI_AIUTO'].sum()
regioni_total = total_aiuti.groupby(['REGIONE_BENEFICIARIO', pd.Grouper(key='DATA_CONCESSIONE', freq='A')])['ELEMENTO_DI_AIUTO'].sum()
# Out:
# DES_TIPO_MISURA  DATA_CONCESSIONE
# Aiuto ad hoc     2015-12-31         600000.000
#                  2016-12-31         1640000.000
#                  2017-12-31         6653783.510
# Regime di aiuti  2009-12-31         198000.000
#                  2010-12-31         660000.000
#                  2011-12-31         615000.000
#                  2012-12-31         797847.490
#                  2013-12-31         3744137.140
#                  2014-12-31         491097584.050
#                  2015-12-31         177223275.840
#                  2016-12-31         178818536.130
#                  2017-12-31         4677032404.520
#                  2018-12-31         2796422.890
# Name: ELEMENTO_DI_AIUTO, dtype: float64

# %%
total_aiuti.groupby(['Y','DES_TIPO_MISURA'])['COR'].count()
# Out:
# Y     DES_TIPO_MISURA
# 2009  Regime di aiuti    14
# 2010  Regime di aiuti    48
# 2011  Regime di aiuti    47
# 2012  Regime di aiuti    35
# 2013  Regime di aiuti    92
# 2014  Regime di aiuti    23204
# 2015  Aiuto ad hoc       1
#       Regime di aiuti    2265
# 2016  Aiuto ad hoc       3
#       Regime di aiuti    6300
# 2017  Aiuto ad hoc       24
#       Regime di aiuti    140131
# 2018  Regime di aiuti    652
# Name: COR, dtype: int64

# %%
regioni = pd.value_counts(aiuti['REGIONE_BENEFICIARIO'].values, sort=True)
regioni
# Out:
# Lombardia                                                            38563
# Veneto                                                               15988
# Emilia-Romagna                                                       14472
# Sicilia                                                              13415
# Piemonte                                                             11180
# Campania                                                             10844
# Toscana                                                              8286
# Friuli-Venezia Giulia                                                7972
# Puglia                                                               7970
# Marche                                                               6919
# Sardegna                                                             6771
# Lazio                                                                6555
# Calabria                                                             3907
# Provincia Autonoma di Bolzano/Bozen                                  3144
# Abruzzo                                                              2885
# Umbria                                                               2815
# Provincia Autonoma di Trento                                         2638
# Liguria                                                              1315
# Basilicata                                                           1164
# Valle d'Aosta/Vallée d'Aoste                                         870
# Molise                                                               501
# Campania, Lazio                                                      47
# Lombardia, Piemonte                                                  34
# Inner London - East                                                  31
# Campania, Lombardia                                                  26
# Lombardia, Veneto                                                    22
# Friuli-Venezia Giulia, Veneto                                        17
# Emilia-Romagna, Lombardia                                            17
# Campania, Emilia-Romagna                                             16
# Emilia-Romagna, Veneto                                               13
#                                                                      ..
# Emilia-Romagna, Lombardia, Piemonte, Toscana, Veneto                 1
# Emilia-Romagna, Liguria                                              1
# Calabria, Campania, Lazio, Toscana                                   1
# Abruzzo, Umbria                                                      1
# Friuli-Venezia Giulia, Sardegna                                      1
# Abruzzo, Lazio, Umbria                                               1
# Lazio, Molise                                                        1
# Campania, Lombardia, Sicilia                                         1
# Calabria, Emilia-Romagna, Lazio, Liguria                             1
# Emilia-Romagna, Sardegna                                             1
# Basilicata, Molise                                                   1
# Abruzzo, Toscana                                                     1
# Calabria, Campania                                                   1
# Emilia-Romagna, Molise                                               1
# Calabria, Sardegna                                                   1
# Abruzzo, Campania, Lombardia                                         1
# Emilia-Romagna, Toscana                                              1
# Basilicata, Calabria                                                 1
# Emilia-Romagna, Provincia Autonoma di Trento, Veneto                 1
# Abruzzo, Molise                                                      1
# Campania, Piemonte, Puglia                                           1
# Campania, Provincia Autonoma di Trento                               1
# Provincia Autonoma di Bolzano/Bozen, Provincia Autonoma di Trento    1
# Liguria, Provincia Autonoma di Trento                                1
# Basilicata, Campania, Piemonte, Puglia                               1
# Basilicata, Emilia-Romagna                                           1
# Toscana, Veneto                                                      1
# Friuli-Venezia Giulia, Liguria                                       1
# Liguria, Sicilia                                                     1
# Liguria, Toscana                                                     1
# Length: 135, dtype: int64

# %%
#BENEFICIARI per numero di AIUTI
beneficiari = pd.value_counts(aiuti.DENOMINAZIONE_BENEFICIARIO.values, sort=True)
beneficiari
# Out:
# Politecnico di Milano                                                                                                                      62
# EUROCOT S.P.A. TRASPORTI E DEPOSITI                                                                                                        48
# Ufficio Infrastrutture per telecomunicazioni                                                                                               35
# Università della Calabria                                                                                                                  28
# PULITECNICA FRIULANA S.R.L.                                                                                                                27
# BPER BANCA S.P.A.                                                                                                                          27
# BANCA CARIGE S.P.A. - CASSA DI RISPARMIO DI GENOVA E IMPERIA SIGLABILE "BANCA CARIGE S.P.A." O "CARIGE S.P.A."                             26
# BANCA SELLA HOLDING S.P.A.                                                                                                                 26
# COOPERATIVA ITACA SOCIETA' COOPERATIVA SOCIALE O.N.L.U.S.                                                                                  24
# BANCA SELLA - S.P.A.                                                                                                                       22
# LA QUERCIA SOCIETA' COOPERATIVA SOCIALE                                                                                                    19
# IBL ISTITUTO BANCARIO DEL LAVORO S.P.A. O IN FORMA ABBREVIATA IBL BANCA.                                                                   18
# BANCA POPOLARE ETICA   SOCIETA' COOPERATIVA PER AZIONI O IN FORMA ABBREVIATA "BANCA ETICA" O "BPE".                                        18
# CASSA DI RISPARMIO DI CENTO S.P.A.                                                                                                         15
# INNOVA S.R.L.                                                                                                                              15
# ENERGIA VITALE S.R.L.                                                                                                                      14
# V.S.G. S.N.C. DI GAMBRON UMBERTO & C.                                                                                                      14
# A.T.L. - AZIENDA TRASPORTI LOMBARDI SRL                                                                                                    14
# PR.E.M.A.V. S.R.L.                                                                                                                         14
# SOCIETA' COOPERATIVA SOCIALE CHIANOC - ONLUS                                                                                               13
# HOTEL SAVOY SRL                                                                                                                            13
# EOS S.R.L.                                                                                                                                 13
# ITAS ISTITUTO TRENTINO ALTO ADIGE PER ASSICURAZIONI SOCIETA' MUTUA DI ASSICURAZIONI IN SIGLA ITAS MUTUA                                    13
# "TECNO FARM SOCIETA' A RESPONSABILITA' LIMITATA"                                                                                           13
# BANCA POPOLARE DEL LAZIO - SOCIETA' COOPERATIVA PER AZIONI                                                                                 13
# BIELLA LEASING - S.P.A.                                                                                                                    13
# FAMILIA S.R.L.                                                                                                                             13
# A.T.E.R. DI PORDENONE                                                                                                                      13
# EDYNA SRL                                                                                                                                  13
# AGRICOLA MONTE SAN PANTALEONE - COOPERATIVA SOCIALE - SOCIETA' COOPERATIVA - ONLUS IN FORMA ABBREVIATA "AGRICOLA MONTE SAN PANTALEONE "    12
#                                                                                                                                            ..
# ELETTRORIZ DI RIZZINI PIETRO                                                                                                               1
# MACELLERIA STEINER SNC DI FLORIAN  STEINER                                                                                                 1
# STUDIO CONTE S.R.L. SOCIETA' UNIPERSONALE                                                                                                  1
# CALDERARO GIUSEPPE                                                                                                                         1
# A.F. DI FACECCHIA GIANCARLO                                                                                                                1
# EXPLORA DI TRIVELLI SELENE                                                                                                                 1
# MACELLERIA FRATELLI PRIMANTE SNC DI PRIMANTE ALESSANDRO & C.                                                                               1
# GEDOIL SRL                                                                                                                                 1
# SANITARIA SAN GIUSEPPE DI GENTILE ANGELA                                                                                                   1
# STUDIO ASSOCIATO COMINI PINI                                                                                                               1
# TECNOTTICA PARISI DI PARISI ALDO                                                                                                           1
# VITALBA FITNESS CLUB S.A.S. DI FRIGERIO BRUNO E SPADA GIOVANNI LU CA                                                                       1
# INVEST S.N.C. DI PREVITI PASQUALE &amp; GIUNTA FRANCESCA MARIA                                                                             1
# FABRIK S.R.L.                                                                                                                              1
# TELIX SOCIETA' A RESPONSABILITA' LIMITATA SEMPLIFICATA                                                                                     1
# DE SANTIS FRANCO                                                                                                                           1
# CASA DEL FORMAGGIO DI PASSINI CARLO MARIA                                                                                                  1
# RM ELETTRONICA DI ROCCHI MARCO                                                                                                             1
# ANTONIO DEMURTAS E C. S.A.S.                                                                                                               1
# GEOMORE S.R.L.                                                                                                                             1
# RISTORANTE LA BAITA S.R.L.                                                                                                                 1
# RONSISVALLE UGO                                                                                                                            1
# VILLA CANTONI SRL                                                                                                                          1
# LA DOCCIA S.A.S. DI FRONTANI ANGIOLINO E C.                                                                                                1
# L'AQUILA ROSSA  S.R.L.                                                                                                                     1
# C'EST CHIC DI FORTINI GIULIA                                                                                                               1
# ANTONIO GIANNINI                                                                                                                           1
# ATREIDES GROUP S.R.L.                                                                                                                      1
# IMPREGIVI S.R.L.                                                                                                                           1
# NEROCREMA DI RUSSO ALESSANDRO                                                                                                              1
# Length: 130585, dtype: int64

# %%
aiuti.DENOMINAZIONE_BENEFICIARIO.value_counts()
# Out:
# Politecnico di Milano                                                                                                                      62
# EUROCOT S.P.A. TRASPORTI E DEPOSITI                                                                                                        48
# Ufficio Infrastrutture per telecomunicazioni                                                                                               35
# Università della Calabria                                                                                                                  28
# PULITECNICA FRIULANA S.R.L.                                                                                                                27
# BPER BANCA S.P.A.                                                                                                                          27
# BANCA CARIGE S.P.A. - CASSA DI RISPARMIO DI GENOVA E IMPERIA SIGLABILE "BANCA CARIGE S.P.A." O "CARIGE S.P.A."                             26
# BANCA SELLA HOLDING S.P.A.                                                                                                                 26
# COOPERATIVA ITACA SOCIETA' COOPERATIVA SOCIALE O.N.L.U.S.                                                                                  24
# BANCA SELLA - S.P.A.                                                                                                                       22
# LA QUERCIA SOCIETA' COOPERATIVA SOCIALE                                                                                                    19
# IBL ISTITUTO BANCARIO DEL LAVORO S.P.A. O IN FORMA ABBREVIATA IBL BANCA.                                                                   18
# BANCA POPOLARE ETICA   SOCIETA' COOPERATIVA PER AZIONI O IN FORMA ABBREVIATA "BANCA ETICA" O "BPE".                                        18
# CASSA DI RISPARMIO DI CENTO S.P.A.                                                                                                         15
# INNOVA S.R.L.                                                                                                                              15
# ENERGIA VITALE S.R.L.                                                                                                                      14
# V.S.G. S.N.C. DI GAMBRON UMBERTO & C.                                                                                                      14
# A.T.L. - AZIENDA TRASPORTI LOMBARDI SRL                                                                                                    14
# PR.E.M.A.V. S.R.L.                                                                                                                         14
# SOCIETA' COOPERATIVA SOCIALE CHIANOC - ONLUS                                                                                               13
# HOTEL SAVOY SRL                                                                                                                            13
# EOS S.R.L.                                                                                                                                 13
# ITAS ISTITUTO TRENTINO ALTO ADIGE PER ASSICURAZIONI SOCIETA' MUTUA DI ASSICURAZIONI IN SIGLA ITAS MUTUA                                    13
# "TECNO FARM SOCIETA' A RESPONSABILITA' LIMITATA"                                                                                           13
# BANCA POPOLARE DEL LAZIO - SOCIETA' COOPERATIVA PER AZIONI                                                                                 13
# BIELLA LEASING - S.P.A.                                                                                                                    13
# FAMILIA S.R.L.                                                                                                                             13
# A.T.E.R. DI PORDENONE                                                                                                                      13
# EDYNA SRL                                                                                                                                  13
# AGRICOLA MONTE SAN PANTALEONE - COOPERATIVA SOCIALE - SOCIETA' COOPERATIVA - ONLUS IN FORMA ABBREVIATA "AGRICOLA MONTE SAN PANTALEONE "    12
#                                                                                                                                            ..
# ELETTRORIZ DI RIZZINI PIETRO                                                                                                               1
# MACELLERIA STEINER SNC DI FLORIAN  STEINER                                                                                                 1
# STUDIO CONTE S.R.L. SOCIETA' UNIPERSONALE                                                                                                  1
# CALDERARO GIUSEPPE                                                                                                                         1
# A.F. DI FACECCHIA GIANCARLO                                                                                                                1
# EXPLORA DI TRIVELLI SELENE                                                                                                                 1
# MACELLERIA FRATELLI PRIMANTE SNC DI PRIMANTE ALESSANDRO & C.                                                                               1
# GEDOIL SRL                                                                                                                                 1
# SANITARIA SAN GIUSEPPE DI GENTILE ANGELA                                                                                                   1
# STUDIO ASSOCIATO COMINI PINI                                                                                                               1
# TECNOTTICA PARISI DI PARISI ALDO                                                                                                           1
# VITALBA FITNESS CLUB S.A.S. DI FRIGERIO BRUNO E SPADA GIOVANNI LU CA                                                                       1
# INVEST S.N.C. DI PREVITI PASQUALE &amp; GIUNTA FRANCESCA MARIA                                                                             1
# FABRIK S.R.L.                                                                                                                              1
# TELIX SOCIETA' A RESPONSABILITA' LIMITATA SEMPLIFICATA                                                                                     1
# DE SANTIS FRANCO                                                                                                                           1
# CASA DEL FORMAGGIO DI PASSINI CARLO MARIA                                                                                                  1
# RM ELETTRONICA DI ROCCHI MARCO                                                                                                             1
# ANTONIO DEMURTAS E C. S.A.S.                                                                                                               1
# GEOMORE S.R.L.                                                                                                                             1
# RISTORANTE LA BAITA S.R.L.                                                                                                                 1
# RONSISVALLE UGO                                                                                                                            1
# VILLA CANTONI SRL                                                                                                                          1
# LA DOCCIA S.A.S. DI FRONTANI ANGIOLINO E C.                                                                                                1
# L'AQUILA ROSSA  S.R.L.                                                                                                                     1
# C'EST CHIC DI FORTINI GIULIA                                                                                                               1
# ANTONIO GIANNINI                                                                                                                           1
# ATREIDES GROUP S.R.L.                                                                                                                      1
# IMPREGIVI S.R.L.                                                                                                                           1
# NEROCREMA DI RUSSO ALESSANDRO                                                                                                              1
# Name: DENOMINAZIONE_BENEFICIARIO, Length: 130585, dtype: int64

# %%
total_aiuti.DES_PROCEDIMENTO.value_counts()
# Out:
# De Minimis    139028
# Esenzione     32761
# Notifica      1027
# Name: DES_PROCEDIMENTO, dtype: int64

# %%
aiuti.SOGGETTO_CONCEDENTE.value_counts()
# Out:
# Banca del Mezzogiorno MedioCredito Centrale S.p.A.                                                                                                           45318
# Ministero dello sviluppo economico - Direzione generale per gli incentivi alle imprese                                                                       38804
# Regione Lombardia - DG Sviluppo economico                                                                                                                    16653
# FONDIMPRESA                                                                                                                                                  9006
# Regione Emilia-Romagna - Giunta Regionale - Direzione Generale Economia della Conoscenza, del Lavoro e dell'Impresa                                          4325
# Formazienda                                                                                                                                                  3065
# REGIONE AUTONOMA FRIULI VENEZIA GIULIA - DIREZIONE CENTRALE LAVORO, FORMAZIONE, ISTRUZIONE, PARI OPPORTUNITA', POLITICHE GIOVANILI, RICERCA E UNIVERSITA'    2714
# UNIONCAMERE LOMBARDIA                                                                                                                                        2672
# FONDER                                                                                                                                                       2071
# FONDO FOR.TE                                                                                                                                                 2007
# Regione Veneto - Direzione Formazione e Istruzione                                                                                                           1825
# Veneto Sviluppo Spa                                                                                                                                          1790
# Provincia Autonoma di Bolzano - Ripartizione Economia                                                                                                        1706
# FonARCom                                                                                                                                                     1503
# Camera di Commercio Industria Artigianato e Agricoltura di Cuneo                                                                                             1224
# INAIL - Direzione Centrale Prevenzione                                                                                                                       1182
# AOO Regione Toscana Giunta                                                                                                                                   1146
# REGIONE PIEMONTE - DIREZIONE COESIONE SOCIALE                                                                                                                1107
# CITTA' METROPOLITANA DI TORINO                                                                                                                               1067
# ForAgri                                                                                                                                                      1031
# REGIONE SICILIANA - DIPARTIMENTO ATTIVITA' PRODUTTIVE                                                                                                        969
# Regione Lombardia - DG Università Ricerca e Open Innovation                                                                                                  908
# CONFIDI TRENTINO IMPRESE - SOCIETA' COOPERATIVA                                                                                                              887
# GESTORE SERVIZI ENERGETICI                                                                                                                                   823
# Regione Lombardia - DG Istruzione Formazione Lavoro                                                                                                          811
# Provincia Autonoma di Trento                                                                                                                                 748
# CATA ARTIGIANATO FRIULI VENEZIA GIULIA S.R.L.                                                                                                                658
# Camera di Commercio, Industria, Artigianato e Agricoltura di Firenze                                                                                         619
# Regione autonoma Friuli Venezia Giulia - Direzione centrale attività produttive, turismo e cooperazione                                                      608
# Fondo artigianato formazione                                                                                                                                 606
#                                                                                                                                                             ...
# UNIONE MONTANA APPENNINO PARMA EST                                                                                                                           2
# Regione Veneto - Direzione Ricerca Innovazione ed Energia                                                                                                    2
# FidImpresa MARCHE                                                                                                                                            2
# COMUNE DI TRIESTE                                                                                                                                            2
# SARDAFIDI SCPA                                                                                                                                               2
# Comune di Borgo Valsugana                                                                                                                                    2
# COFIMER S.C.P.A.                                                                                                                                             2
# Fondoprofessioni                                                                                                                                             2
# Regione Autonoma Valle d'Aosta - Dipartimento trasporti - Struttura aeroporto e ferrovie                                                                     2
# Film Commission Vallée d'Aoste                                                                                                                               2
# ARTIGIANFIDI PADOVA SOCIETA' COOPERATIVA                                                                                                                     1
# UNIONE DEI COMUNI VALLI TARO E CENO                                                                                                                          1
# Struttura s.r.l.                                                                                                                                             1
# CONFIDARE SCPA (EX CONFARTIGIANATO FIDI PIEMONTE E NORD OVEST S.C.P.A.)                                                                                      1
# FINAOSTA SPA                                                                                                                                                 1
# Regione Autonoma delle Sardegna - Servizio Sostegno alle Imprese                                                                                             1
# FOGALCO Soc. Coop. - Fondo di Garanzia al Commercio Turismo e Servizi - Società Cooperativa -                                                                1
# COOPERATIVA ARTIGIANA DI GARANZIA "G.KUFERLE" A R.L.                                                                                                         1
# CONFIDI RATING ITALIA                                                                                                                                        1
# FIDI NORDEST soc coop (EX ARTIGIANFIDI VICENZA soc.coop.)                                                                                                    1
# COOPERATIVA DI GARANZIA FRA GLI ARTIGIANI DELLA PROVINCIA DI TERNI S.C. -Confidi-                                                                            1
# Camera di Commercio della Maremma e del Tirreno                                                                                                              1
# ASCOM FIDI Soc. Coop. Collettiva                                                                                                                             1
# CAMERA DI COMMERCIO INDUSTRIA ARTIGIANATO E AGRICOLTURA DI VITERBO                                                                                           1
# IN.SAR. Iniziative Sardegna spa                                                                                                                              1
# COMUNE DI STREMBO                                                                                                                                            1
# GA.FI.ART. S.C.                                                                                                                                              1
# ASSICOMFIDI                                                                                                                                                  1
# Comunità Montana Valtellina di Sondrio                                                                                                                       1
# SVILUPPO ARTIGIANO SOCIETA'  REGIONALE CONSORTILE COOPERATIVA DI GARANZIA COLLETTIVA FIDI                                                                    1
# Name: SOGGETTO_CONCEDENTE, Length: 275, dtype: int64

# %%
aiuti.DES_TIPO_BENEFICIARIO.value_counts()
# Out:
# PMI               162684
# -                 3416
# Grande impresa    2682
# Name: DES_TIPO_BENEFICIARIO, dtype: int64

# %%
aiuti.TITOLO_MISURA.value_counts()
# Out:
# Fondo di garanzia per le piccole e medie imprese                                                                                                                                                                                                                   45318
# Regolamento per i fondi interprofessionali per la formazione continua per la concessioni di aiuti di stato esentati ai sensi del regolamento CE n.651/2014 e in regime de minimis ai sensi del regolamento CE n.1407/2013                                          21289
# Zone Franche Urbane dell’Obiettivo Convergenza, nonché nel territorio dei comuni della provincia di Carbonia-Iglesias                                                                                                                                              19850
# Nuova Sabatini - Finanziamenti per l'acquisto di nuovi macchinari, impianti e attrezzature da parte delle piccole e medie imprese                                                                                                                                  10047
# LINEA DI INTERVENTO CONTROGARANZIE                                                                                                                                                                                                                                 9467
# Zona Franca Urbana Sisma Centro Italia                                                                                                                                                                                                                             6149
# AVVISO PUBBLICO FINALIZZATO A FAVORIRE L'ACCESSO AL CREDITO DELLE IMPRESE PER IL TRAMITE DEI CONFIDI                                                                                                                                                               3360
# MODALITA' DI APPLICAZIONE DEL REGOLAMENTO (UE) N. 1407/2013 DEL 18/12/2013 SUGLI AIUTI DE MINIMIS ALLE IMPRESE OPERANTI NEL TERRITORIO DELLA REGIONE EMILIA-ROMAGNA E DESTINATARIE DI CONTRIBUTI PUBBLICI NELL'AMBITO DELLE POLITICHE ATTIVE DEL LAVORO            2316
# FVG-INCENTIVI PER INTERVENTI DI POLITICA ATTIVA DEL LAVORO                                                                                                                                                                                                         1949
# Zona Franca dell'Emilia                                                                                                                                                                                                                                            1770
# Interventi di ingegneria finanziaria per il sostegno e lo sviluppo delle piccole e medie imprese. Aggiornamento delle disposizioni operative per l'utilizzo del Fondo regionale di Garanzia, istituito presso la finanziaria regionale Veneto Sviluppo S.p.A.,     1475
# Programma Operativo Regionale - Fondo Sociale Europeo 2014-2020 in sinergia con il Fondo Europeo di Sviluppo Regionale - Asse I Occupabilità - "L'impresa Inn-FORMATA. La formazione che innova le imprese venete". Avviso pubblico per la presentazione di pro    1424
# RER - Aiuti destinati alle imprese operanti nel territorio della Regione appartenenti ai settori esposti alla concorrenza internazionale e che sono rivolti alla prima formazione, alla riqualificazione ed aggiornamento dei loro addetti                         1193
# PIANI FORMATIVI DI AREA A FINANZIAMENTO INDIRETTO PER IMPRESE E SOGGETTI ASSIMILABILI. BANDO REGIONALE 2016-2018.                                                                                                                                                  1107
# BANDO DELLA CITTA' METROPOLITANA DI TORINO (2016-2018) "PIANI FORMATIVI DI AREA A FINANZIAMENTO INDIRETTO PER IMPRESE E SOGGETTI ASSIMILABILI"                                                                                                                     1067
# Avviso pubblico ISI 2016, Incentivi alle imprese per la realizzazione di interventi in materia di salute e sicurezza sul lavoro, in attuazione dell’articolo 11, comma 5, del decreto legislativo 9 aprile 2008, n.81                                              1018
# FVG-DPReg 226/2007-Regolamento per l’assegnazione delle risorse finanziarie ai sensi dell’ articolo 7, comma 35, della legge regionale 1/2007 a favore dei Consorzi di garanzia fidi della regione Friuli Venezia Giulia.                                          958
# POR FESR 2014-2020 – ASSE III – AZIONE III.3.B.2.3 (AZIONE 3.3.4 DELL’ACCORDO                                                                                                                                                                                      880
# Credito d'esercizio                                                                                                                                                                                                                                                871
# DM 23 GIUGNO 2016 - REGIME DI INCENTIVAZIONE DELL'ENERGIA ELETTRICA PRODOTTA DA FONTI RINNOVABILI DIVERSE DAL SOLARE FOTOVOLTAICO                                                                                                                                  823
# Contributi per sicurezza, certificazioni di prodotto e di processo, ambiente                                                                                                                                                                                       748
# POR FSE 2014 - 2020 - Approvazione dell'avviso formazione continua - Fase V                                                                                                                                                                                        724
# Bando "Impresa Sicura" - 2016                                                                                                                                                                                                                                      705
# Zona Franca della Lombardia                                                                                                                                                                                                                                        631
# RIORGANIZZAZIONE DEGLI STRUMENTI PER LE AGEVOLAZIONI CREDITIZIE E LO SVILUPPO DEL SISTEMA DELLE GARANZIE PER LE IMPRESE ARTIGIANE                                                                                                                                  603
# contributi per investimenti innovativi finalizzati all’incremento della sicurezza a favore delle micro e piccole imprese commerciali - bando 2015                                                                                                                  539
# Accrescimento delle competenze della forza lavoro - azioni di formazione continua                                                                                                                                                                                  523
# FORMAZIONE - AIUTI DE MINIMIS destinati alle imprese operanti nel territorio della Regione Toscana                                                                                                                                                                 520
# Bando Ricerca e innovazione  - edizione 2014                                                                                                                                                                                                                       469
# PAT - Aiuti alle imprese L.P. 6/99 in COMPENSAZIONE FISCALE                                                                                                                                                                                                        453
#                                                                                                                                                                                                                                                                   ...
# Contributo per "Reggio Emilia città contemporanea d'arte e di cultura - Incoming culturale a Reggio per Reggio"                                                                                                                                                    1
# Regime di aiuto per la tutela dell'ambiente - efficienza energetica- ex art.38                                                                                                                                                                                     1
# 1.4.1. Sostegno alla creazione e al consolidamento di start up innovative ad alta intensità di apllicazione di concoscenza e alle iniziative di spinn off della ricerca                                                                                            1
# Interventi coordinati per l’occupazione – ICO                                                                                                                                                                                                                      1
# Interventi straordinari a favore di impianti di risalita di paese e di piccoli comprensori sciistici                                                                                                                                                               1
# Bando per la concessione di contributi volti alla qualificazione e valorizzazione di personale e all’acquisto di dispositivi di sicurezza da parte delle pmi del settore dei trasporti della provincia di Udine_ 2017                                              1
# Sostegno per la costituzione e la gestione di gruppi operativi del PEI in materia di produttività e sostenibilità dell'agricoltura                                                                                                                                 1
# Concessione di contributi per spese correnti all'Azienda sanitaria dell'Alto Adige, riguardante l'assistenza ai bambini                                                                                                                                            1
# Criteri per la concessione di aiuti per la difesa passiva attraverso polizze assicurative e relativi mutui                                                                                                                                                         1
# Criteri e modalità per l’erogazione di contributi a grandi eventi sportivi: campionati nazionali, mondiali, europei, coppe del mondo ed eventi nazionali e internazionali che si svolgeranno sul territorio lombardo                                               1
# FVG-DPReg 224/2009-Reg di cui all’art. 12 bis della LR 4/2005, concernente concessione garanzie del Fondo regionale garanzia per le PMI, tipologie di operazioni in relazione alle quali possono operare e l’ammontare dell’impegno massimo del Fondo              1
# Partecipazione della Regione Lazio alle attività dell'anno 2016 della Fondazione Musica per Roma                                                                                                                                                                   1
# VOUCHER ALLE IMPRESE START - UP  PER ASSISTENZA TECNICO-SPECIALISTICA FINALIZZATA ALLO SVILUPPO DELL'INNOVAZIONE APPROVATO CON DELIBERA N.31 DEL 12/04/2017 - AMPLIAMENTO DEL PLAFOND DISPONIBILE                                                                  1
# INCENTIVI ALLE AZIENDE                                                                                                                                                                                                                                             1
# Fondo per la nascita e lo sviluppo delle start up innovative                                                                                                                                                                                                       1
# PAT Aiuti alle imprese L.P. 6/99 per CONSORZI                                                                                                                                                                                                                      1
# Progetto Valorizzazione del patrimonio culturale e Promozione del Turismo nella Provincia di Verona                                                                                                                                                                1
# Bando contributi in c/capitale alle PMI cuneesi in collaborazione con Ascom Fidi Langhe e Roero anno 2016                                                                                                                                                          1
# Concessione contributo al COSILT per infrastruttura locale                                                                                                                                                                                                         1
# CREDITO IN - CASSA B2B - SOTTO MISURA B                                                                                                                                                                                                                            1
# RETTIFICA DGR 4663 - 23/12/2015 “APPROVAZ. REQUISITI E CRITERI BANDO PER DOMANDE DI FINANZIAM. SU FONDO DI ROTAZIONE PER RISTRUTTURAZ. E ADEGUAM. TECNOLOG. SALE PER ATT. SPETTAC. E ACQUISTO ED INSTALLAZ. APPARECCH. DIGITALI PER PROIEZ.  ART. 5 L.R. 21/08     1
# FVG - REALIZZAZIONE PROGETTI ATTUAZIONE TIROCINI INTEGRAZIONE LAVORATIVA PERSONE CON DISABILITA'                                                                                                                                                                   1
# FVG - DPReg. 9/2008 "Interventi a favore dell'innovazione nel settore della filiera foresta-legno", di cui all'art. 16 L.R. 26/2005                                                                                                                                1
# Contributi alle imprese neo costituite                                                                                                                                                                                                                             1
# Partecipazione della Regione Lazio alle attività dell'anno 2017 alla Fondazione Musica per Roma                                                                                                                                                                    1
# FONDO DI GARANZIA PMI AGRICOLE PER IL TRAMITE DEI CONFIDI                                                                                                                                                                                                          1
# FVG - DPGR N. 84/2017 REGOLAMENTO PER LA CONCESSIONE DI CONTRIBUTI AI CONSORZI DI SVILUPPO ECONOMICO LOCALE PER COPERTURA SPESE SOSTENUTE PER REALIZZAZIONE O AMMODERNAMENTO DI INFRASTRUTTURE LOCALI PER L'INSEDIAMENTO DI ATTIVITA' PRODUTTIVE                   1
# Progetto integrativo al Piano straordinario di videosorvelgianza                                                                                                                                                                                                   1
# Integrazione accordo di programma riqualificazione Zingonia                                                                                                                                                                                                        1
# GORIZIA - Regolamento tecnico per la concessione di contributi e finanziamenti a sostegno dell'economia locale, ai sensi dell'art. 12 della Legge n. 241/90 e successive modifiche e integrazioni                                                                  1
# Name: TITOLO_MISURA, Length: 767, dtype: int64

# %%
componenti.DES_OBIETTIVO.value_counts()
# Out:
# PMI                                                                                                                                                                                                                                               72382
# Sviluppo regionale o locale                                                                                                                                                                                                                       30184
# Formazione                                                                                                                                                                                                                                        19652
# Aiuti alla Formazione (art.31)                                                                                                                                                                                                                    12624
# Aiuti agli investimenti e all'occupazione in favore delle PMI (art. 15)                                                                                                                                                                           10049
# Altro obiettivo di sviluppo economico o sociale non classificato                                                                                                                                                                                  6321
# Promozione dell'esportazione e dell'internazionalizzazione                                                                                                                                                                                        2710
# Ricerca, sviluppo e innovazione                                                                                                                                                                                                                   2357
# Aiuti a favore di ricerca, sviluppo e innovazione | Ricerca industriale (art 25) [art. 25, par. 2, lettera b)]                                                                                                                                    1784
# Aiuti a favore di ricerca, sviluppo e innovazione | Sviluppo sperimentale [art. 25, par. 2, lettera c)]                                                                                                                                           1725
# Sviluppo settoriale                                                                                                                                                                                                                               1650
# Aiuti alle PMI | Aiuti agli investimenti a favore delle PMI (art. 17)                                                                                                                                                                             1570
# Protezione ambientale                                                                                                                                                                                                                             1177
# Finanziamento del rischio                                                                                                                                                                                                                         1103
# Aiuti alle PMI | Aiuti per servizi di consulenza (art. 18)                                                                                                                                                                                        670
# Aiuti a favore di ricerca, sviluppo e innovazione | Aiuti all'innovazione a favore delle PMI (art. 28)                                                                                                                                            544
# Aiuti a favore di lavoratori svantaggiati e di lavoratori con disabilità | Aiuti all'assunzione di lavoratori svantaggiati sotto forma di integrazioni salariali (art. 32)                                                                        441
# Accesso delle PMI ai finanziamenti | Aiuti alle imprese in fase di avviamento (art. 22)                                                                                                                                                           416
# Aiuti alle PMI | Aiuti per la partecipazione alle fiere (art. 19)                                                                                                                                                                                 381
# Aiuti a favore dei lavoratori svantaggiati e/o dei lavoratori con disabilità                                                                                                                                                                      339
# Efficienza energetica                                                                                                                                                                                                                             310
# Aiuti per la cultura e la conservazione del patrimonio (art. 53)                                                                                                                                                                                  290
# Aiuti per la tutela dell'ambiente | Aiuti agli investimenti che consentono alle imprese di andare oltre le norme dell'Unione in materia di tutela ambientale o di innalzare il livello di tutela ambientale in assenza di tali norme (art. 36)    252
# Cultura                                                                                                                                                                                                                                           237
# Servizi d'interesse economico generale (SIEG)                                                                                                                                                                                                     205
# Aiuti a favore di ricerca, sviluppo e innovazione | Aiuti per l'innovazione dei processi e dell'organizzazione (art. 29)                                                                                                                          187
# Aiuti a favore di lavoratori svantaggiati e di lavoratori con disabilità | Aiuti all'occupazione di lavoratori con disabilita sotto forma di integrazioni salariali (art. 33)                                                                     172
# Regimi di aiuti a favore delle opere audiovisive (art. 54)                                                                                                                                                                                        166
# Infrastrutture sportive e infrastrutture ricreative multifunzionali                                                                                                                                                                               159
# Compensazione di danni arrecati da calamità naturali o da altri eventi eccezionali                                                                                                                                                                135
# Aiuti per la tutela dell'ambiente | Aiuti agli investimenti a favore di misure di efficienza energetica (art. 38)                                                                                                                                 120
# Realizzazione di un importante progetto di comune interesse europeo                                                                                                                                                                               109
# Aiuti a finalità regionale — Aiuti agli investimenti (art. 14) — Regime                                                                                                                                                                           101
# Aiuti per la tutela dell'ambiente | Aiuti agli investimenti volti a promuovere la produzione di energia da fonti rinnovabili (art. 41)                                                                                                            79
# Energia rinnovabile                                                                                                                                                                                                                               71
# Aiuti per le infrastrutture sportive e le infrastrutture ricreative multifunzionali (art. 55)                                                                                                                                                     53
# Aiuti a favore di lavoratori svantaggiati e di lavoratori con disabilità | Aiuti intesi a compensare i sovraccosti connessi all'occupazione di lavoratori con disabilita (art. 34)                                                                51
# Aiuti per la tutela dell'ambiente | Aiuti per gli studi ambientali (art. 49)                                                                                                                                                                      48
# Aiuti a favore di ricerca, sviluppo e innovazione | Ricerca fondamentale [art. 25, par. 2, lettera a)]                                                                                                                                            41
# Infrastrutture energetiche                                                                                                                                                                                                                        39
# Aiuti per le infrastrutture a banda larga (art. 52)                                                                                                                                                                                               38
# Infrastrutture a banda larga                                                                                                                                                                                                                      24
# Aiuti a favore di ricerca, sviluppo e innovazione | Aiuti ai poli d'innovazione (art. 27)                                                                                                                                                         22
# Aiuti a favore di ricerca, sviluppo e innovazione | Studi di fattibilità [art. 25, par. 2, lettera d)]                                                                                                                                            15
# Aiuti per la tutela dell'ambiente | Aiuti agli investimenti per teleriscaldamento e teleraffreddamento efficienti sotto il profilo energetico (art. 46)                                                                                           13
# Conservazione del patrimonio                                                                                                                                                                                                                      13
# Aiuti agli investimenti per le infrastrutture locali (art. 56)                                                                                                                                                                                    8
# Aiuti per la tutela dell'ambiente | Aiuti agli investimenti a favore della cogenerazione ad alto rendimento (art. 40)                                                                                                                             7
# Aiuti a favore di ricerca, sviluppo e innovazione | Aiuti agli investimenti per le infrastrutture di ricerca (art. 26)                                                                                                                            6
# Aiuti sotto forma di capitale di rischio (art. 28-29)                                                                                                                                                                                             3
# Aiuti regionali agli investimenti e all'occupazione (art. 13) — Regime                                                                                                                                                                            2
# Aiuti a finalità regionale per lo sviluppo urbano (Art.16)                                                                                                                                                                                        2
# Aiuti destinati a ovviare ai danni arrecati da determinate calamità naturali (art.50)                                                                                                                                                             2
# Aiuti per la tutela dell'ambiente | Aiuti agli investimenti per l'adeguamento anticipato a future norme dell'Unione (art. 37)                                                                                                                     1
# Sostegno sociale a singoli consumatori                                                                                                                                                                                                            1
# Aiuti a favore di lavoratori svantaggiati e di lavoratori con disabilità | Aiuti intesi a compensare i costi dell'assistenza fornita ai lavoratori svantaggiati (art. 35)                                                                         1
# Name: DES_OBIETTIVO, dtype: int64

# %%
strumenti.DES_STRUMENTO.value_counts()
# Out:
# Sovvenzione/Contributo in conto interessi                                                                                                                                                                                                         75365
# Garanzia (se del caso con un riferimento alla decisione della Commissione (10))                                                                                                                                                                   59286
# Agevolazione fiscale o esenzione fiscale                                                                                                                                                                                                          28489
# Misura per il finanziamento del rischio                                                                                                                                                                                                           4835
# Prestito/Anticipo rimborsabile                                                                                                                                                                                                                    3116
# AIUTI ALLA FORMAZIONE (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                      341
# contributo in conto capitale (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                               188
# Contributo in forma di servizio agevolato (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                  183
# riduzione aliquota tariffa elettrica (Categoria: Agevolazione fiscale o esenzione fiscale)                                                                                                                                                        109
# SOVVENZIONE (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                                105
# sovvenzione diretta attinenti a: formazione, sovraccosti connessi all'occupazione di lavoratori con disabilità - assistenza fornita ai lavoratori svantaggiati - integrazioni salariali (Categoria: Sovvenzione/Contributo in conto interessi)    70
# Incentivo all'assunzione e formazione continua (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                             68
# contributo in conto capitale  (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                              62
# contributo riduzione costi garanzia (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                        54
# contributo a fondo perduto (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                 51
# Indennizzo (Categoria: Garanzia (se del caso con un riferimento alla decisione della Commissione (10)))                                                                                                                                           50
# Contributi a fondo perduto (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                 43
# Aiuti partecipazioni a fiere (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                               35
# dote impresa incentivo all'assunzione (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                      33
# Contributo a fondo perduto (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                 32
# Contributo spese per il personale (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                          27
# Aiuto alla liquidità attraverso rinegoziazione durata e/o tasso di interesse di mutui già concessi (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                         22
# Sospensione rate dei mutui (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                 17
# Aiuto in conto servizio (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                    15
# AIUTI PARTECIPAZIONE FIERE (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                 14
# Servizi Agevolati (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                          14
# VOUCHER (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                                    13
# supporto alla costituzione, allo start up  e incubazione (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                   12
# Sovvenzione diretta (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                        11
# aiuti partecipazione a fiere (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                               11
# Voucher (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                                    11
# sovvenzione diretta in denaro (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                              11
# contributo in conto capitale start up (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                      7
# contributi a fondo perduto (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                 6
# incentivo alle imprese (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                     4
# PREMIO FORFETTARIO (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                         4
# CONTRIBUTO (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                                 4
# compesazione oneri servizio (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                3
# RIMBORSO SPESE (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                             3
# contributi  (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                                2
# sovvenzione per servizi di internazionalizzazione (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                          2
# Aiuti partecipazioni fiere (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                 2
# Contributo per attività istituzionale volo sportivo (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                        2
# Contributo (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                                 1
# contributo in conto capitale (Categoria: Misura per il finanziamento del rischio)                                                                                                                                                                 1
# Contributo a fondo perduto per parziale copertura dei costi (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                1
# contributo (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                                 1
# Contributo diretto di spesa (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                1
# Sovvenzione (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                                1
# Moratoria su finanziamenti (Categoria: Prestito/Anticipo rimborsabile)                                                                                                                                                                            1
# sovvenzione (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                                1
# contributo straordinario (Categoria: Sovvenzione/Contributo in conto interessi)                                                                                                                                                                   1
# Name: DES_STRUMENTO, dtype: int64

# %%
total_aiuti.groupby(['Y','DES_TIPO_BENEFICIARIO'])['ELEMENTO_DI_AIUTO'].sum()
# Out:
# Y     DES_TIPO_BENEFICIARIO
# 2009  PMI                     198000.000
# 2010  PMI                     660000.000
# 2011  PMI                     615000.000
# 2012  PMI                     797847.490
# 2013  -                       1299800.000
#       PMI                     2444337.140
# 2014  PMI                     491097584.050
# 2015  -                       144198919.820
#       Grande impresa          5618190.070
#       PMI                     28006165.950
# 2016  -                       23015730.250
#       Grande impresa          57121001.730
#       PMI                     100321804.150
# 2017  -                       788768687.280
#       Grande impresa          1950051135.740
#       PMI                     1944866365.010
# 2018  Grande impresa          339304.390
#       PMI                     2457118.500
# Name: ELEMENTO_DI_AIUTO, dtype: float64

# %%
total_aiuti.groupby(['Y','DES_OBIETTIVO'])['ELEMENTO_DI_AIUTO'].sum()
# Out:
# Y     DES_OBIETTIVO
# 2009  PMI                                                                                                                                                                                                                                              198000.000
# 2010  PMI                                                                                                                                                                                                                                              660000.000
# 2011  PMI                                                                                                                                                                                                                                              615000.000
# 2012  PMI                                                                                                                                                                                                                                              797847.490
# 2013  Cultura                                                                                                                                                                                                                                          1334800.000
#       PMI                                                                                                                                                                                                                                              2409337.140
# 2014  Aiuti a favore dei lavoratori svantaggiati e/o dei lavoratori con disabilità                                                                                                                                                                     79200.000
#       Aiuti per la cultura e la conservazione del patrimonio (art. 53)                                                                                                                                                                                 422693.160
#       Altro obiettivo di sviluppo economico o sociale non classificato                                                                                                                                                                                 56230.000
#       Cultura                                                                                                                                                                                                                                          387023.000
#       PMI                                                                                                                                                                                                                                              12379823.970
#       Ricerca, sviluppo e innovazione                                                                                                                                                                                                                  4165221.840
#       Sviluppo regionale o locale                                                                                                                                                                                                                      471729024.060
#       Sviluppo settoriale                                                                                                                                                                                                                              1878368.020
# 2015  Aiuti a favore dei lavoratori svantaggiati e/o dei lavoratori con disabilità                                                                                                                                                                     339808.900
#       Aiuti a favore di ricerca, sviluppo e innovazione | Aiuti per l'innovazione dei processi e dell'organizzazione (art. 29)                                                                                                                         578565.000
#       Aiuti a favore di ricerca, sviluppo e innovazione | Ricerca fondamentale [art. 25, par. 2, lettera a)]                                                                                                                                           14854858.300
#       Aiuti a favore di ricerca, sviluppo e innovazione | Ricerca industriale (art 25) [art. 25, par. 2, lettera b)]                                                                                                                                   1305986.500
#       Aiuti a favore di ricerca, sviluppo e innovazione | Sviluppo sperimentale [art. 25, par. 2, lettera c)]                                                                                                                                          2749464.110
#       Aiuti alla Formazione (art.31)                                                                                                                                                                                                                   278659.110
#       Aiuti alle PMI | Aiuti agli investimenti a favore delle PMI (art. 17)                                                                                                                                                                            0.010
#       Aiuti alle PMI | Aiuti per servizi di consulenza (art. 18)                                                                                                                                                                                       1158950.000
#       Aiuti per la cultura e la conservazione del patrimonio (art. 53)                                                                                                                                                                                 4272811.020
#       Aiuti per la tutela dell'ambiente | Aiuti agli investimenti che consentono alle imprese di andare oltre le norme dell'Unione in materia di tutela ambientale o di innalzare il livello di tutela ambientale in assenza di tali norme (art. 36)   297344.000
#       Aiuti per le infrastrutture sportive e le infrastrutture ricreative multifunzionali (art. 55)                                                                                                                                                    600000.000
#       Altro obiettivo di sviluppo economico o sociale non classificato                                                                                                                                                                                 190347.600
#       Cultura                                                                                                                                                                                                                                          588610.000
#       Infrastrutture sportive e infrastrutture ricreative multifunzionali                                                                                                                                                                              563321.510
#       PMI                                                                                                                                                                                                                                              10550500.870
#       Promozione dell'esportazione e dell'internazionalizzazione                                                                                                                                                                                       111675.580
#                                                                                                                                                                                                                                                           ...
# 2017  Aiuti per le infrastrutture sportive e le infrastrutture ricreative multifunzionali (art. 55)                                                                                                                                                    7332758.440
#       Aiuti regionali agli investimenti e all'occupazione (art. 13) — Regime                                                                                                                                                                           1248607.100
#       Aiuti sotto forma di capitale di rischio (art. 28-29)                                                                                                                                                                                            929100.000
#       Altro obiettivo di sviluppo economico o sociale non classificato                                                                                                                                                                                 133754443.520
#       Compensazione di danni arrecati da calamità naturali o da altri eventi eccezionali                                                                                                                                                               16691760.860
#       Conservazione del patrimonio                                                                                                                                                                                                                     2229671.230
#       Cultura                                                                                                                                                                                                                                          1916005.550
#       Efficienza energetica                                                                                                                                                                                                                            6562525.810
#       Energia rinnovabile                                                                                                                                                                                                                              2906624.700
#       Finanziamento del rischio                                                                                                                                                                                                                        10176974.110
#       Formazione                                                                                                                                                                                                                                       85076613.110
#       Infrastrutture a banda larga                                                                                                                                                                                                                     1622947714.000
#       Infrastrutture energetiche                                                                                                                                                                                                                       64651.200
#       Infrastrutture sportive e infrastrutture ricreative multifunzionali                                                                                                                                                                              2091948.740
#       PMI                                                                                                                                                                                                                                              522612532.960
#       Promozione dell'esportazione e dell'internazionalizzazione                                                                                                                                                                                       22619828.390
#       Protezione ambientale                                                                                                                                                                                                                            479632829.610
#       Realizzazione di un importante progetto di comune interesse europeo                                                                                                                                                                              135373588.110
#       Regimi di aiuti a favore delle opere audiovisive (art. 54)                                                                                                                                                                                       13667278.530
#       Ricerca, sviluppo e innovazione                                                                                                                                                                                                                  9594713.370
#       Servizi d'interesse economico generale (SIEG)                                                                                                                                                                                                    109919005.080
#       Sostegno sociale a singoli consumatori                                                                                                                                                                                                           50000.000
#       Sviluppo regionale o locale                                                                                                                                                                                                                      304362673.790
#       Sviluppo settoriale                                                                                                                                                                                                                              11825545.320
# 2018  Aiuti a favore dei lavoratori svantaggiati e/o dei lavoratori con disabilità                                                                                                                                                                     42500.000
#       Aiuti alla Formazione (art.31)                                                                                                                                                                                                                   362326.350
#       Altro obiettivo di sviluppo economico o sociale non classificato                                                                                                                                                                                 63402.500
#       Formazione                                                                                                                                                                                                                                       2197600.950
#       PMI                                                                                                                                                                                                                                              9543.090
#       Sviluppo regionale o locale                                                                                                                                                                                                                      121050.000
# Name: ELEMENTO_DI_AIUTO, Length: 125, dtype: float64

# %%
total_aiuti.groupby(['DES_OBIETTIVO','Y'])['ELEMENTO_DI_AIUTO'].sum()
# Out:
# DES_OBIETTIVO                                                                                                                                                                       Y
# Accesso delle PMI ai finanziamenti | Aiuti alle imprese in fase di avviamento (art. 22)                                                                                             2017   15551157.780
# Aiuti a favore dei lavoratori svantaggiati e/o dei lavoratori con disabilità                                                                                                        2014   79200.000
#                                                                                                                                                                                     2015   339808.900
#                                                                                                                                                                                     2016   221086.340
#                                                                                                                                                                                     2017   2252423.630
#                                                                                                                                                                                     2018   42500.000
# Aiuti a favore di lavoratori svantaggiati e di lavoratori con disabilità | Aiuti all'assunzione di lavoratori svantaggiati sotto forma di integrazioni salariali (art. 32)          2016   90000.000
#                                                                                                                                                                                     2017   4177332.390
# Aiuti a favore di lavoratori svantaggiati e di lavoratori con disabilità | Aiuti all'occupazione di lavoratori con disabilita sotto forma di integrazioni salariali (art. 33)       2016   16963.310
#                                                                                                                                                                                     2017   1567167.230
# Aiuti a favore di lavoratori svantaggiati e di lavoratori con disabilità | Aiuti intesi a compensare i costi dell'assistenza fornita ai lavoratori svantaggiati (art. 35)           2017   6400.000
# Aiuti a favore di lavoratori svantaggiati e di lavoratori con disabilità | Aiuti intesi a compensare i sovraccosti connessi all'occupazione di lavoratori con disabilita (art. 34)  2016   16069.200
#                                                                                                                                                                                     2017   464495.580
# Aiuti a favore di ricerca, sviluppo e innovazione | Aiuti agli investimenti per le infrastrutture di ricerca (art. 26)                                                              2017   6682545.830
# Aiuti a favore di ricerca, sviluppo e innovazione | Aiuti ai poli d'innovazione (art. 27)                                                                                           2016   465177.830
#                                                                                                                                                                                     2017   2088164.340
# Aiuti a favore di ricerca, sviluppo e innovazione | Aiuti all'innovazione a favore delle PMI (art. 28)                                                                              2016   205724.790
#                                                                                                                                                                                     2017   16828247.310
# Aiuti a favore di ricerca, sviluppo e innovazione | Aiuti per l'innovazione dei processi e dell'organizzazione (art. 29)                                                            2015   578565.000
#                                                                                                                                                                                     2017   10661866.180
# Aiuti a favore di ricerca, sviluppo e innovazione | Ricerca fondamentale [art. 25, par. 2, lettera a)]                                                                              2015   14854858.300
# Aiuti a favore di ricerca, sviluppo e innovazione | Ricerca industriale (art 25) [art. 25, par. 2, lettera b)]                                                                      2015   1305986.500
#                                                                                                                                                                                     2016   42118626.890
#                                                                                                                                                                                     2017   287390800.310
# Aiuti a favore di ricerca, sviluppo e innovazione | Studi di fattibilità [art. 25, par. 2, lettera d)]                                                                              2017   2108984.000
# Aiuti a favore di ricerca, sviluppo e innovazione | Sviluppo sperimentale [art. 25, par. 2, lettera c)]                                                                             2015   2749464.110
#                                                                                                                                                                                     2016   53045058.230
#                                                                                                                                                                                     2017   202378691.360
# Aiuti a finalità regionale per lo sviluppo urbano (Art.16)                                                                                                                          2017   1031758.510
# Aiuti a finalità regionale — Aiuti agli investimenti (art. 14) — Regime                                                                                                             2017   143049616.660
#                                                                                                                                                                                                 ...
# PMI                                                                                                                                                                                 2012   797847.490
#                                                                                                                                                                                     2013   2409337.140
#                                                                                                                                                                                     2014   12379823.970
#                                                                                                                                                                                     2015   10550500.870
#                                                                                                                                                                                     2016   11643067.690
#                                                                                                                                                                                     2017   522612532.960
#                                                                                                                                                                                     2018   9543.090
# Promozione dell'esportazione e dell'internazionalizzazione                                                                                                                          2015   111675.580
#                                                                                                                                                                                     2016   662236.260
#                                                                                                                                                                                     2017   22619828.390
# Protezione ambientale                                                                                                                                                               2017   479632829.610
# Realizzazione di un importante progetto di comune interesse europeo                                                                                                                 2017   135373588.110
# Regimi di aiuti a favore delle opere audiovisive (art. 54)                                                                                                                          2016   2070423.560
#                                                                                                                                                                                     2017   13667278.530
# Ricerca, sviluppo e innovazione                                                                                                                                                     2014   4165221.840
#                                                                                                                                                                                     2015   8340552.710
#                                                                                                                                                                                     2016   2971094.230
#                                                                                                                                                                                     2017   9594713.370
# Servizi d'interesse economico generale (SIEG)                                                                                                                                       2015   130466852.590
#                                                                                                                                                                                     2016   1890582.120
#                                                                                                                                                                                     2017   109919005.080
# Sostegno sociale a singoli consumatori                                                                                                                                              2017   50000.000
# Sviluppo regionale o locale                                                                                                                                                         2014   471729024.060
#                                                                                                                                                                                     2015   574968.030
#                                                                                                                                                                                     2016   45079432.050
#                                                                                                                                                                                     2017   304362673.790
#                                                                                                                                                                                     2018   121050.000
# Sviluppo settoriale                                                                                                                                                                 2014   1878368.020
#                                                                                                                                                                                     2016   418068.860
#                                                                                                                                                                                     2017   11825545.320
# Name: ELEMENTO_DI_AIUTO, Length: 125, dtype: float64
